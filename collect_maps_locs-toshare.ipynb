# %% [markdown]
# The code below represents the fairly manual process of collecting Google Places data from cities of interest for my project on urban intergroup integration post-conflict and its impact on conflict recovery. I created grids of 400 x 400m (generally) for each city in ArcGIS Pro, then cycle through each grid centroid with the Google Places API to collect all places within a radius that meet my search criteria (religious, cultural, administrative, educational, medical sites, primarily).
#
# The Places API has a limit of 20 sites it can return, so for each city after cycling through all the points initially, I test if any have returned 20+ sites. For these, I rerun using a version of the code that searches for different types separately (`split`), and in the few cases where that still goes over the API return limit, I split every category out separately (`split_all`). I do this instead of just splitting all the categories from the start to minimize the number of API calls I make, as they are not free. In this example code I show the process for a few cities as an example.
#
# I store the end result as a goeojson for each city and process all of the cities' data together in another script, `calc_clustering_metrics.ipynb`.

# %%
import pandas as pd
import geopandas as gpd
import requests
import json
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/mnt/c/Users/natra/Documents/Research/Identity-Conflict'

# %% [markdown]
# ## Global Code

# %%
def place_extract_point(url,headers,included_types,lat,lon,radius):
    """
    Return the dictionary of places within a radius around the given lat/lon
    """

    json_data = {'includedTypes': included_types,
            'locationRestriction': {
                'circle' : {
                    'center' : {
                        'latitude' : lat,
                        'longitude' :  lon},
                    # radius in meters
                    'radius' : radius
                }}}

    print('posting request')
    response = requests.post(url, headers=headers, json=json_data)
    print('obtained response')
    try:
        places_out = json.loads(response.text)
    except json.decoder.JSONDecodeError:
        print("API returned nothing, JSON Decode Error")
        return None

    return(places_out)

# %%
def obtain_places_from_points(url, headers, point_gdf,radius=200,places_func="full"):
    """
    From a dataframe of points, search for nearby places around each point
        and return a dictionary of lists of the places
    places_func: either "main" for all places;
                "split" if need to use 2 separate calls to obtain the full list of 
                    places; 
                "split_all" if need to call each location type separately.
                Use when too many locations in a given point to avoid 
                    hitting the 20-max threshold in Google Places API
    """

    point_dicts = []
    nrow = point_gdf.shape[0]
    included_types = ['art_gallery','museum','performing_arts_theater',
                            'library','school','university',
                            'community_center','cultural_center','historical_landmark',
                            'city_hall','courthouse','local_government_office','police',
                            'hospital',
                            'church','hindu_temple','mosque','synagogue']
    if places_func == "split":
        included_types_re =  ['library','school','university',
                            'church','hindu_temple','mosque','synagogue']
        included_types_cg = ['art_gallery','museum','performing_arts_theater',
                            'community_center','cultural_center','historical_landmark',
                            'city_hall','courthouse','local_government_office','police',
                            'hospital']

    for i, row in point_gdf.iterrows():
        print('obtaining places for point ',i,' / ',nrow)
        
        lon = row['geometry'].x
        lat = row['geometry'].y

        if places_func=="full":
            out_places = place_extract_point(url,headers,included_types,lat,lon,radius)
            if out_places:
                dict_places = out_places['places']
            else:
                dict_places = []
        elif places_func=="split":
            print("Obtaining religious and educational places..")
            out_places_re = place_extract_point(url, headers, included_types_re,lat, lon, radius)
            print("Religious & Edu out_places:", out_places_re)
            print("Obtaining cultural and government places..")
            out_places_cg = place_extract_point(url, headers, included_types_cg,lat, lon, radius)
            print("Culture & Gov out_places:", out_places_cg)
            if out_places_re and out_places_cg:
                # use lengths to confirm not 20 places returned, if so, likely hitting limit of api
                # and need to split further
                print("Number of results returned from re: ",len(out_places_re['places']))
                print("Number of results returned from cg: ",len(out_places_cg['places']))
                dict_places = out_places_re['places'] + out_places_cg['places']
            elif out_places_re:
                print("Number of results returned from re: ",len(out_places_re['places']))
                dict_places = out_places_re['places']
            elif out_places_cg:
                print("Number of results returned from cg: ",len(out_places_cg['places']))
                dict_places = out_places_cg['places']
            else:
                dict_places = []
        elif places_func == "split_all":
            dict_places = []
            print("Obtaining places type by type")
            for pl_type in included_types:
                print("Obtaining for type ",pl_type)
                out_places = place_extract_point(url,headers,[pl_type],lat,lon,radius)
                if out_places:
                    print(f"Number of results returned from type {pl_type}: {len(out_places['places'])}")
                    dict_places = dict_places + out_places['places']
        
        print(dict_places)

        # create dictionary with geometry of point as the key
        point_dict = {row['geometry']: dict_places}

        point_dicts.append(point_dict)

    return(point_dicts)

# %%
def clean_maps_api_output(pts_lst):
    """
    Take full list of points from Google Maps API output and convert
        to GeoPandas geodataframe for future use.
    """
    pts_lst_content = [pt for pt in pts_lst if len(list(pt.values())[0]) > 0]
    print("Number of place dictionaries returned from API: ",len(pts_lst_content))
    pts_lst_content[0:1]

    # convert place list to tables
    df_lst = []
    for pt_entry in pts_lst_content:
        df_row = pd.json_normalize(list(pt_entry.values())[0])
        df_row['api_loc'] = list(pt_entry.keys())[0]
        df_lst.append(df_row)
    loc_df = pd.concat(df_lst)

    print("Shape of resulting dataframe: ",loc_df.shape)
    # remove duplicates caused by overlapping cells
    loc_df = loc_df.drop_duplicates(subset=['location.latitude',
                                            'location.longitude',
                                            'id']).reset_index(drop=True)
    print("Shape of dataframe after dropping dups: ",loc_df.shape)

    # rename columns to friendlier names
    loc_df = loc_df.rename(columns={'location.latitude':'latitude',
                                                'location.longitude':'longitude',
                                                'displayName.text':'displayName',
                                                'displayName.languageCode':'nameLang',
                                                'primaryTypeDisplayName.text':'primaryTypeDisplayName',
                                                'primaryTypeDisplayName.languageCode':
                                                'primaryTypeDisplayLang'})

    # turn the api location point column into lat/lon to be able to store final file with single geom
    loc_df = gpd.GeoDataFrame(loc_df, geometry='api_loc')
    loc_df['api_lat'] = loc_df['api_loc'].y
    loc_df['api_lon'] = loc_df['api_loc'].x
    loc_df.drop(columns=['api_loc'], inplace=True)

    # convert to gdf with actual loc column as geometry
    loc_gdf = gpd.GeoDataFrame(loc_df, 
                                        geometry=gpd.points_from_xy(loc_df.longitude
                                                                    ,loc_df.latitude),
                                        crs='epsg:4326')
    # convert list to str for storage
    loc_gdf['types'] = loc_gdf['types'].astype('str')
    
    return loc_gdf

# %%
API_KEY = ""   # removed for privacy


url = f"https://places.googleapis.com/v1/places:searchNearby"
headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': API_KEY,
    'X-Goog-FieldMask': 'places.displayName,places.formattedAddress,places.businessStatus,places.id,places.location,places.primaryType,places.primaryTypeDisplayName,places.shortFormattedAddress,places.subDestinations,places.types,',
}

# %% [markdown]
# ## Croatia

# %% [markdown]
# ### Osijek

# %%
# created grid in as 400 x 400 w x h grids with Fishnet tool in ArcGIS Pro
grid = gpd.read_file('./croatia_files/raw/site_locations/osijek-fishnet-clip-4326.shp')
print(grid.shape)
print(grid.crs)
grid.head()
# Out:
# (525, 2)
# EPSG:4326
#    Id                   geometry
# 0   0  POINT (18.62279 45.51391)
# 1   0  POINT (18.62791 45.51381)
# 2   0  POINT (18.63303 45.51372)
# 3   0  POINT (18.63814 45.51362)
# 4   0  POINT (18.64326 45.51352)

# %%
points_lst = obtain_places_from_points(url, headers, grid, 200)
# Out:
# obtaining places for point  0  /  525
# posting request
# obtained response
# []
# obtaining places for point  1  /  525
# posting request
# obtained response
# []
# obtaining places for point  2  /  525
# posting request
# obtained response
# []
# obtaining places for point  3  /  525
# posting request
# obtained response
# []
# obtaining places for point  4  /  525
# posting request
# obtained response
# []
# obtaining places for point  5  /  525
# posting request
# obtained response
# []
# obtaining places for point  6  /  525
# posting request
# obtained response
# []
# obtaining places for point  7  /  525
# posting request
# obtained response
# []
# obtaining places for point  8  /  525
# posting request
# obtained response
# []
# obtaining places for point  9  /  525
# posting request
# obtained response
# []
# obtaining places for point  10  /  525
# posting request
# obtained response
# []
# obtaining places for point  11  /  525
# posting request
# obtained response
# []
# obtaining places for point  12  /  525
# posting request
# obtained response
# []
# obtaining places for point  13  /  525
# posting request
# obtained response
# []
# obtaining places for point  14  /  525
# posting request
# obtained response
# []
# obtaining places for point  15  /  525
# posting request
# obtained response
# []
# obtaining places for point  16  /  525
# posting request
# obtained response
# []
# obtaining places for point  17  /  525
# posting request
# obtained response
# []
# obtaining places for point  18  /  525
# posting request
# obtained response
# []
# obtaining places for point  19  /  525
# posting request
# obtained response
# []
# obtaining places for point  20  /  525
# posting request
# obtained response
# []
# obtaining places for point  21  /  525
# posting request
# obtained response
# []
# obtaining places for point  22  /  525
# posting request
# obtained response
# []
# obtaining places for point  23  /  525
# posting request
# obtained response
# []
# obtaining places for point  24  /  525
# posting request
# obtained response
# []
# obtaining places for point  25  /  525
# posting request
# obtained response
# []
# obtaining places for point  26  /  525
# posting request
# obtained response
# [{'id': 'ChIJW7CwKQ3mXEcRbrlx_vDnKwU', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Usorska ul. 80, 31000, Brijest, Croatia', 'location': {'latitude': 45.518030599999996, 'longitude': 18.675072699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of the Martyrdom of St. John the Baptist', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Usorska ul. 80, Brijest'}, {'id': 'ChIJVZtPnJ_nXEcRQIys-N0RRmI', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Južno predgrađe 54, 31000, Osijek, Croatia', 'location': {'latitude': 45.5168727, 'longitude': 18.673980699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mjesni odbor Brijest', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Ul. Južno predgrađe 54, Osijek'}]
# obtaining places for point  27  /  525
# posting request
# obtained response
# []
# obtaining places for point  28  /  525
# posting request
# obtained response
# []
# obtaining places for point  29  /  525
# posting request
# obtained response
# []
# obtaining places for point  30  /  525
# posting request
# obtained response
# []
# obtaining places for point  31  /  525
# posting request
# obtained response
# []
# obtaining places for point  32  /  525
# posting request
# obtained response
# []
# obtaining places for point  33  /  525
# posting request
# obtained response
# []
# obtaining places for point  34  /  525
# posting request
# obtained response
# []
# obtaining places for point  35  /  525
# posting request
# obtained response
# []
# obtaining places for point  36  /  525
# posting request
# obtained response
# []
# obtaining places for point  37  /  525
# posting request
# obtained response
# []
# obtaining places for point  38  /  525
# posting request
# obtained response
# []
# obtaining places for point  39  /  525
# posting request
# obtained response
# []
# obtaining places for point  40  /  525
# posting request
# obtained response
# []
# obtaining places for point  41  /  525
# posting request
# obtained response
# []
# obtaining places for point  42  /  525
# posting request
# obtained response
# []
# obtaining places for point  43  /  525
# posting request
# obtained response
# []
# obtaining places for point  44  /  525
# posting request
# obtained response
# []
# obtaining places for point  45  /  525
# posting request
# obtained response
# []
# obtaining places for point  46  /  525
# posting request
# obtained response
# []
# obtaining places for point  47  /  525
# posting request
# obtained response
# []
# obtaining places for point  48  /  525
# posting request
# obtained response
# []
# obtaining places for point  49  /  525
# posting request
# obtained response
# []
# obtaining places for point  50  /  525
# posting request
# obtained response
# []
# obtaining places for point  51  /  525
# posting request
# obtained response
# []
# obtaining places for point  52  /  525
# posting request
# obtained response
# []
# obtaining places for point  53  /  525
# posting request
# obtained response
# []
# obtaining places for point  54  /  525
# posting request
# obtained response
# []
# obtaining places for point  55  /  525
# posting request
# obtained response
# []
# obtaining places for point  56  /  525
# posting request
# obtained response
# []
# obtaining places for point  57  /  525
# posting request
# obtained response
# []
# obtaining places for point  58  /  525
# posting request
# obtained response
# []
# obtaining places for point  59  /  525
# posting request
# obtained response
# []
# obtaining places for point  60  /  525
# posting request
# obtained response
# []
# obtaining places for point  61  /  525
# posting request
# obtained response
# []
# obtaining places for point  62  /  525
# posting request
# obtained response
# []
# obtaining places for point  63  /  525
# posting request
# obtained response
# []
# obtaining places for point  64  /  525
# posting request
# obtained response
# []
# obtaining places for point  65  /  525
# posting request
# obtained response
# []
# obtaining places for point  66  /  525
# posting request
# obtained response
# []
# obtaining places for point  67  /  525
# posting request
# obtained response
# []
# obtaining places for point  68  /  525
# posting request
# obtained response
# []
# obtaining places for point  69  /  525
# posting request
# obtained response
# []
# obtaining places for point  70  /  525
# posting request
# obtained response
# []
# obtaining places for point  71  /  525
# posting request
# obtained response
# []
# obtaining places for point  72  /  525
# posting request
# obtained response
# []
# obtaining places for point  73  /  525
# posting request
# obtained response
# []
# obtaining places for point  74  /  525
# posting request
# obtained response
# []
# obtaining places for point  75  /  525
# posting request
# obtained response
# []
# obtaining places for point  76  /  525
# posting request
# obtained response
# []
# obtaining places for point  77  /  525
# posting request
# obtained response
# []
# obtaining places for point  78  /  525
# posting request
# obtained response
# []
# obtaining places for point  79  /  525
# posting request
# obtained response
# []
# obtaining places for point  80  /  525
# posting request
# obtained response
# []
# obtaining places for point  81  /  525
# posting request
# obtained response
# []
# obtaining places for point  82  /  525
# posting request
# obtained response
# []
# obtaining places for point  83  /  525
# posting request
# obtained response
# []
# obtaining places for point  84  /  525
# posting request
# obtained response
# []
# obtaining places for point  85  /  525
# posting request
# obtained response
# []
# obtaining places for point  86  /  525
# posting request
# obtained response
# []
# obtaining places for point  87  /  525
# posting request
# obtained response
# []
# obtaining places for point  88  /  525
# posting request
# obtained response
# []
# obtaining places for point  89  /  525
# posting request
# obtained response
# []
# obtaining places for point  90  /  525
# posting request
# obtained response
# []
# obtaining places for point  91  /  525
# posting request
# obtained response
# []
# obtaining places for point  92  /  525
# posting request
# obtained response
# []
# obtaining places for point  93  /  525
# posting request
# obtained response
# []
# obtaining places for point  94  /  525
# posting request
# obtained response
# []
# obtaining places for point  95  /  525
# posting request
# obtained response
# []
# obtaining places for point  96  /  525
# posting request
# obtained response
# []
# obtaining places for point  97  /  525
# posting request
# obtained response
# []
# obtaining places for point  98  /  525
# posting request
# obtained response
# []
# obtaining places for point  99  /  525
# posting request
# obtained response
# []
# obtaining places for point  100  /  525
# posting request
# obtained response
# []
# obtaining places for point  101  /  525
# posting request
# obtained response
# []
# obtaining places for point  102  /  525
# posting request
# obtained response
# []
# obtaining places for point  103  /  525
# posting request
# obtained response
# []
# obtaining places for point  104  /  525
# posting request
# obtained response
# []
# obtaining places for point  105  /  525
# posting request
# obtained response
# []
# obtaining places for point  106  /  525
# posting request
# obtained response
# [{'id': 'ChIJw84jtSXnXEcRz-WNEksyLOE', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zelena ul. 1, 31000, Briješće, Croatia', 'location': {'latitude': 45.528538399999995, 'longitude': 18.624333200000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Osnovna škola Cvjetno', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Zelena ul. 1, Briješće'}]
# obtaining places for point  107  /  525
# posting request
# obtained response
# []
# obtaining places for point  108  /  525
# posting request
# obtained response
# []
# obtaining places for point  109  /  525
# posting request
# obtained response
# []
# obtaining places for point  110  /  525
# posting request
# obtained response
# []
# obtaining places for point  111  /  525
# posting request
# obtained response
# []
# obtaining places for point  112  /  525
# posting request
# obtained response
# []
# obtaining places for point  113  /  525
# posting request
# obtained response
# []
# obtaining places for point  114  /  525
# posting request
# obtained response
# []
# obtaining places for point  115  /  525
# posting request
# obtained response
# []
# obtaining places for point  116  /  525
# posting request
# obtained response
# []
# obtaining places for point  117  /  525
# posting request
# obtained response
# []
# obtaining places for point  118  /  525
# posting request
# obtained response
# []
# obtaining places for point  119  /  525
# posting request
# obtained response
# []
# obtaining places for point  120  /  525
# posting request
# obtained response
# []
# obtaining places for point  121  /  525
# posting request
# obtained response
# []
# obtaining places for point  122  /  525
# posting request
# obtained response
# []
# obtaining places for point  123  /  525
# posting request
# obtained response
# []
# obtaining places for point  124  /  525
# posting request
# obtained response
# []
# obtaining places for point  125  /  525
# posting request
# obtained response
# []
# obtaining places for point  126  /  525
# posting request
# obtained response
# []
# obtaining places for point  127  /  525
# posting request
# obtained response
# []
# obtaining places for point  128  /  525
# posting request
# obtained response
# []
# obtaining places for point  129  /  525
# posting request
# obtained response
# []
# obtaining places for point  130  /  525
# posting request
# obtained response
# []
# obtaining places for point  131  /  525
# posting request
# obtained response
# []
# obtaining places for point  132  /  525
# posting request
# obtained response
# []
# obtaining places for point  133  /  525
# posting request
# obtained response
# []
# obtaining places for point  134  /  525
# posting request
# obtained response
# []
# obtaining places for point  135  /  525
# posting request
# obtained response
# []
# obtaining places for point  136  /  525
# posting request
# obtained response
# []
# obtaining places for point  137  /  525
# posting request
# obtained response
# []
# obtaining places for point  138  /  525
# posting request
# obtained response
# []
# obtaining places for point  139  /  525
# posting request
# obtained response
# []
# obtaining places for point  140  /  525
# posting request
# obtained response
# []
# obtaining places for point  141  /  525
# posting request
# obtained response
# []
# obtaining places for point  142  /  525
# posting request
# obtained response
# []
# obtaining places for point  143  /  525
# posting request
# obtained response
# []
# obtaining places for point  144  /  525
# posting request
# obtained response
# []
# obtaining places for point  145  /  525
# posting request
# obtained response
# []
# obtaining places for point  146  /  525
# posting request
# obtained response
# []
# obtaining places for point  147  /  525
# posting request
# obtained response
# []
# obtaining places for point  148  /  525
# posting request
# obtained response
# []
# obtaining places for point  149  /  525
# posting request
# obtained response
# []
# obtaining places for point  150  /  525
# posting request
# obtained response
# []
# obtaining places for point  151  /  525
# posting request
# obtained response
# []
# obtaining places for point  152  /  525
# posting request
# obtained response
# []
# obtaining places for point  153  /  525
# posting request
# obtained response
# []
# obtaining places for point  154  /  525
# posting request
# obtained response
# []
# obtaining places for point  155  /  525
# posting request
# obtained response
# []
# obtaining places for point  156  /  525
# posting request
# obtained response
# []
# obtaining places for point  157  /  525
# posting request
# obtained response
# []
# obtaining places for point  158  /  525
# posting request
# obtained response
# []
# obtaining places for point  159  /  525
# posting request
# obtained response
# []
# obtaining places for point  160  /  525
# posting request
# obtained response
# []
# obtaining places for point  161  /  525
# posting request
# obtained response
# []
# obtaining places for point  162  /  525
# posting request
# obtained response
# []
# obtaining places for point  163  /  525
# posting request
# obtained response
# []
# obtaining places for point  164  /  525
# posting request
# obtained response
# []
# obtaining places for point  165  /  525
# posting request
# obtained response
# []
# obtaining places for point  166  /  525
# posting request
# obtained response
# []
# obtaining places for point  167  /  525
# posting request
# obtained response
# []
# obtaining places for point  168  /  525
# posting request
# obtained response
# []
# obtaining places for point  169  /  525
# posting request
# obtained response
# []
# obtaining places for point  170  /  525
# posting request
# obtained response
# []
# obtaining places for point  171  /  525
# posting request
# obtained response
# []
# obtaining places for point  172  /  525
# posting request
# obtained response
# []
# obtaining places for point  173  /  525
# posting request
# obtained response
# []
# obtaining places for point  174  /  525
# posting request
# obtained response
# []
# obtaining places for point  175  /  525
# posting request
# obtained response
# []
# obtaining places for point  176  /  525
# posting request
# obtained response
# []
# obtaining places for point  177  /  525
# posting request
# obtained response
# [{'id': 'ChIJF1xS6pTmXEcRSn4iLkWroFE', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Svetog Leopolda Bogdana Mandića 159, 31000, Osijek, Croatia', 'location': {'latitude': 45.535346399999995, 'longitude': 18.6354139}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Leopold Bogdan Mandić', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Svetog Leopolda Bogdana Mandića 159, Osijek'}]
# obtaining places for point  178  /  525
# posting request
# obtained response
# []
# obtaining places for point  179  /  525
# posting request
# obtained response
# []
# obtaining places for point  180  /  525
# posting request
# obtained response
# []
# obtaining places for point  181  /  525
# posting request
# obtained response
# []
# obtaining places for point  182  /  525
# posting request
# obtained response
# []
# obtaining places for point  183  /  525
# posting request
# obtained response
# []
# obtaining places for point  184  /  525
# posting request
# obtained response
# []
# obtaining places for point  185  /  525
# posting request
# obtained response
# []
# obtaining places for point  186  /  525
# posting request
# obtained response
# []
# obtaining places for point  187  /  525
# posting request
# obtained response
# []
# obtaining places for point  188  /  525
# posting request
# obtained response
# []
# obtaining places for point  189  /  525
# posting request
# obtained response
# []
# obtaining places for point  190  /  525
# posting request
# obtained response
# []
# obtaining places for point  191  /  525
# posting request
# obtained response
# []
# obtaining places for point  192  /  525
# posting request
# obtained response
# []
# obtaining places for point  193  /  525
# posting request
# obtained response
# []
# obtaining places for point  194  /  525
# posting request
# obtained response
# []
# obtaining places for point  195  /  525
# posting request
# obtained response
# []
# obtaining places for point  196  /  525
# posting request
# obtained response
# []
# obtaining places for point  197  /  525
# posting request
# obtained response
# []
# obtaining places for point  198  /  525
# posting request
# obtained response
# []
# obtaining places for point  199  /  525
# posting request
# obtained response
# []
# obtaining places for point  200  /  525
# posting request
# obtained response
# []
# obtaining places for point  201  /  525
# posting request
# obtained response
# []
# obtaining places for point  202  /  525
# posting request
# obtained response
# []
# obtaining places for point  203  /  525
# posting request
# obtained response
# []
# obtaining places for point  204  /  525
# posting request
# obtained response
# []
# obtaining places for point  205  /  525
# posting request
# obtained response
# []
# obtaining places for point  206  /  525
# posting request
# obtained response
# []
# obtaining places for point  207  /  525
# posting request
# obtained response
# []
# obtaining places for point  208  /  525
# posting request
# obtained response
# []
# obtaining places for point  209  /  525
# posting request
# obtained response
# []
# obtaining places for point  210  /  525
# posting request
# obtained response
# []
# obtaining places for point  211  /  525
# posting request
# obtained response
# []
# obtaining places for point  212  /  525
# posting request
# obtained response
# []
# obtaining places for point  213  /  525
# posting request
# obtained response
# []
# obtaining places for point  214  /  525
# posting request
# obtained response
# []
# obtaining places for point  215  /  525
# posting request
# obtained response
# []
# obtaining places for point  216  /  525
# posting request
# obtained response
# []
# obtaining places for point  217  /  525
# posting request
# obtained response
# []
# obtaining places for point  218  /  525
# posting request
# obtained response
# []
# obtaining places for point  219  /  525
# posting request
# obtained response
# []
# obtaining places for point  220  /  525
# posting request
# obtained response
# []
# obtaining places for point  221  /  525
# posting request
# obtained response
# []
# obtaining places for point  222  /  525
# posting request
# obtained response
# []
# obtaining places for point  223  /  525
# posting request
# obtained response
# []
# obtaining places for point  224  /  525
# posting request
# obtained response
# []
# obtaining places for point  225  /  525
# posting request
# obtained response
# []
# obtaining places for point  226  /  525
# posting request
# obtained response
# []
# obtaining places for point  227  /  525
# posting request
# obtained response
# []
# obtaining places for point  228  /  525
# posting request
# obtained response
# []
# obtaining places for point  229  /  525
# posting request
# obtained response
# []
# obtaining places for point  230  /  525
# posting request
# obtained response
# []
# obtaining places for point  231  /  525
# posting request
# obtained response
# []
# obtaining places for point  232  /  525
# posting request
# obtained response
# []
# obtaining places for point  233  /  525
# posting request
# obtained response
# []
# obtaining places for point  234  /  525
# posting request
# obtained response
# []
# obtaining places for point  235  /  525
# posting request
# obtained response
# []
# obtaining places for point  236  /  525
# posting request
# obtained response
# []
# obtaining places for point  237  /  525
# posting request
# obtained response
# []
# obtaining places for point  238  /  525
# posting request
# obtained response
# []
# obtaining places for point  239  /  525
# posting request
# obtained response
# []
# obtaining places for point  240  /  525
# posting request
# obtained response
# []
# obtaining places for point  241  /  525
# posting request
# obtained response
# []
# obtaining places for point  242  /  525
# posting request
# obtained response
# []
# obtaining places for point  243  /  525
# posting request
# obtained response
# []
# obtaining places for point  244  /  525
# posting request
# obtained response
# []
# obtaining places for point  245  /  525
# posting request
# obtained response
# []
# obtaining places for point  246  /  525
# posting request
# obtained response
# []
# obtaining places for point  247  /  525
# posting request
# obtained response
# []
# obtaining places for point  248  /  525
# posting request
# obtained response
# []
# obtaining places for point  249  /  525
# posting request
# obtained response
# []
# obtaining places for point  250  /  525
# posting request
# obtained response
# []
# obtaining places for point  251  /  525
# posting request
# obtained response
# [{'id': 'ChIJRWUvuFfmXEcRwyTBJA3Cy4w', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bednjanska ul. 49, 31000, Osijek, Croatia', 'location': {'latitude': 45.5432263, 'longitude': 18.6655415}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'St. Mark’s Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Bednjanska ul. 49, Osijek'}]
# obtaining places for point  252  /  525
# posting request
# obtained response
# []
# obtaining places for point  253  /  525
# posting request
# obtained response
# []
# obtaining places for point  254  /  525
# posting request
# obtained response
# []
# obtaining places for point  255  /  525
# posting request
# obtained response
# []
# obtaining places for point  256  /  525
# posting request
# obtained response
# []
# obtaining places for point  257  /  525
# posting request
# obtained response
# []
# obtaining places for point  258  /  525
# posting request
# obtained response
# [{'id': 'ChIJfQ0bwDPmXEcRXExXocYh9Mc', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bogdanovačka ul. 21, 31000, Osijek, Croatia', 'location': {'latitude': 45.5420011, 'longitude': 18.700056}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DJEČJI VRTIĆ LANE OSIJEK', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Bogdanovačka ul. 21, Osijek'}]
# obtaining places for point  259  /  525
# posting request
# obtained response
# [{'id': 'ChIJpTNnii3mXEcR0i0sSr9BRug', 'types': ['primary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ćelijska ul., 31000, Osijek, Croatia', 'location': {'latitude': 45.5424219, 'longitude': 18.704192199999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'OSIgurajmo im JEdnaKost', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Ćelijska ul., Osijek'}]
# obtaining places for point  260  /  525
# posting request
# obtained response
# [{'id': 'ChIJI-5S7qfnXEcR3OUQBFZZHig', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Josipa Reihl - Kira 75, 31000, Osijek, Croatia', 'location': {'latitude': 45.5426742, 'longitude': 18.711633499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PETRONI d.o.o.', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Ul. Josipa Reihl - Kira 75, Osijek'}]
# obtaining places for point  261  /  525
# posting request
# obtained response
# []
# obtaining places for point  262  /  525
# posting request
# obtained response
# []
# obtaining places for point  263  /  525
# posting request
# obtained response
# []
# obtaining places for point  264  /  525
# posting request
# obtained response
# []
# obtaining places for point  265  /  525
# posting request
# obtained response
# [{'id': 'ChIJZ0p3BLznXEcRij8SMIGgwRM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Južno predgrađe 17, 31000, Osijek, Croatia', 'location': {'latitude': 45.5406353, 'longitude': 18.7359871}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Agricultural Institute', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Južno predgrađe 17, Osijek'}]
# obtaining places for point  266  /  525
# posting request
# obtained response
# []
# obtaining places for point  267  /  525
# posting request
# obtained response
# []
# obtaining places for point  268  /  525
# posting request
# obtained response
# []
# obtaining places for point  269  /  525
# posting request
# obtained response
# []
# obtaining places for point  270  /  525
# posting request
# obtained response
# []
# obtaining places for point  271  /  525
# posting request
# obtained response
# []
# obtaining places for point  272  /  525
# posting request
# obtained response
# []
# obtaining places for point  273  /  525
# posting request
# obtained response
# []
# obtaining places for point  274  /  525
# posting request
# obtained response
# []
# obtaining places for point  275  /  525
# posting request
# obtained response
# []
# obtaining places for point  276  /  525
# posting request
# obtained response
# []
# obtaining places for point  277  /  525
# posting request
# obtained response
# []
# obtaining places for point  278  /  525
# posting request
# obtained response
# []
# obtaining places for point  279  /  525
# posting request
# obtained response
# []
# obtaining places for point  280  /  525
# posting request
# obtained response
# []
# obtaining places for point  281  /  525
# posting request
# obtained response
# [{'id': 'ChIJS833YQ3nXEcRn-9NwkfQYQo', 'types': ['community_center', 'convention_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gospodarska zona 10, 31000, Osijek, Croatia', 'location': {'latitude': 45.546306, 'longitude': 18.644838399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Business Centre of Osijek-Baranja County', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Gospodarska zona 10, Osijek'}]
# obtaining places for point  282  /  525
# posting request
# obtained response
# []
# obtaining places for point  283  /  525
# posting request
# obtained response
# [{'id': 'ChIJTamWl7vnXEcRhkNNlxiD0tM', 'types': ['dance_hall', 'sports_club', 'event_venue', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Svetog Leopolda Bogdana Mandića 50a, 31000, Osijek, Croatia', 'location': {'latitude': 45.5464139, 'longitude': 18.656619}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Plesni Studio Leon', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Ul. Svetog Leopolda Bogdana Mandića 50a, Osijek'}]
# obtaining places for point  284  /  525
# posting request
# obtained response
# []
# obtaining places for point  285  /  525
# posting request
# obtained response
# []
# obtaining places for point  286  /  525
# posting request
# obtained response
# []
# obtaining places for point  287  /  525
# posting request
# obtained response
# [{'id': 'ChIJm0gL7lznXEcRfZ3jAxygg84', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vinkovačka cesta 66D, 31000, Osijek, Croatia', 'location': {'latitude': 45.545181799999995, 'longitude': 18.6774614}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska i sveučilišna knjižnica Osijek', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Vinkovačka cesta 66D, Osijek'}, {'id': 'ChIJrRskYFTnXEcRhpUklcuJBvo', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'health', 'establishment'], 'formattedAddress': 'Vinkovačka cesta 68, 31000, Osijek, Croatia', 'location': {'latitude': 45.544488199999996, 'longitude': 18.6766522}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'LG Vita', 'languageCode': 'en'}, 'shortFormattedAddress': 'Vinkovačka cesta 68, Osijek'}]
# obtaining places for point  288  /  525
# posting request
# obtained response
# [{'id': 'ChIJ42KQNKXnXEcRmcsI3DCquR4', 'types': ['local_government_office', 'government_office', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 8, 31000, Osijek, Croatia', 'location': {'latitude': 45.546630099999994, 'longitude': 18.681680699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bureau of Public Health Osijek-Baranja County', 'languageCode': 'en'}, 'shortFormattedAddress': 'Drinska ul. 8, Osijek'}, {'id': 'ChIJf4YwlU3mXEcROUycY9vjr1c', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gacka ul. 1A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5452666, 'longitude': 18.679223}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DJEČJI VRTIĆ PČELICA', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Gacka ul. 1A, Osijek'}, {'id': 'ChIJf4YwlU3mXEcR1b5w8sqiCs4', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gacka ul. 1B, 31000, Osijek, Croatia', 'location': {'latitude': 45.5453398, 'longitude': 18.6799474}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DJEČJE JASLICE TRATINČICA', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Gacka ul. 1B, Osijek'}]
# obtaining places for point  289  /  525
# posting request
# obtained response
# [{'id': 'ChIJHy2Si7LnXEcRzx-FXpItXdo', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Krbavska ul., 31000, Osijek, Croatia', 'location': {'latitude': 45.5466194, 'longitude': 18.6858539}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PROSVJETNO-KULTURNI CENTAR MAĐARA U REPUBLICI HRVATSKOJ', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Krbavska ul., Osijek'}]
# obtaining places for point  290  /  525
# posting request
# obtained response
# []
# obtaining places for point  291  /  525
# posting request
# obtained response
# []
# obtaining places for point  292  /  525
# posting request
# obtained response
# [{'id': 'ChIJL5cFpcznXEcRhiBb9JWVvt4', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bihaćka ul. 1, 31000, Osijek, Croatia', 'location': {'latitude': 45.5459925, 'longitude': 18.7010689}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Croinvest', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Bihaćka ul. 1, Osijek'}]
# obtaining places for point  293  /  525
# posting request
# obtained response
# []
# obtaining places for point  294  /  525
# posting request
# obtained response
# [{'id': 'ChIJp97-nbrnXEcRCgH0oLJq1is', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Velaluška ul. 1a, 31000, Osijek, Croatia', 'location': {'latitude': 45.543912299999995, 'longitude': 18.7125378}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić MASLAČAK', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Velaluška ul. 1a, Osijek'}]
# obtaining places for point  295  /  525
# posting request
# obtained response
# [{'id': 'ChIJmRZI137oXEcRpN6-ll2eg7c', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Srijemska ul. 124A, 31000, Osijek, Croatia', 'location': {'latitude': 45.544846799999995, 'longitude': 18.7175774}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City district South II', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Srijemska ul. 124A, Osijek'}, {'id': 'ChIJ21MWbtHnXEcRq_b51dU392Q', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Srijemska ul. 124A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5457665, 'longitude': 18.7166879}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'GRADSKA I SVEUČILIŠNA KNJIŽNICA OSIJEK', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Srijemska ul. 124A, Osijek'}]
# obtaining places for point  296  /  525
# posting request
# obtained response
# [{'id': 'ChIJLQbw19TnXEcRvUPd3ATBQ1U', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Opatijska ul. 46, 31000, Osijek, Croatia', 'location': {'latitude': 45.54470990000001, 'longitude': 18.723460199999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary School “Tin Ujević”, Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Opatijska ul. 46, Osijek'}, {'id': 'ChIJLQbw19TnXEcRL93tAAFibNg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Opatijska ul. 68A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5442269, 'longitude': 18.7212566}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DV Nevičica', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Opatijska ul. 68A, Osijek'}]
# obtaining places for point  297  /  525
# posting request
# obtained response
# []
# obtaining places for point  298  /  525
# posting request
# obtained response
# []
# obtaining places for point  299  /  525
# posting request
# obtained response
# []
# obtaining places for point  300  /  525
# posting request
# obtained response
# []
# obtaining places for point  301  /  525
# posting request
# obtained response
# []
# obtaining places for point  302  /  525
# posting request
# obtained response
# []
# obtaining places for point  303  /  525
# posting request
# obtained response
# []
# obtaining places for point  304  /  525
# posting request
# obtained response
# []
# obtaining places for point  305  /  525
# posting request
# obtained response
# []
# obtaining places for point  306  /  525
# posting request
# obtained response
# []
# obtaining places for point  307  /  525
# posting request
# obtained response
# []
# obtaining places for point  308  /  525
# posting request
# obtained response
# []
# obtaining places for point  309  /  525
# posting request
# obtained response
# []
# obtaining places for point  310  /  525
# posting request
# obtained response
# []
# obtaining places for point  311  /  525
# posting request
# obtained response
# []
# obtaining places for point  312  /  525
# posting request
# obtained response
# []
# obtaining places for point  313  /  525
# posting request
# obtained response
# []
# obtaining places for point  314  /  525
# posting request
# obtained response
# []
# obtaining places for point  315  /  525
# posting request
# obtained response
# []
# obtaining places for point  316  /  525
# posting request
# obtained response
# []
# obtaining places for point  317  /  525
# posting request
# obtained response
# []
# obtaining places for point  318  /  525
# posting request
# obtained response
# []
# obtaining places for point  319  /  525
# posting request
# obtained response
# []
# obtaining places for point  320  /  525
# posting request
# obtained response
# []
# obtaining places for point  321  /  525
# posting request
# obtained response
# []
# obtaining places for point  322  /  525
# posting request
# obtained response
# [{'id': 'ChIJ4b-8SU3mXEcR80zByZpZ2V0', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Neretvanska ul. 10, 31000, Osijek, Croatia', 'location': {'latitude': 45.5474124, 'longitude': 18.6805914}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary school Dobriše (Dobroslava) Cesarića', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Neretvanska ul. 10, Osijek'}, {'id': 'ChIJ9W3Oq7LnXEcRA2_4W4KPsQQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Savska ul. 34, 31000, Osijek, Croatia', 'location': {'latitude': 45.548606, 'longitude': 18.6817501}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'St. Joseph’s Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Savska ul. 34, Osijek'}]
# obtaining places for point  323  /  525
# posting request
# obtained response
# [{'id': 'ChIJHy2Si7LnXEcRMHPQipOnewc', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 12, 31000, Osijek, Croatia', 'location': {'latitude': 45.547458899999995, 'longitude': 18.686090099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'School of Art and Design in Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Drinska ul. 12, Osijek'}, {'id': 'ChIJDQg0L7PnXEcRSNwrKKPBP_o', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 12B, 31000, Osijek, Croatia', 'location': {'latitude': 45.547400599999996, 'longitude': 18.6853458}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Centar za odgoj i obrazovanje Ivan Štark', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Drinska ul. 12B, Osijek'}, {'id': 'ChIJDQg0L7PnXEcRqnRQfwGxvCM', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 14, 31000, Osijek, Croatia', 'location': {'latitude': 45.5486065, 'longitude': 18.685757499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary School August Šenoa', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Drinska ul. 14, Osijek'}, {'id': 'ChIJScVL1LLnXEcRe3afShf2Gfc', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 41, 31000, Osijek, Croatia', 'location': {'latitude': 45.5483037, 'longitude': 18.684142100000003}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Heidi', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Drinska ul. 41, Osijek'}, {'id': 'ChIJDQg0L7PnXEcRDXrL9CYendY', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 85, 31000, Osijek, Croatia', 'location': {'latitude': 45.5497619, 'longitude': 18.687618699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'SYGMA d.o.o.', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Drinska ul. 85, Osijek'}]
# obtaining places for point  324  /  525
# posting request
# obtained response
# [{'id': 'ChIJDQg0L7PnXEcRPAJshC9w7-0', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 16A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5493962, 'longitude': 18.688838}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Architectural-Geodetic School Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Drinska ul. 16A, Osijek'}, {'id': 'ChIJTz6sd7rnXEcRY_10SH2epdc', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 16A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5493962, 'longitude': 18.688838}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kineziološki fakultet Osijek', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Drinska ul. 16A, Osijek'}, {'id': 'ChIJ74NifQDnXEcReMbPJO_7sCk', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drinska ul. 16A, 31000, Osijek, Croatia', 'location': {'latitude': 45.5493962, 'longitude': 18.688838}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'EDVIN ŠIPTAR', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Drinska ul. 16A, Osijek'}]
# obtaining places for point  325  /  525
# posting request
# obtained response
# [{'id': 'ChIJC8aw4dPnXEcRRhARFkOPng4', 'types': ['preschool', 'school', 'child_care_agency', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Woodrowa Wilsona 35, 31000, Osijek, Croatia', 'location': {'latitude': 45.546833, 'longitude': 18.6963407}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DV EciPeciPec', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Ul. Woodrowa Wilsona 35, Osijek'}]
# obtaining places for point  326  /  525
# posting request
# obtained response
# []
# obtaining places for point  327  /  525
# posting request
# obtained response
# [{'id': 'ChIJcY5og83nXEcR20IwMbp5qAM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. kralja Petra Svačića 36a, 31000, Osijek, Croatia', 'location': {'latitude': 45.5470567, 'longitude': 18.706556}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kosjenka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. kralja Petra Svačića 36a, Osijek'}, {'id': 'ChIJk631vc3nXEcR2fun_IbRJ5M', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. kralja Petra Svačića 36, 31000, Osijek, Croatia', 'location': {'latitude': 45.5475607, 'longitude': 18.706626399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Šokačka grana - Osijek', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Ul. kralja Petra Svačića 36, Osijek'}]
# obtaining places for point  328  /  525
# posting request
# obtained response
# [{'id': 'ChIJp4fT19PnXEcRhH7lrUcG4Ng', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korčulanska ul. 1, 31000, Osijek, Croatia', 'location': {'latitude': 45.5477389, 'longitude': 18.7130475}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary school "Grigor Vitez" Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Korčulanska ul. 1, Osijek'}, {'id': 'ChIJp4fT19PnXEcRmcQDoVdn1vk', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Osječka 55, 31204, Sarvaš, Croatia', 'location': {'latitude': 45.5477504, 'longitude': 18.7118833}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'kindergarten "Ribica"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Osječka 55, Sarvaš'}, {'id': 'ChIJteclAwDnXEcRbp5kR71C020', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bosutska ul 5, 31000, Osijek, Croatia', 'location': {'latitude': 45.548684099999996, 'longitude': 18.7098777}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'od majmunčića zgrada', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Bosutska ul 5, Osijek'}, {'id': 'ChIJ8VLGbADnXEcR166GkM9u8D4', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bračka 138A, 31000, Osijek, Croatia', 'location': {'latitude': 45.549546299999996, 'longitude': 18.7100346}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Majmunčić br.1', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Bračka 138A, Osijek'}]
# obtaining places for point  329  /  525
# posting request
# obtained response
# [{'id': 'ChIJR8ztYVrnXEcRS6voco92-Tk', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bakarska ul. 1, 31000, Osijek, Croatia', 'location': {'latitude': 45.547052, 'longitude': 18.714230200000003}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Marija Petković', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Bakarska ul. 1, Osijek'}]
# obtaining places for point  330  /  525
# posting request
# obtained response
# []
# obtaining places for point  331  /  525
# posting request
# obtained response
# []
# obtaining places for point  332  /  525
# posting request
# obtained response
# []
# obtaining places for point  333  /  525
# posting request
# obtained response
# []
# obtaining places for point  334  /  525
# posting request
# obtained response
# []
# obtaining places for point  335  /  525
# posting request
# obtained response
# []
# obtaining places for point  336  /  525
# posting request
# obtained response
# []
# obtaining places for point  337  /  525
# posting request
# obtained response
# []
# obtaining places for point  338  /  525
# posting request
# obtained response
# []
# obtaining places for point  339  /  525
# posting request
# obtained response
# []
# obtaining places for point  340  /  525
# posting request
# obtained response
# []
# obtaining places for point  341  /  525
# posting request
# obtained response
# []
# obtaining places for point  342  /  525
# posting request
# obtained response
# []
# obtaining places for point  343  /  525
# posting request
# obtained response
# []
# obtaining places for point  344  /  525
# posting request
# obtained response
# []
# obtaining places for point  345  /  525
# posting request
# obtained response
# []
# obtaining places for point  346  /  525
# posting request
# obtained response
# []
# obtaining places for point  347  /  525
# posting request
# obtained response
# []
# obtaining places for point  348  /  525
# posting request
# obtained response
# []
# obtaining places for point  349  /  525
# posting request
# obtained response
# []
# obtaining places for point  350  /  525
# posting request
# obtained response
# []
# obtaining places for point  351  /  525
# posting request
# obtained response
# []
# obtaining places for point  352  /  525
# posting request
# obtained response
# []
# obtaining places for point  353  /  525
# posting request
# obtained response
# []
# ...
# obtaining places for point  441  /  525
# posting request
# obtained response
# [{'id': 'ChIJvSS8rQ_nXEcRND8bdkLmdS4', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Vijenac Augusta Cesarca 36, 31000, Osijek, Croatia', 'location': {'latitude': 45.562823599999994, 'longitude': 18.6673203}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary school Vladimir Becic Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Ul. Vijenac Augusta Cesarca 36, Osijek'}, {'id': 'ChIJMzPjqA_nXEcRUIkyoSVDCQ8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Vijenac Augusta Cesarca 37, 31000, Osijek, Croatia', 'location': {'latitude': 45.5628745, 'longitude': 18.6660195}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji Vrtić Latica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Vijenac Augusta Cesarca 37, Osijek'}, {'id': 'ChIJu3PNz4PnXEcRIflwHMM-etg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Ante Paradžika 3, 31000, Osijek, Croatia', 'location': {'latitude': 45.5634735, 'longitude': 18.663989}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječiji vrtić Mali Princ - Osijek Paradžika', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Ante Paradžika 3, Osijek'}]
# obtaining places for point  442  /  525
# posting request
# obtained response
# [{'id': 'ChIJv-I-tA7nXEcR0zA9H99Oqec', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Josipa Jurja Strossmayera, 31000, Osijek, Croatia', 'location': {'latitude': 45.563998399999996, 'longitude': 18.670234699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Saint Roch’s Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Josipa Jurja Strossmayera, Osijek'}, {'id': 'ChIJeyfXo97nXEcRRgcWS-1Vpns', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Josipa Jurja Strossmayera 35, 31000, Osijek, Croatia', 'location': {'latitude': 45.563035199999995, 'longitude': 18.6725708}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Snjeguljica', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Josipa Jurja Strossmayera 35, Osijek'}]
# obtaining places for point  443  /  525
# posting request
# obtained response
# [{'id': 'ChIJcRPfaEfnXEcRwtarnR6xyUQ', 'types': ['courthouse', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Ante Starčevića 7, 31000, Osijek, Croatia', 'location': {'latitude': 45.5617825, 'longitude': 18.6764057}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Upravni sud u Osijeku', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Trg Ante Starčevića 7, Osijek'}, {'id': 'ChIJQZHep_7nXEcRgtsQUWs78Is', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Županijska 1, Ul. Josipa Jurja Strossmayera 17, 31000, Osijek, Croatia', 'location': {'latitude': 45.562005, 'longitude': 18.676061000000004}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'LICHTE - Center for instructions', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Županijska 1, Ul. Josipa Jurja Strossmayera 17, Osijek'}, {'id': 'ChIJ_cugIiznXEcRqAPsk-67dt4', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gornjodravska obala 88, 31000, Osijek, Croatia', 'location': {'latitude': 45.5630108, 'longitude': 18.6745215}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Apartman Bruna', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Gornjodravska obala 88, Osijek'}, {'id': 'ChIJDRn58yjnXEcRBbgoEd6XC-I', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šetalište kardinala Franje Šepera 13/IV, 31000, Osijek, Croatia', 'location': {'latitude': 45.5627193, 'longitude': 18.6773025}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Veleučilište Baltazar Zaprešić - Osijek', 'languageCode': 'en'}, 'shortFormattedAddress': 'Šetalište kardinala Franje Šepera 13/IV, Osijek'}]
# obtaining places for point  444  /  525
# posting request
# obtained response
# []
# obtaining places for point  445  /  525
# posting request
# obtained response
# [{'id': 'ChIJBQaniqPnXEcRWr7aAdd4iwE', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šetalište kardinala Franje Šepera 1, 31000, Osijek, Croatia', 'location': {'latitude': 45.5624884, 'longitude': 18.6852038}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bridge Bench', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Perivoj kralja Tomislava, Šetalište kardinala Franje Šepera 1, Osijek'}]
# obtaining places for point  446  /  525
# posting request
# obtained response
# []
# obtaining places for point  447  /  525
# posting request
# obtained response
# [{'id': 'ChIJyzj0p77nXEcRmeLwPHqUf8E', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Vatroslava Lisinskog 1, 31000, Osijek, Croatia', 'location': {'latitude': 45.5618811, 'longitude': 18.6956672}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Isusovačka klasična gimnazija Osijek', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Trg Vatroslava Lisinskog 1, Osijek'}]
# obtaining places for point  448  /  525
# posting request
# obtained response
# [{'id': 'ChIJiamfIr7nXEcREA2jcar2eug', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Tvrđavica 263, 31000, Osijek, Croatia', 'location': {'latitude': 45.5643104, 'longitude': 18.7005034}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Catacombs Osijek', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Tvrđavica 263, Osijek'}]
# obtaining places for point  449  /  525
# posting request
# obtained response
# []
# obtaining places for point  450  /  525
# posting request
# obtained response
# [{'id': 'ChIJe6c09unnXEcRBR2QlQE2He0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Princa Eugena Savojskog 4, 31000, Podravlje, Croatia', 'location': {'latitude': 45.563510099999995, 'longitude': 18.713408}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'CENTAR ZA PREDŠKOLSKI ODGOJ OSIJEK', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Princa Eugena Savojskog 4, Podravlje'}]
# obtaining places for point  451  /  525
# posting request
# obtained response
# []
# obtaining places for point  452  /  525
# posting request
# obtained response
# []
# obtaining places for point  453  /  525
# posting request
# obtained response
# []
# obtaining places for point  454  /  525
# posting request
# obtained response
# []
# obtaining places for point  455  /  525
# posting request
# obtained response
# []
# obtaining places for point  456  /  525
# posting request
# obtained response
# []
# obtaining places for point  457  /  525
# posting request
# obtained response
# []
# obtaining places for point  458  /  525
# posting request
# obtained response
# []
# obtaining places for point  459  /  525
# posting request
# obtained response
# []
# obtaining places for point  460  /  525
# posting request
# obtained response
# []
# obtaining places for point  461  /  525
# posting request
# obtained response
# []
# obtaining places for point  462  /  525
# posting request
# obtained response
# []
# obtaining places for point  463  /  525
# posting request
# obtained response
# [{'id': 'ChIJYf0AAgDnXEcRwyF1akjYcqY', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Šandora Petofia, 31000, Osijek, Croatia', 'location': {'latitude': 45.569191100000005, 'longitude': 18.639768099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Spomenik Mihaela Topalića', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Ul. Šandora Petofia, Osijek'}]
# obtaining places for point  464  /  525
# posting request
# obtained response
# [{'id': 'ChIJxbIAr_LnXEcRxhu7dqIoe7Q', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Bele Bartoka 55a, 31000, Osijek, Croatia', 'location': {'latitude': 45.5664588, 'longitude': 18.6458628}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Jelenko', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Bele Bartoka 55a, Osijek'}]
# obtaining places for point  465  /  525
# posting request
# obtained response
# [{'id': 'ChIJpTUJvY3lXEcR3QEOPqqhtIo', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Šandora Petofia 76, 31000, Osijek, Croatia', 'location': {'latitude': 45.568044699999994, 'longitude': 18.6489607}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Népkör – Hungarian Cultural Society', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Ul. Šandora Petofia 76, Osijek'}]
# obtaining places for point  466  /  525
# posting request
# obtained response
# []
# obtaining places for point  467  /  525
# posting request
# obtained response
# []
# obtaining places for point  468  /  525
# posting request
# obtained response
# []
# obtaining places for point  469  /  525
# posting request
# obtained response
# []
# obtaining places for point  470  /  525
# posting request
# obtained response
# []
# obtaining places for point  471  /  525
# posting request
# obtained response
# []
# obtaining places for point  472  /  525
# posting request
# obtained response
# []
# obtaining places for point  473  /  525
# posting request
# obtained response
# []
# obtaining places for point  474  /  525
# posting request
# obtained response
# []
# obtaining places for point  475  /  525
# posting request
# obtained response
# [{'id': 'ChIJEbHTdOjnXEcRG04ZOtiIdak', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '31000, Osijek, Croatia', 'location': {'latitude': 45.564997, 'longitude': 18.7008451}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of the Queen of Peace', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Osijek'}]
# obtaining places for point  476  /  525
# posting request
# obtained response
# []
# obtaining places for point  477  /  525
# posting request
# obtained response
# []
# obtaining places for point  478  /  525
# posting request
# obtained response
# []
# obtaining places for point  479  /  525
# posting request
# obtained response
# []
# obtaining places for point  480  /  525
# posting request
# obtained response
# []
# obtaining places for point  481  /  525
# posting request
# obtained response
# []
# obtaining places for point  482  /  525
# posting request
# obtained response
# []
# obtaining places for point  483  /  525
# posting request
# obtained response
# []
# obtaining places for point  484  /  525
# posting request
# obtained response
# []
# obtaining places for point  485  /  525
# posting request
# obtained response
# []
# obtaining places for point  486  /  525
# posting request
# obtained response
# []
# obtaining places for point  487  /  525
# posting request
# obtained response
# []
# obtaining places for point  488  /  525
# posting request
# obtained response
# []
# obtaining places for point  489  /  525
# posting request
# obtained response
# []
# obtaining places for point  490  /  525
# posting request
# obtained response
# []
# obtaining places for point  491  /  525
# posting request
# obtained response
# []
# obtaining places for point  492  /  525
# posting request
# obtained response
# []
# obtaining places for point  493  /  525
# posting request
# obtained response
# []
# obtaining places for point  494  /  525
# posting request
# obtained response
# []
# obtaining places for point  495  /  525
# posting request
# obtained response
# []
# obtaining places for point  496  /  525
# posting request
# obtained response
# []
# obtaining places for point  497  /  525
# posting request
# obtained response
# []
# obtaining places for point  498  /  525
# posting request
# obtained response
# []
# obtaining places for point  499  /  525
# posting request
# obtained response
# []
# obtaining places for point  500  /  525
# posting request
# obtained response
# []
# obtaining places for point  501  /  525
# posting request
# obtained response
# []
# obtaining places for point  502  /  525
# posting request
# obtained response
# []
# obtaining places for point  503  /  525
# posting request
# obtained response
# []
# obtaining places for point  504  /  525
# posting request
# obtained response
# []
# obtaining places for point  505  /  525
# posting request
# obtained response
# []
# obtaining places for point  506  /  525
# posting request
# obtained response
# []
# obtaining places for point  507  /  525
# posting request
# obtained response
# []
# obtaining places for point  508  /  525
# posting request
# obtained response
# []
# obtaining places for point  509  /  525
# posting request
# obtained response
# []
# obtaining places for point  510  /  525
# posting request
# obtained response
# []
# obtaining places for point  511  /  525
# posting request
# obtained response
# []
# obtaining places for point  512  /  525
# posting request
# obtained response
# []
# obtaining places for point  513  /  525
# posting request
# obtained response
# []
# obtaining places for point  514  /  525
# posting request
# obtained response
# []
# obtaining places for point  515  /  525
# posting request
# obtained response
# []
# obtaining places for point  516  /  525
# posting request
# obtained response
# []
# obtaining places for point  517  /  525
# posting request
# obtained response
# []
# obtaining places for point  518  /  525
# posting request
# obtained response
# []
# obtaining places for point  519  /  525
# posting request
# obtained response
# []
# obtaining places for point  520  /  525
# posting request
# obtained response
# []
# obtaining places for point  521  /  525
# posting request
# obtained response
# []
# obtaining places for point  522  /  525
# posting request
# obtained response
# []
# obtaining places for point  523  /  525
# posting request
# obtained response
# []
# obtaining places for point  524  /  525
# posting request
# obtained response
# []

# %%
# ensure no points which reached the 20-place cutoff from Google
idxs_of_problem_spots = [i for i, pt in enumerate(points_lst) if len(list(pt.values())[0]) > 19]
idxs_of_problem_spots
# Out:
# []

# %%
city_gdf = clean_maps_api_output(points_lst)

city_gdf.to_file("/mnt/c/Users/natra/Documents/Research/Identity-Conflict/croatia_files/clean/osijek_locs_400x400.geojson",
                          driver='GeoJSON')
# Out:
# Number of place dictionaries returned from API:  70
# Shape of resulting dataframe:  (184, 13)
# Shape of dataframe after dropping dups:  (184, 13)

# %% [markdown]
# ### Rijeka

# %%
# created grid in as 400 x 400 w x h grids with Fishnet tool in ArcGIS Pro
grid = gpd.read_file('./croatia_files/raw/site_locations/rijeka-fishnet-clip-4326.shp')
print(grid.shape)
print(grid.crs)
grid.head()
# Out:
# (340, 2)
# EPSG:4326
#    Id                   geometry
# 0   0  POINT (14.53001 45.30597)
# 1   0  POINT (14.53511 45.30606)
# 2   0   POINT (14.51969 45.3094)
# 3   0  POINT (14.52479 45.30948)
# 4   0  POINT (14.52989 45.30957)

# %%
points_lst = obtain_places_from_points(url, headers, grid, 200)
# Out:
# obtaining places for point  0  /  340
# posting request
# obtained response
# []
# obtaining places for point  1  /  340
# posting request
# obtained response
# [{'id': 'ChIJw4KMjwOfZEcRrsIEbR4nRt4', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Primorje ul. 39, 51222, Bakar, Croatia', 'location': {'latitude': 45.3053059, 'longitude': 14.534917000000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Matija Mažić Community Centre', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Primorje ul. 39, Bakar'}, {'id': 'ChIJ1agoXaOfZEcRcAesr6p4Vro', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '51222, Bakar, Croatia', 'location': {'latitude': 45.3073754, 'longitude': 14.533659900000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'St. Andrew’s Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Bakar'}, {'id': 'ChIJAQmdqKSfZEcRYOpVWVeSaBg', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '51222, Bakar, Croatia', 'location': {'latitude': 45.3069789, 'longitude': 14.5339425}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Turkish House', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Bakar'}, {'id': 'ChIJIdgPrNqfZEcRZrD7INQHbig', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Primorje ul. 50, 51222, Bakar, Croatia', 'location': {'latitude': 45.306276600000004, 'longitude': 14.535404100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Perilo', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Primorje ul. 50, Bakar'}, {'id': 'ChIJO5rHqB33YUcRVrDsAq1nUpc', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Primorje ul. 39, 51222, Bakar, Croatia', 'location': {'latitude': 45.3056883, 'longitude': 14.535313499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Town Bakar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': 'Primorje ul. 39, Bakar'}, {'id': 'ChIJvRF8F4GfZEcRIz_wXCVnpWk', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '51222, Bakar, Croatia', 'location': {'latitude': 45.3068307, 'longitude': 14.5345607}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kamene mjere', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Bakar'}, {'id': 'ChIJO5rHqB33YUcR__TBc6L-hxM', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Primorje ul. 39, 51222, Bakar, Croatia', 'location': {'latitude': 45.3056681, 'longitude': 14.5351638}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'URED DRŽAVNE UPRAVE U PRIMORSKO-GORANSKOJ ŽUPANIJI', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Primorje ul. 39, Bakar'}, {'id': 'ChIJxRLDN7ufZEcRfaGQpcZc8sA', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Primorje ul. 45/A, 51222, Bakar, Croatia', 'location': {'latitude': 45.305684199999995, 'longitude': 14.5349899}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska knjižnica Bakar', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'t ...
# obtaining places for point  2  /  340
# posting request
# obtained response
# []
# obtaining places for point  3  /  340
# posting request
# obtained response
# []
# obtaining places for point  4  /  340
# posting request
# obtained response
# []
# obtaining places for point  5  /  340
# posting request
# obtained response
# [{'id': 'ChIJlY72YaOfZEcRCqdqye0Rz5c', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Lokaj ul., 51222, Bakar, Croatia', 'location': {'latitude': 45.308162100000004, 'longitude': 14.535123599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bakar Elementary School', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Lokaj ul., Bakar'}]
# obtaining places for point  6  /  340
# posting request
# obtained response
# [{'id': 'ChIJE91M3EWgZEcRDKfAePDdmcY', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pećine ul. 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3131379, 'longitude': 14.472311}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Villa Ružić', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Pećine ul. 5, Rijeka'}, {'id': 'ChIJ21N5LJuhZEcRST-WjyEiT0A', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '8F7G+85P, 51000, Rijeka, Croatia', 'location': {'latitude': 45.313337499999996, 'longitude': 14.475453099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Spomen Prijateljstva grada Kawasakija gradu Rijeci', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': '8F7G+85P, Rijeka'}]
# obtaining places for point  7  /  340
# posting request
# obtained response
# []
# obtaining places for point  8  /  340
# posting request
# obtained response
# []
# obtaining places for point  9  /  340
# posting request
# obtained response
# []
# obtaining places for point  10  /  340
# posting request
# obtained response
# []
# obtaining places for point  11  /  340
# posting request
# obtained response
# []
# obtaining places for point  12  /  340
# posting request
# obtained response
# [{'id': 'ChIJvywF_8efZEcRut71HkNO3uM', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sveti Kuzam 22, 51222, Sveti Kuzam, Croatia', 'location': {'latitude': 45.312366999999995, 'longitude': 14.523733100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Cosmas and Damian', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Sveti Kuzam 22, Sveti Kuzam'}]
# obtaining places for point  13  /  340
# posting request
# obtained response
# []
# obtaining places for point  14  /  340
# posting request
# obtained response
# []
# obtaining places for point  15  /  340
# posting request
# obtained response
# [{'id': 'ChIJu2GKxE-gZEcRKky_-BeGi5g', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šetalište XIII divizije 101, 51000, Rijeka, Croatia', 'location': {'latitude': 45.316387899999995, 'longitude': 14.469239499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Holy Family Parish', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Šetalište XIII divizije 101, Rijeka'}, {'id': 'ChIJUX7nxf2gZEcRryo51wKk_x0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šetalište XIII divizije 68, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3165622, 'longitude': 14.4683725}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola Andrije Ljudevita Adamića', 'languageCode': 'bs'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Šetalište XIII divizije 68, Rijeka'}]
# obtaining places for point  16  /  340
# posting request
# obtained response
# [{'id': 'ChIJOYfGp0-gZEcR03SkxvmIco0', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Radnička ul. 33, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3164296, 'longitude': 14.4715401}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Department Of Motor Vehicles Pećine', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Radnička ul. 33, Rijeka'}, {'id': 'ChIJoVTyokigZEcRuLMxet4TiB8', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Spinčićeva ul. 2, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3145883, 'longitude': 14.475101200000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Dvorana kulture 'JUSŽ'", 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Spinčićeva ul. 2, Rijeka'}, {'id': 'ChIJV24rck-gZEcRbUIkac-w0dQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Janka Polića Kamova 103, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3148651, 'longitude': 14.473156899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Jehovah's Witness Kingdom Hall", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Janka Polića Kamova 103, Rijeka'}]
# obtaining places for point  17  /  340
# posting request
# obtained response
# [{'id': 'ChIJEyPl-L2hZEcR_iiuqhfPhkk', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Braće Pavlinića 30, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3163255, 'longitude': 14.478865899999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bunker "Vežica 2"', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Ul. Braće Pavlinića 30, Rijeka'}, {'id': 'ChIJ1301IAChZEcRIRGHnr8PCXI', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Braće Pavlinića 30, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3162444, 'longitude': 14.478893200000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Čuvari grada na Rječini 1.', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Ul. Braće Pavlinića 30, Rijeka'}]
# obtaining places for point  18  /  340
# posting request
# obtained response
# []
# obtaining places for point  19  /  340
# posting request
# obtained response
# [{'id': 'ChIJa_Ixo4ihZEcRKxDd8TqQR6s', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Glavani, 51221, Kostrena, Croatia', 'location': {'latitude': 45.317614899999995, 'longitude': 14.4952779}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pretpovijesna gradina Solin', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Kostrena'}]
# obtaining places for point  20  /  340
# posting request
# obtained response
# []
# obtaining places for point  21  /  340
# posting request
# obtained response
# []
# obtaining places for point  22  /  340
# posting request
# obtained response
# []
# obtaining places for point  23  /  340
# posting request
# obtained response
# []
# obtaining places for point  24  /  340
# posting request
# obtained response
# []
# obtaining places for point  25  /  340
# posting request
# obtained response
# []
# obtaining places for point  26  /  340
# posting request
# obtained response
# [{'id': 'ChIJj3cA8-afZEcREkGQO7rVWPo', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '51223, Škrljevo, Croatia', 'location': {'latitude': 45.3168783, 'longitude': 14.5271692}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Škrljevo'}]
# obtaining places for point  27  /  340
# posting request
# obtained response
# []
# obtaining places for point  28  /  340
# posting request
# obtained response
# [{'id': 'ChIJi7GUVVGgZEcR2zr6cwmqPkk', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Janka Polića Kamova 17, 51000, Rijeka, Croatia', 'location': {'latitude': 45.320555899999995, 'longitude': 14.463538899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Technology and Innovation Center', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Ul. Janka Polića Kamova 17, Rijeka'}, {'id': 'ChIJAZyCbVGgZEcR5HncoAe7HZk', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Janka Polića Kamova 58, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3191369, 'longitude': 14.465423699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Sušak - PPO Veseljko', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Janka Polića Kamova 58, Rijeka'}]
# obtaining places for point  29  /  340
# posting request
# obtained response
# [{'id': 'ChIJhWhuDlKgZEcR35HhOBSYook', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kvaternikova ul. 37, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3204893, 'longitude': 14.4695568}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Sušak - PPO Vežica', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Kvaternikova ul. 37, Rijeka'}, {'id': 'ChIJX1v4XwChZEcRh9NZRcU23Pk', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kvaternikova ul. 30, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3202449, 'longitude': 14.4700653}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Partizan', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Kvaternikova ul. 30, Rijeka'}, {'id': 'ChIJCY7rM0ChZEcR6d5kyJic238', 'types': ['performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Drage Gervaisa 64, 51000, Rijeka, Croatia', 'location': {'latitude': 45.318456399999995, 'longitude': 14.470263699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kazališni studio', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Performing Arts Theater', 'languageCode': 'en-US'}, 'primaryType': 'performing_arts_theater', 'shortFormattedAddress': 'Ul. Drage Gervaisa 64, Rijeka'}]
# obtaining places for point  30  /  340
# posting request
# obtained response
# [{'id': 'ChIJ56ROS0ygZEcR0wHhUYzazQk', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kvaternikova ul. 60, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3205553, 'longitude': 14.473819500000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Sušak, PPO Galeb', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Kvaternikova ul. 60, Rijeka'}]
# obtaining places for point  31  /  340
# posting request
# obtained response
# []
# obtaining places for point  32  /  340
# posting request
# obtained response
# [{'id': 'ChIJhUf5fOmhZEcRwKMHjjL1jwo', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. dr. Zdravka Kučića 62, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3190526, 'longitude': 14.481690499999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bunker "Vežica 1"', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Ul. dr. Zdravka Kučića 62, Rijeka'}]
# obtaining places for point  33  /  340
# posting request
# obtained response
# []
# obtaining places for point  34  /  340
# posting request
# obtained response
# []
# obtaining places for point  35  /  340
# posting request
# obtained response
# []
# obtaining places for point  36  /  340
# posting request
# obtained response
# [{'id': 'ChIJgeVyzXShZEcR_X7-bz7fjkQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Brig ul., 51000, Rijeka, Croatia', 'location': {'latitude': 45.3193146, 'longitude': 14.504545499999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. James', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Brig ul., Rijeka'}]
# obtaining places for point  37  /  340
# posting request
# obtained response
# []
# obtaining places for point  38  /  340
# posting request
# obtained response
# []
# obtaining places for point  39  /  340
# posting request
# obtained response
# []
# obtaining places for point  40  /  340
# posting request
# obtained response
# [{'id': 'ChIJs9mdJ5ihZEcRaqYEt6vl4V0', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Matačićeva ul. 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.323639799999995, 'longitude': 14.44358}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'MKD Ilinden', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Matačićeva ul. 5, Rijeka'}]
# obtaining places for point  41  /  340
# posting request
# obtained response
# [{'id': 'ChIJN5UeE8OhZEcR0jIokmeXY-Q', 'types': ['performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Delta 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3234141, 'longitude': 14.448143400000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DRAM(M)A CENTAR ZAJC', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Performing Arts Theater', 'languageCode': 'en-US'}, 'primaryType': 'performing_arts_theater', 'shortFormattedAddress': 'Delta 5, Rijeka'}]
# obtaining places for point  42  /  340
# posting request
# obtained response
# []
# obtaining places for point  43  /  340
# posting request
# obtained response
# [{'id': 'ChIJP1Fsnx6hZEcRD3qSi6XANN0', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stube Trinaestorice strijeljanih, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3236946, 'longitude': 14.4561139}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'SPOMEN ŽRTAVA FAŠIZMA', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Stube Trinaestorice strijeljanih, Rijeka'}]
# obtaining places for point  44  /  340
# posting request
# obtained response
# []
# obtaining places for point  45  /  340
# posting request
# obtained response
# [{'id': 'ChIJG-u0Oo6hZEcRVXqcunpXdVw', 'types': ['hospital', 'point_of_interest', 'health', 'establishment'], 'formattedAddress': 'Tihovac ul. 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3215156, 'longitude': 14.4684321}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'SANTETSKI PRIJEVOZ NEPOKRETNIH I TESKO POKRETNIH ,AMBULANTNI PRJEVOZ PRIJEVOZ INVALIDA', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Tihovac ul. 10, Rijeka'}]
# obtaining places for point  46  /  340
# posting request
# obtained response
# []
# obtaining places for point  47  /  340
# posting request
# obtained response
# [{'id': 'ChIJX6ADQLOhZEcRqiSrfNt0Nb0', 'types': ['primary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Gornja Vežica 31, 51000, Rijeka, Croatia', 'location': {'latitude': 45.324599899999996, 'longitude': 14.4772188}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary & Middle School Gornja Vežica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Gornja Vežica 31, Rijeka'}, {'id': 'ChIJvxdstbShZEcRmOBXF4HXTBA', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Franje Belulovića 8, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3232137, 'longitude': 14.4795326}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'TEEN, VL. GRACIJELA OROBABIĆ', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Franje Belulovića 8, Rijeka'}]
# obtaining places for point  48  /  340
# posting request
# obtained response
# [{'id': 'ChIJC_a0nsqhZEcRN8hJEXaPlcQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sveti Križ 38A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.323805799999995, 'longitude': 14.485194199999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of the Holy Cross', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Sveti Križ 38A, Rijeka'}]
# obtaining places for point  49  /  340
# posting request
# obtained response
# []
# obtaining places for point  50  /  340
# posting request
# obtained response
# [{'id': 'ChIJhfzwqc2hZEcRfUWqifj5_tU', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Orlići ul. 13A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.323578999999995, 'longitude': 14.494752699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Anthony', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Orlići ul. 13A, Rijeka'}]
# obtaining places for point  51  /  340
# posting request
# obtained response
# [{'id': 'ChIJQd_61rGhZEcRrVXfjH33czQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Brig ul. 16, 51000, Rijeka, Croatia', 'location': {'latitude': 45.322389199999996, 'longitude': 14.4971567}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Brig ul. 16, Rijeka'}]
# obtaining places for point  52  /  340
# posting request
# obtained response
# []
# obtaining places for point  53  /  340
# posting request
# obtained response
# [{'id': 'ChIJmdLLZQChZEcRGT0DWSwvI1A', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': '8GF6+M7, 51227, Kukuljanovo, Croatia', 'location': {'latitude': 45.3242162, 'longitude': 14.510658900000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rotor', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': '8GF6+M7, Kukuljanovo'}]
# obtaining places for point  54  /  340
# posting request
# obtained response
# []
# obtaining places for point  55  /  340
# posting request
# obtained response
# [{'id': 'ChIJwUEkzfGhZEcRnefRMtpCYXU', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '51000, Rijeka, Croatia', 'location': {'latitude': 45.3243874, 'longitude': 14.433001200000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rijeka Cranes', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Rijeka'}, {'id': 'ChIJBXsHHgChZEcRu09vjcICHss', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': '51000, Croatia', 'location': {'latitude': 45.324535499999996, 'longitude': 14.433053699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Nave museo Galeb', 'languageCode': 'it'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum'}]
# obtaining places for point  56  /  340
# posting request
# obtained response
# [{'id': 'ChIJ5fESteGgZEcRInr66sE_0tc', 'types': ['police', 'point_of_interest', 'establishment'], 'formattedAddress': 'Riva 16, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3272829, 'longitude': 14.4385585}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Maritime Police Station - City Of Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Police', 'languageCode': 'en-US'}, 'primaryType': 'police', 'shortFormattedAddress': 'Riva 16, Rijeka'}, {'id': 'ChIJHUG6M-CgZEcRGGpXzmhgX7U', 'types': ['courthouse', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zadarska ul. 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3275535, 'longitude': 14.438133599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Trgovački sud u Rijeci', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Zadarska ul. 3, Rijeka'}, {'id': 'ChIJ1UOhNuCgZEcRqdES_-yjAxo', 'types': ['local_government_office', 'government_office', 'finance', 'consultant', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zadarska ul. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3276213, 'longitude': 14.437739899999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zemljišnoknjižni odjel Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Zadarska ul. 1, Rijeka'}, {'id': 'ChIJsVrV8GuhZEcRejp95mppnTQ', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Riva 16, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3272829, 'longitude': 14.4385585}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Palača Jadran', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Riva 16, Rijeka'}, {'id': 'ChIJzSR8IEWhZEcRE1DzyWj_vNc', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Riva 20, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3275375, 'longitude': 14.4376962}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Parallel', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Riva 20, Rijeka'}]
# obtaining places for point  57  /  340
# posting request
# obtained response
# [{'id': 'ChIJOey1QeKgZEcRIcnpatZ9WVk', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Ivana Koblera 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3266667, 'longitude': 14.443055599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Clock Tower', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trg Ivana Koblera 1, Rijeka'}, {'id': 'ChIJ9z2ddmmhZEcRZQX_L2XOUoI', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Ivana Koblera 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3270239, 'longitude': 14.4436369}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Old Town Hall', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trg Ivana Koblera 4, Rijeka'}, {'id': 'ChIJbRuc-OGgZEcRE6wanKxOuNQ', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327624, 'longitude': 14.441770499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Visoka poslovna škola PAR', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Trg Riječke rezolucije 4, Rijeka'}, {'id': 'ChIJsVXCb-KgZEcRZ5YB20-qNSE', 'types': ['monument', 'historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Stara Vrata 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3272365, 'longitude': 14.443667699999999}, 'businessStatus': 'CLOSED_TEMPORARILY', 'displayName': {'text': 'Old Roman Arch', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Monument', 'languageCode': 'en-US'}, 'primaryType': 'monument', 'shortFormattedAddress': 'Ul. Stara Vrata 3, Rijeka'}, {'id': 'ChIJu2omGOKgZEcRKgD_YIyoNxA', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 16, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3269131, 'longitude': 14.442420199999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Hall Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': 'Korzo 16, Rijeka'}, {'id': 'ChIJGZyGAuKgZEcRs3UGZAWqAeM', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3273295, 'longitude': 14.4421117}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Jerome', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg Riječke rezolucije, Rijeka'}, {'id': 'ChIJRdRW5D-hZEcR5WjHBJ6Mp7g', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Riva 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3266397, 'longitude': 14.440157500000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Matični ured Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Riva 10, Rijeka'}, {'id': 'ChIJX4bPri6hZEcRqt3xGMZ_Kao', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'palača Modello, Bačvarska ul., 51000, Rijeka, Croatia', 'location': {'lati ...
# obtaining places for point  58  /  340
# posting request
# obtained response
# [{'id': 'ChIJ8Y2so-KgZEcRU0rbQxL7k60', 'types': ['hospital', 'point_of_interest', 'health', 'establishment'], 'formattedAddress': 'Agatićeva ul. 8, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327198499999994, 'longitude': 14.4468397}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Specialty hospital MEDICO', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Agatićeva ul. 8, Rijeka'}, {'id': 'ChIJ78j1k-KgZEcRt6xaLyGbbVU', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Pavla Rittera Vitezovića 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3265411, 'longitude': 14.4456378}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of the Assumption of Blessed Virgin Mary', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Pavla Rittera Vitezovića 3, Rijeka'}, {'id': 'ChIJpZYtCf2gZEcRLS1VQxmWT4I', 'types': ['secondary_school', 'school', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Podhumskih žrtava 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325459699999996, 'longitude': 14.449783199999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Construction Technical High School Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Ul. Podhumskih žrtava 4, Rijeka'}, {'id': 'ChIJ5XQfjeKgZEcR5A6CoVM7yAc', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Užarska ul. 15, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326596200000004, 'longitude': 14.445500700000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Leaning Tower', 'languageCode': 'hu'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Užarska ul. 15, Rijeka'}, {'id': 'ChIJ70ixcv2gZEcRLkwLvSYVF2Q', 'types': ['primary_school', 'school', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Podhumskih žrtava 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325784899999995, 'longitude': 14.449749399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Primary School Center', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Ul. Podhumskih žrtava 5, Rijeka'}, {'id': 'ChIJBzy5r-KgZEcRLgcl1Xi52Nc', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Fiumara ul. 13 / 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3266389, 'longitude': 14.4468486}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Driving School VLAMAL d.o.o.', 'languageCode': 'en'}, 'shortFormattedAddress': 'Fiumara ul. 13 / 1, Rijeka'}, {'id': 'ChIJzd-k7OKgZEcRvR31Wr789Ro', 'types': ['courthouse', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Užarska ul. 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3262968, 'longitude': 14.445451499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Magistrates Court In Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Užarska ul. 3, Rijeka'}, {'id': 'ChIJG__aDv2gZEcRCMZQlaDN6ZY', 'types': ['secondary_school', 'school', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Podhumskih žrtava 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.32533780000001, 'longitude': 14.4497889}, 'businessStatus': 'OPERATIONAL', ...
# obtaining places for point  59  /  340
# posting request
# obtained response
# [{'id': 'ChIJD5vcdKuhZEcR9LPqSvjASJA', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg braće Mažuranića 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3256265, 'longitude': 14.454109200000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sveučilište u Rijeci', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Trg braće Mažuranića 10, Rijeka'}, {'id': 'ChIJFzxuvf2gZEcRWGpmbmrhNcU', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Strossmayerova 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3253261, 'longitude': 14.451525999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Croatian Cultural Center', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Ul. Strossmayerova 1, Rijeka'}, {'id': 'ChIJY63zGP6gZEcRNZ3JcUpbF6U', 'types': ['secondary_school', 'government_office', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Ljudevita Gaja 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3258362, 'longitude': 14.455213100000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'First Sušak Croatian Gymnasium', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Ul. Ljudevita Gaja 1, Rijeka'}, {'id': 'ChIJad_bbP6gZEcRlk4u0fH2dtg', 'types': ['police', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gundulićeva ul. 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3251616, 'longitude': 14.4544199}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Second Police Station Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Government Office', 'languageCode': 'en-US'}, 'primaryType': 'government_office', 'shortFormattedAddress': 'Gundulićeva ul. 7, Rijeka'}, {'id': 'ChIJ6V9jnv2gZEcRDvcB8sRhHCo', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Strossmayerova 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325707, 'longitude': 14.4510987}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Galerija Kortil', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Ul. Strossmayerova 1, Rijeka'}, {'id': 'ChIJo4DN__2gZEcRlKVUqssNpIM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg braće Mažuranića 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326912, 'longitude': 14.4537801}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Rijeka - PPO Bulevard', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Trg braće Mažuranića 4, Rijeka'}, {'id': 'ChIJ1YKhJQChZEcRrusw5YsiLP4', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar oslobođenja 12, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326348499999995, 'longitude': 14.451634899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Cyril and Methodius', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Bulevar oslobođenja 12, Rijeka'}, {'id': 'ChIJkWODrWGhZEcRoSgXBKNDNYA', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Strossmayerova 13B, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3249752, 'longitude': 14.4527123}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kuća Brodova, Hrvatski savez brodomaketara - H ...
# obtaining places for point  60  /  340
# posting request
# obtained response
# [{'id': 'ChIJcWlmpUShZEcREu07bN9h7B0', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '8FH5+4J, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327855, 'longitude': 14.459045500000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Spomenik i spomen-kosturnica palih boraca', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': '8FH5+4J Park Heroja, Rijeka'}]
# obtaining places for point  61  /  340
# posting request
# obtained response
# [{'id': 'ChIJM15tH6uhZEcR7r3-d5nnSO8', 'types': ['primary_school', 'government_office', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'prilaz Vladimira Gortana 2, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326398499999996, 'longitude': 14.463901100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vladimir Gortan Rijeka Elementary School', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'prilaz Vladimira Gortana 2, Rijeka'}, {'id': 'ChIJKSI1mQqhZEcR17jMMv5I2RM', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Radićeva ul. 18, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3253081, 'longitude': 14.461332700000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DENTAL FUSION', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Radićeva ul. 18, Rijeka'}, {'id': 'ChIJyXGPTbGhZEcRVnvAHI2IjAE', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '8FH6+4Q, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327833, 'longitude': 14.461955999999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kapela sv. Mihovil', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': '8FH6+4Q, Rijeka'}]
# obtaining places for point  62  /  340
# posting request
# obtained response
# [{'id': 'ChIJQW0sA62hZEcRvKXnq0YfznI', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Tome Strižića 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3256413, 'longitude': 14.4700225}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rijeka Clinical Hospital Center Sušak Locality', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ul. Tome Strižića 3, Rijeka'}, {'id': 'ChIJsTJvagChZEcRAYMpKL7b7Xo', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Vjekoslava Dukića 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.32687610000001, 'longitude': 14.469060299999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječja bolnica Sušak', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ul. Vjekoslava Dukića 7, Rijeka'}, {'id': 'ChIJZcS8KAChZEcR4XkmHU3rqBs', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Vjekoslava Dukića 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3271224, 'longitude': 14.469272499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bolnica za majku i dijete Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ul. Vjekoslava Dukića 7, Rijeka'}, {'id': 'ChIJCYN6d6uhZEcRiRqii7QP1W0', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Znanstveno-tehnologijski park, Slavka Krautzeka 83, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3270373, 'longitude': 14.466340100000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Academy of Applied Arts', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Science and Technology Park, Slavka Krautzeka 83, Rijeka'}, {'id': 'ChIJrVo_cQChZEcRbiJRTG6_Eug', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sveučilišna Av, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326606899999994, 'longitude': 14.4695779}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rađaonica', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Sveučilišna Av, Rijeka'}, {'id': 'ChIJjVsjQgChZEcR2PeLuJFdYkE', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Tome Strižića 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327039, 'longitude': 14.4689787}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Odjel za intenzivno liječenje novorođenčadi', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ul. Tome Strižića 3, Rijeka'}, {'id': 'ChIJ038NqayhZEcR4f02B0EFSP8', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Slavka Krautzeka 84, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3251852, 'longitude': 14.4664877}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Sušak - PPO Pčelice', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Slavka Krautzeka 84, Rijeka'}]
# obtaining places for point  63  /  340
# posting request
# obtained response
# [{'id': 'ChIJeSzbge6hZEcRl7_YnTetIXA', 'types': ['hospital', 'point_of_interest', 'health', 'establishment'], 'formattedAddress': 'Ul. Vjekoslava Dukića 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3259787, 'longitude': 14.4718748}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'KBC Rijeka Rodilište', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ul. Vjekoslava Dukića 7, Rijeka'}]
# obtaining places for point  64  /  340
# posting request
# obtained response
# []
# obtaining places for point  65  /  340
# posting request
# obtained response
# []
# obtaining places for point  66  /  340
# posting request
# obtained response
# []
# obtaining places for point  67  /  340
# posting request
# obtained response
# []
# obtaining places for point  68  /  340
# posting request
# obtained response
# []
# obtaining places for point  69  /  340
# posting request
# obtained response
# []
# obtaining places for point  70  /  340
# posting request
# obtained response
# []
# obtaining places for point  71  /  340
# posting request
# obtained response
# []
# obtaining places for point  72  /  340
# posting request
# obtained response
# ...
# obtained response
# []
# obtaining places for point  250  /  340
# posting request
# obtained response
# []
# obtaining places for point  251  /  340
# posting request
# obtained response
# []
# obtaining places for point  252  /  340
# posting request
# obtained response
# [{'id': 'ChIJzafuKACnZEcRZCPb_yTo9Fo', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pletenci 6b, 51000, Rijeka, Croatia', 'location': {'latitude': 45.358691, 'longitude': 14.394661}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kamen', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Pletenci 6b, Rijeka'}]
# obtaining places for point  253  /  340
# posting request
# obtained response
# []
# obtaining places for point  254  /  340
# posting request
# obtained response
# [{'id': 'ChIJ9VCQzL6mZEcRVwRVljY_qUg', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mihovilići 33, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3560902, 'longitude': 14.405309599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Mavrica Pehlin', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Mihovilići 33, Rijeka'}]
# obtaining places for point  255  /  340
# posting request
# obtained response
# []
# obtaining places for point  256  /  340
# posting request
# obtained response
# []
# obtaining places for point  257  /  340
# posting request
# obtained response
# [{'id': 'ChIJsaQv67KmZEcRpiWFpD4clyc', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Ružice Mihić 29, 51000, Rijeka, Croatia', 'location': {'latitude': 45.357879999999994, 'longitude': 14.423394600000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of the All Saints', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Ružice Mihić 29, Rijeka'}]
# obtaining places for point  258  /  340
# posting request
# obtained response
# [{'id': 'ChIJI6eroVKhZEcRzg3unvBeyuM', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drenovski put 138a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.358610399999996, 'longitude': 14.427290500000002}, 'businessStatus': 'CLOSED_TEMPORARILY', 'displayName': {'text': 'Drenova Heritage Museum', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Drenovski put 138a, Rijeka'}, {'id': 'ChIJNzXK2cahZEcR6hDyLgt0dYQ', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drenovski put 138a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.358652899999996, 'longitude': 14.427364899999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Društveni dom Drenova', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Drenovski put 138a, Rijeka'}]
# obtaining places for point  259  /  340
# posting request
# obtained response
# [{'id': 'ChIJTWWO1FihZEcRdA5dfIZA74o', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Drenovski put, 51000, Rijeka, Croatia', 'location': {'latitude': 45.357714699999995, 'longitude': 14.432620499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kapela', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Drenovski put, Rijeka'}]
# obtaining places for point  260  /  340
# posting request
# obtained response
# []
# obtaining places for point  261  /  340
# posting request
# obtained response
# []
# obtaining places for point  262  /  340
# posting request
# obtained response
# []
# obtaining places for point  263  /  340
# posting request
# obtained response
# []
# obtaining places for point  264  /  340
# posting request
# obtained response
# []
# obtaining places for point  265  /  340
# posting request
# obtained response
# []
# obtaining places for point  266  /  340
# posting request
# obtained response
# []
# obtaining places for point  267  /  340
# posting request
# obtained response
# []
# obtaining places for point  268  /  340
# posting request
# obtained response
# [{'id': 'ChIJtd7LiGqmZEcRjz5Suyjy-7w', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Brestovice 31, 51215, Kastav, Croatia', 'location': {'latitude': 45.3599633, 'longitude': 14.3551826}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'AUTO KRUNA D.O.O.', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Brestovice 31, Kastav'}, {'id': 'ChIJIQ7CZQ6nZEcRhAARlpqRsd4', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Brestovice 44-45, 51215, Kastav, Croatia', 'location': {'latitude': 45.3608604, 'longitude': 14.354489099999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Fiorella La Guardina 5', 'languageCode': 'de'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Brestovice 44-45, Kastav'}, {'id': 'ChIJW5d77tWnZEcR_mkLjZYHyjk', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Brestovice 34a, 51215, Kastav, Croatia', 'location': {'latitude': 45.359628799999996, 'longitude': 14.3548624}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječji vrtić Kockica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Brestovice 34a, Kastav'}]
# obtaining places for point  269  /  340
# posting request
# obtained response
# []
# obtaining places for point  270  /  340
# posting request
# obtained response
# []
# obtaining places for point  271  /  340
# posting request
# obtained response
# []
# obtaining places for point  272  /  340
# posting request
# obtained response
# []
# obtaining places for point  273  /  340
# posting request
# obtained response
# []
# obtaining places for point  274  /  340
# posting request
# obtained response
# []
# obtaining places for point  275  /  340
# posting request
# obtained response
# []
# obtaining places for point  276  /  340
# posting request
# obtained response
# []
# obtaining places for point  277  /  340
# posting request
# obtained response
# [{'id': 'ChIJp9BZewKnZEcRnMIC-jRQ0b0', 'types': ['school', 'point_of_interest', 'store', 'establishment'], 'formattedAddress': 'Ul. Baretićevo 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3607683, 'longitude': 14.399714800000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Glazbeni studio Froge', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Ul. Baretićevo 3, Rijeka'}]
# obtaining places for point  278  /  340
# posting request
# obtained response
# []
# obtaining places for point  279  /  340
# posting request
# obtained response
# []
# obtaining places for point  280  /  340
# posting request
# obtained response
# []
# obtaining places for point  281  /  340
# posting request
# obtained response
# []
# obtaining places for point  282  /  340
# posting request
# obtained response
# [{'id': 'ChIJLZn8RACnZEcRUmPOwoADhis', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pešćevac 20, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3623438, 'longitude': 14.425091700000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kip Zuzza Easterncatta', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Pešćevac 20, Rijeka'}, {'id': 'ChIJocr7VQCnZEcRyvsK4wu3BPs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Brune Francetića 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3626887, 'longitude': 14.424109900000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rokova gejming spilja', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Brune Francetića 10, Rijeka'}]
# obtaining places for point  283  /  340
# posting request
# obtained response
# []
# obtaining places for point  284  /  340
# posting request
# obtained response
# [{'id': 'ChIJ7dB8KmmhZEcRsGkR3XANRWI', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '51000, Rijeka, Croatia', 'location': {'latitude': 45.3619722, 'longitude': 14.4386143}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of the Mother of God', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Rijeka'}]
# obtaining places for point  285  /  340
# posting request
# obtained response
# []
# obtaining places for point  286  /  340
# posting request
# obtained response
# []
# obtaining places for point  287  /  340
# posting request
# obtained response
# [{'id': 'ChIJjTZYGPCmZEcR7rMKMBGl-2Q', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ćikovići 26/4, 51215, Kastav, Croatia', 'location': {'latitude': 45.3639965, 'longitude': 14.348543399999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DJEČJI VRTIĆ PONEŠTRICA', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Ćikovići 26/4, Kastav'}]
# obtaining places for point  288  /  340
# posting request
# obtained response
# []
# obtaining places for point  289  /  340
# posting request
# obtained response
# []
# obtaining places for point  290  /  340
# posting request
# obtained response
# []
# obtaining places for point  291  /  340
# posting request
# obtained response
# []
# obtaining places for point  292  /  340
# posting request
# obtained response
# []
# obtaining places for point  293  /  340
# posting request
# obtained response
# []
# obtaining places for point  294  /  340
# posting request
# obtained response
# []
# obtaining places for point  295  /  340
# posting request
# obtained response
# []
# obtaining places for point  296  /  340
# posting request
# obtained response
# [{'id': 'ChIJWXU7o9inZEcR7DnAoEsUpBE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stupari 14, 51216, Marinići, Croatia', 'location': {'latitude': 45.3661013, 'longitude': 14.3958163}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Tri praščića, obrt za čuvanje djece', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Stupari 14, Marinići'}]
# obtaining places for point  297  /  340
# posting request
# obtained response
# []
# obtaining places for point  298  /  340
# posting request
# obtained response
# []
# obtaining places for point  299  /  340
# posting request
# obtained response
# []
# obtaining places for point  300  /  340
# posting request
# obtained response
# []
# obtaining places for point  301  /  340
# posting request
# obtained response
# []
# obtaining places for point  302  /  340
# posting request
# obtained response
# []
# obtaining places for point  303  /  340
# posting request
# obtained response
# []
# obtaining places for point  304  /  340
# posting request
# obtained response
# []
# obtaining places for point  305  /  340
# posting request
# obtained response
# []
# obtaining places for point  306  /  340
# posting request
# obtained response
# []
# obtaining places for point  307  /  340
# posting request
# obtained response
# [{'id': 'ChIJZ-oozAOnZEcR-2yCtH5ZOrs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Jurčići, 51215, Kastav, Croatia', 'location': {'latitude': 45.366188699999995, 'longitude': 14.3537037}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Jurčići, Kastav'}]
# obtaining places for point  308  /  340
# posting request
# obtained response
# []
# obtaining places for point  309  /  340
# posting request
# obtained response
# []
# obtaining places for point  310  /  340
# posting request
# obtained response
# []
# obtaining places for point  311  /  340
# posting request
# obtained response
# [{'id': 'ChIJfQOKDCukZEcRDzQA1byy09E', 'types': ['preschool', 'school', 'child_care_agency', 'point_of_interest', 'establishment'], 'formattedAddress': 'Marinići 144, 51216, Marinići, Croatia', 'location': {'latitude': 45.368316799999995, 'longitude': 14.3920622}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'DJEČJI VRTIĆ ZVONČICA', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Marinići 144, Marinići'}]
# obtaining places for point  312  /  340
# posting request
# obtained response
# []
# obtaining places for point  313  /  340
# posting request
# obtained response
# []
# obtaining places for point  314  /  340
# posting request
# obtained response
# []
# obtaining places for point  315  /  340
# posting request
# obtained response
# []
# obtaining places for point  316  /  340
# posting request
# obtained response
# []
# obtaining places for point  317  /  340
# posting request
# obtained response
# []
# obtaining places for point  318  /  340
# posting request
# obtained response
# [{'id': 'ChIJdxIjLi2lZEcRAVmemv33HMI', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Svetog Jurja 9, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3685887, 'longitude': 14.425687400000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. George', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Svetog Jurja 9, Rijeka'}]
# obtaining places for point  319  /  340
# posting request
# obtained response
# []
# obtaining places for point  320  /  340
# posting request
# obtained response
# []
# obtaining places for point  321  /  340
# posting request
# obtained response
# []
# obtaining places for point  322  /  340
# posting request
# obtained response
# []
# obtaining places for point  323  /  340
# posting request
# obtained response
# []
# obtaining places for point  324  /  340
# posting request
# obtained response
# []
# obtaining places for point  325  /  340
# posting request
# obtained response
# []
# obtaining places for point  326  /  340
# posting request
# obtained response
# []
# obtaining places for point  327  /  340
# posting request
# obtained response
# []
# obtaining places for point  328  /  340
# posting request
# obtained response
# []
# obtaining places for point  329  /  340
# posting request
# obtained response
# []
# obtaining places for point  330  /  340
# posting request
# obtained response
# []
# obtaining places for point  331  /  340
# posting request
# obtained response
# []
# obtaining places for point  332  /  340
# posting request
# obtained response
# []
# obtaining places for point  333  /  340
# posting request
# obtained response
# []
# obtaining places for point  334  /  340
# posting request
# obtained response
# []
# obtaining places for point  335  /  340
# posting request
# obtained response
# []
# obtaining places for point  336  /  340
# posting request
# obtained response
# []
# obtaining places for point  337  /  340
# posting request
# obtained response
# []
# obtaining places for point  338  /  340
# posting request
# obtained response
# []
# obtaining places for point  339  /  340
# posting request
# obtained response
# []

# %%
# extract the usable output from the above run
idxs_of_problem_spots = [i for i, pt in enumerate(points_lst) if len(list(pt.values())[0]) > 19]
print(idxs_of_problem_spots)
# keep only the results that weren't cut off by the api limit
points_lst_good = [pt for idx, pt in enumerate(points_lst) if idx not in idxs_of_problem_spots]
print(len(points_lst_good))

# re-run the points with > 20 locations using the 'split' method
# first, get geometry representations for each of the points that had > 20 places
problem_points = [points_lst[i] for i in idxs_of_problem_spots]
print(len(problem_points))
# then, get these geometries as a list
prob_point_vals = [list(pt.keys())[0] for pt in problem_points]
print(prob_point_vals)
# finally, filter the overall grid space to identify these problem geometries
pts_to_repeat = grid[grid['geometry'].isin(prob_point_vals)]
pts_to_repeat
# Out:
# [57, 73, 74]
# 337
# 3
# [<POINT (14.443 45.326)>, <POINT (14.437 45.33)>, <POINT (14.442 45.33)>]
#     Id                   geometry
# 57   0  POINT (14.44257 45.32603)
# 73   0  POINT (14.43734 45.32953)
# 74   0  POINT (14.44244 45.32963)

# %%
points_lst_fixed = obtain_places_from_points(url, headers, pts_to_repeat, 200, 'split')
# Out:
# obtaining places for point  57  /  3
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJbRuc-OGgZEcRE6wanKxOuNQ', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327624, 'longitude': 14.441770499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Visoka poslovna škola PAR', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Trg Riječke rezolucije 4, Rijeka'}, {'id': 'ChIJGZyGAuKgZEcRs3UGZAWqAeM', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3273295, 'longitude': 14.4421117}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Jerome', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg Riječke rezolucije, Rijeka'}, {'id': 'ChIJiSk1C-KgZEcRvMZPYo23zUs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Marka Marulića 14, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327566, 'longitude': 14.443368699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of Sts. Fabian and Sebastian', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Marka Marulića 14, Rijeka'}, {'id': 'ChIJGdEk9uGgZEcRTSe6aQ2Cz2I', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 24a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327361499999995, 'longitude': 14.441356899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sveučilište Algebra – regionalni centar Rijeka', 'languageCode': 'en'}, 'shortFormattedAddress': 'Korzo 24a, Rijeka'}, {'id': 'ChIJF1n6TvOhZEcR4wJn9I0UR-s', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Verdijeva ul. 11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.324475899999996, 'longitude': 14.443451800000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja waldorfska škola u Rijeci', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Verdijeva ul. 11, Rijeka'}, {'id': 'ChIJpVP7sOOgZEcRODcT4XvdCRo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Verdijeva ul. 6, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3250106, 'longitude': 14.442612799999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pomorsko Uciliste Nautički Centar -Kvarner', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Verdijeva ul. 6, Rijeka'}, {'id': 'ChIJZaiN136hZEcRwO_sU18Rx-c', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Veslarska ul. 8, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325014900000006, 'longitude': 14.444503599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mathrix - Instrukcije i poduke', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Veslarska ul. 8, Rijeka'}, {'id': 'ChIJSyRKWuKgZEcRqkX-mHXPCXs', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Korzo 2 A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326082299999996, 'longitude': 14.443702100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Intelekt - škola za odrasle', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'lang ...
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJOey1QeKgZEcRIcnpatZ9WVk', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Ivana Koblera 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3266667, 'longitude': 14.443055599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Clock Tower', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trg Ivana Koblera 1, Rijeka'}, {'id': 'ChIJ9z2ddmmhZEcRZQX_L2XOUoI', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Ivana Koblera 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3270239, 'longitude': 14.4436369}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Old Town Hall', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trg Ivana Koblera 4, Rijeka'}, {'id': 'ChIJsVXCb-KgZEcRZ5YB20-qNSE', 'types': ['monument', 'tourist_attraction', 'historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Stara Vrata 3, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3272365, 'longitude': 14.443667699999999}, 'businessStatus': 'CLOSED_TEMPORARILY', 'displayName': {'text': 'Old Roman Arch', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Monument', 'languageCode': 'en-US'}, 'primaryType': 'monument', 'shortFormattedAddress': 'Ul. Stara Vrata 3, Rijeka'}, {'id': 'ChIJu2omGOKgZEcRKgD_YIyoNxA', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 16, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3269131, 'longitude': 14.442420199999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Hall Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': 'Korzo 16, Rijeka'}, {'id': 'ChIJRdRW5D-hZEcR5WjHBJ6Mp7g', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Riva 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3266397, 'longitude': 14.440157500000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Matični ured Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Riva 10, Rijeka'}, {'id': 'ChIJX4bPri6hZEcRqt3xGMZ_Kao', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'palača Modello, Bačvarska ul., 51000, Rijeka, Croatia', 'location': {'latitude': 45.3254109, 'longitude': 14.443767800000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Modello Palace', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Palace Modello, Bačvarska ul., Rijeka'}, {'id': 'ChIJ7aOXJcWhZEcRrCwZuBa7k24', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Užarska ul. 11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3265384, 'longitude': 14.4449952}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Muzej Farmacije', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Užarska ul. 11, Rijeka'}, {'id': 'ChIJTzY1pOOgZEcRyjpZMx6vM34', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Verdijeva ul. 13, 51000, Rij ...
# Number of results returned from re:  12
# Number of results returned from cg:  20
# [{'id': 'ChIJbRuc-OGgZEcRE6wanKxOuNQ', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327624, 'longitude': 14.441770499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Visoka poslovna škola PAR', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Trg Riječke rezolucije 4, Rijeka'}, {'id': 'ChIJGZyGAuKgZEcRs3UGZAWqAeM', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3273295, 'longitude': 14.4421117}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Jerome', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg Riječke rezolucije, Rijeka'}, {'id': 'ChIJiSk1C-KgZEcRvMZPYo23zUs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Marka Marulića 14, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327566, 'longitude': 14.443368699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of Sts. Fabian and Sebastian', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Marka Marulića 14, Rijeka'}, {'id': 'ChIJGdEk9uGgZEcRTSe6aQ2Cz2I', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 24a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327361499999995, 'longitude': 14.441356899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sveučilište Algebra – regionalni centar Rijeka', 'languageCode': 'en'}, 'shortFormattedAddress': 'Korzo 24a, Rijeka'}, {'id': 'ChIJF1n6TvOhZEcR4wJn9I0UR-s', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Verdijeva ul. 11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.324475899999996, 'longitude': 14.443451800000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja waldorfska škola u Rijeci', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Verdijeva ul. 11, Rijeka'}, {'id': 'ChIJpVP7sOOgZEcRODcT4XvdCRo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Verdijeva ul. 6, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3250106, 'longitude': 14.442612799999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pomorsko Uciliste Nautički Centar -Kvarner', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Verdijeva ul. 6, Rijeka'}, {'id': 'ChIJZaiN136hZEcRwO_sU18Rx-c', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Veslarska ul. 8, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325014900000006, 'longitude': 14.444503599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mathrix - Instrukcije i poduke', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Veslarska ul. 8, Rijeka'}, {'id': 'ChIJSyRKWuKgZEcRqkX-mHXPCXs', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Korzo 2 A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326082299999996, 'longitude': 14.443702100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Intelekt - škola za odrasle', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'se ...
# obtaining places for point  73  /  3
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJnfQSOiChZEcRzubl8EtzXmc', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Studentska ul. 2, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3303249, 'longitude': 14.4361567}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Faculty of Maritime Studies of the University of Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Studentska ul. 2, Rijeka'}, {'id': 'ChIJYQySHuCgZEcRHEihzQWPPq8', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kapucinske stube 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328581, 'longitude': 14.4373092}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of Our Lady of Lourdes', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Kapucinske stube 5, Rijeka'}, {'id': 'ChIJC3P1hR-hZEcRqJ1McFf-aU4', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Slaviše Vajnera Čiče 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3304432, 'longitude': 14.4372624}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Church of Jesus Christ of Latter-day Saints', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Slaviše Vajnera Čiče 7, Rijeka'}, {'id': 'ChIJySqwVaKhZEcRhsF31vwKg8U', 'types': ['tour_agency', 'travel_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Prolaz Marije Krucifiske Kozulić 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.329569299999996, 'longitude': 14.438805499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Adriatic Sailing Academy', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Prolaz Marije Krucifiske Kozulić 1, Rijeka'}, {'id': 'ChIJRapklx-hZEcRWkm5y5W-R6U', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pomerio 21, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3301453, 'longitude': 14.438100599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'CALLEGARI TALIJANSKA ŠKOLA MODE I DIZAJNA', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Pomerio 21, Rijeka'}, {'id': 'ChIJL4H4XWKhZEcRPQAVhdEjqR0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pomerio 13, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3301631, 'longitude': 14.4395554}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Područni vrtić "Mima"', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Pomerio 13, Rijeka'}, {'id': 'ChIJs1_2DiChZEcR0vFTOxY8Tbg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Krešimirova ul. 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3292869, 'longitude': 14.435160199999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Association "ART & FUN"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Krešimirova ul. 10, Rijeka'}, {'id': 'ChIJ5TxNewChZEcRHkk6j-72YsA', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Erazma Barčića 9A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328975199999995, 'longitude': 14.439581800000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mala slobodna knjižnica', 'languageCode': 'de'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primary ...
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJzcMaMh6hZEcR3dvcs7jOnBw', 'types': ['coffee_shop', 'art_gallery', 'night_club', 'bar', 'cafe', 'event_venue', 'government_office', 'food_store', 'food', 'point_of_interest', 'store', 'establishment'], 'formattedAddress': 'Ul. Erazma Barčića 9A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.32891130000001, 'longitude': 14.439502999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Youth Club Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Government Office', 'languageCode': 'en-US'}, 'primaryType': 'government_office', 'shortFormattedAddress': 'Ul. Erazma Barčića 9A, Rijeka'}, {'id': 'ChIJFXi_2B-hZEcRxAUVghr2Yus', 'types': ['bar', 'internet_cafe', 'pub', 'art_gallery', 'cafe', 'food', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ciottina ul. 12a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3285595, 'longitude': 14.437954499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Book caffe Dnevni boravak', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Bar', 'languageCode': 'en-US'}, 'primaryType': 'bar', 'shortFormattedAddress': 'Ciottina ul. 12a, Rijeka'}, {'id': 'ChIJWxO_GCChZEcRfewNXaBjuy8', 'types': ['police', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ciottina ul. 25, 51000, Rijeka, Croatia', 'location': {'latitude': 45.329853799999995, 'longitude': 14.4360342}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Traffic police station - City Of Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Police', 'languageCode': 'en-US'}, 'primaryType': 'police', 'shortFormattedAddress': 'Ciottina ul. 25, Rijeka'}, {'id': 'ChIJ8Wey1B-hZEcRwHZMpqDNHwE', 'types': ['local_government_office', 'courthouse', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Erazma Barčića 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3285935, 'longitude': 14.439064100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Of Rijeka Administrative Court', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Ul. Erazma Barčića 5, Rijeka'}, {'id': 'ChIJtVkHKx6hZEcRbVleJEnQRX8', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Erazma Barčića 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328485199999996, 'longitude': 14.439229300000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Regionalni ispitni centar HAK', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Ul. Erazma Barčića 4, Rijeka'}, {'id': 'ChIJdzHAJOCgZEcRiZOIm8ubxd4', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trpimirova ul. 6, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3281256, 'longitude': 14.437631099999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Palača Ploech (Palace Ploech)', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trpimirova ul. 6, Rijeka'}, {'id': 'ChIJGxb9MeCgZEcRydzk2VTlJN0', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trpimirova ul. 2-11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3279681, 'longitude': 14.438292599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zorovic Maritime Services Ltd.', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Government Office', 'languageCode': 'en-US'}, 'primaryType': 'government_office', 'shortFormattedAddress': 'Trpimirova ul. 2-11, Rije ...
# Number of results returned from re:  8
# Number of results returned from cg:  13
# [{'id': 'ChIJnfQSOiChZEcRzubl8EtzXmc', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Studentska ul. 2, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3303249, 'longitude': 14.4361567}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Faculty of Maritime Studies of the University of Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Studentska ul. 2, Rijeka'}, {'id': 'ChIJYQySHuCgZEcRHEihzQWPPq8', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kapucinske stube 5, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328581, 'longitude': 14.4373092}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of Our Lady of Lourdes', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Kapucinske stube 5, Rijeka'}, {'id': 'ChIJC3P1hR-hZEcRqJ1McFf-aU4', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Slaviše Vajnera Čiče 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3304432, 'longitude': 14.4372624}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Church of Jesus Christ of Latter-day Saints', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Slaviše Vajnera Čiče 7, Rijeka'}, {'id': 'ChIJySqwVaKhZEcRhsF31vwKg8U', 'types': ['tour_agency', 'travel_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Prolaz Marije Krucifiske Kozulić 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.329569299999996, 'longitude': 14.438805499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Adriatic Sailing Academy', 'languageCode': 'hr'}, 'shortFormattedAddress': 'Prolaz Marije Krucifiske Kozulić 1, Rijeka'}, {'id': 'ChIJRapklx-hZEcRWkm5y5W-R6U', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pomerio 21, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3301453, 'longitude': 14.438100599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'CALLEGARI TALIJANSKA ŠKOLA MODE I DIZAJNA', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Pomerio 21, Rijeka'}, {'id': 'ChIJL4H4XWKhZEcRPQAVhdEjqR0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pomerio 13, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3301631, 'longitude': 14.4395554}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Područni vrtić "Mima"', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Pomerio 13, Rijeka'}, {'id': 'ChIJs1_2DiChZEcR0vFTOxY8Tbg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Krešimirova ul. 10, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3292869, 'longitude': 14.435160199999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Association "ART & FUN"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Krešimirova ul. 10, Rijeka'}, {'id': 'ChIJ5TxNewChZEcRHkk6j-72YsA', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Erazma Barčića 9A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328975199999995, 'longitude': 14.439581800000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mala slobodna knjižnica', 'languageCode': 'de'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddres ...
# obtaining places for point  74  /  3
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJTeShGx6hZEcRjFHoOgvchjY', 'types': ['secondary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Frana Kurelca 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3283771, 'longitude': 14.441336499999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Rijeka's First Croatian High School", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Ul. Frana Kurelca 1, Rijeka'}, {'id': 'ChIJxTmvBB6hZEcR-3u3-WnhtPs', 'types': ['secondary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Frana Kurelca 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3282337, 'longitude': 14.441508599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Andrija Mohorovičić Rijeka Gymnasium', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Frana Kurelca 1, Rijeka'}, {'id': 'ChIJsQbuhx6hZEcRB-HGvg9uihQ', 'types': ['primary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Laginjina ul. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.330154, 'longitude': 14.442582300000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ivan Matetić Ronjgov Music School', 'languageCode': 'en'}, 'shortFormattedAddress': 'Laginjina ul. 1, Rijeka'}, {'id': 'ChIJAZr-ra2hZEcRbwX2I78h1l8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Ivana Dežmana 2b, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328934, 'longitude': 14.4417955}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Edukido Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Ivana Dežmana 2b, Rijeka'}, {'id': 'ChIJcRb3H_OhZEcRtyjwMrH5hE0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stube Alberta Anđelovića 5C, 51000, Rijeka, Croatia', 'location': {'latitude': 45.330297099999996, 'longitude': 14.442095199999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kreativna Udruga Shabby Chic', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Stube Alberta Anđelovića 5C, Rijeka'}]}
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJKbyE3x2hZEcRusxjjhxgXE8', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riccarda Zanelle 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3295105, 'longitude': 14.4426041}, 'businessStatus': 'CLOSED_TEMPORARILY', 'displayName': {'text': 'Maritime and History Museum of the Croatian Coast', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Trg Riccarda Zanelle 1, Rijeka'}, {'id': 'ChIJtWRRzx2hZEcR4RCHgPgZAXQ', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Lorenzov pro. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3295324, 'longitude': 14.444097999999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Natural History Museum Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Lorenzov pro. 1, Rijeka'}, {'id': 'ChIJUZhrkx2hZEcRO-dZXy0jCPE', 'types': ['courthouse', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Žrtava fašizma 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328350500000006, 'longitude': 14.4440295}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Municipal Court of Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Ul. Žrtava fašizma 7, Rijeka'}, {'id': 'ChIJ9acECB6hZEcRp4t8f_mBWCY', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Slogin-Kula ul. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3282427, 'longitude': 14.442167899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hrvatski zavod za zdravstveno osiguranje - Područna ustrojstvena jedinica Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Slogin-Kula ul. 1, Rijeka'}, {'id': 'ChIJGZ51wtKmZEcRQaSFrDSa2aQ', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Laginjina ul. 11A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3308313, 'longitude': 14.440800699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Centar za socijalnu skrb Rijeka', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Laginjina ul. 11A, Rijeka'}, {'id': 'ChIJCadoa7KhZEcRyUfGrZt7SoU', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riccarda Zanelle 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.329908599999996, 'longitude': 14.4420872}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rijeka City Museum - Cube', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Trg Riccarda Zanelle 1, Rijeka'}, {'id': 'ChIJuxQx0wqhZEcR5ScfM09l_Gk', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '51000, Rijeka, Croatia', 'location': {'latitude': 45.328809799999995, 'longitude': 14.440418900000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Rijeka Tunnel (TunelRI)', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Rijeka'}, {'id': 'ChIJRfmmwP2hZEcRtF5cB6PLM0E', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pa ...
# Number of results returned from re:  5
# Number of results returned from cg:  15
# [{'id': 'ChIJTeShGx6hZEcRjFHoOgvchjY', 'types': ['secondary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Frana Kurelca 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3283771, 'longitude': 14.441336499999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Rijeka's First Croatian High School", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Ul. Frana Kurelca 1, Rijeka'}, {'id': 'ChIJxTmvBB6hZEcR-3u3-WnhtPs', 'types': ['secondary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Ul. Frana Kurelca 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3282337, 'longitude': 14.441508599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Andrija Mohorovičić Rijeka Gymnasium', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Frana Kurelca 1, Rijeka'}, {'id': 'ChIJsQbuhx6hZEcRB-HGvg9uihQ', 'types': ['primary_school', 'government_office', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Laginjina ul. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.330154, 'longitude': 14.442582300000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ivan Matetić Ronjgov Music School', 'languageCode': 'en'}, 'shortFormattedAddress': 'Laginjina ul. 1, Rijeka'}, {'id': 'ChIJAZr-ra2hZEcRbwX2I78h1l8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Ivana Dežmana 2b, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328934, 'longitude': 14.4417955}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Edukido Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ul. Ivana Dežmana 2b, Rijeka'}, {'id': 'ChIJcRb3H_OhZEcRtyjwMrH5hE0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stube Alberta Anđelovića 5C, 51000, Rijeka, Croatia', 'location': {'latitude': 45.330297099999996, 'longitude': 14.442095199999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kreativna Udruga Shabby Chic', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Stube Alberta Anđelovića 5C, Rijeka'}, {'id': 'ChIJKbyE3x2hZEcRusxjjhxgXE8', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riccarda Zanelle 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3295105, 'longitude': 14.4426041}, 'businessStatus': 'CLOSED_TEMPORARILY', 'displayName': {'text': 'Maritime and History Museum of the Croatian Coast', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Trg Riccarda Zanelle 1, Rijeka'}, {'id': 'ChIJtWRRzx2hZEcR4RCHgPgZAXQ', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Lorenzov pro. 1, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3295324, 'longitude': 14.444097999999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Natural History Museum Rijeka', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Lorenzov pro. 1, Rijeka'}, {'id': 'ChIJUZhrkx2hZEcRO-dZXy0jCPE', 'types': ['courthouse', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Žrtava fašizma 7, 51000, Rijeka, Croatia', 'location': {'latitude': 45.328350500000006, 'longitude': 14.4440295}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Municipal Court of Rijeka', 'languageCode': 'en'}, 'primaryType ...

# %%
# still one remaining point that had > 20 with the split of types, so will save the others that had < 20..
points_lst_fixed_good = [pt for idx, pt in enumerate(points_lst_fixed) if idx in [1,2]]
print(len(points_lst_fixed_good))

# .. and re-run the points which still have > 20 locations using the 'split_all' method
# first, get geometry representations for each of the points tha had > 20 places
problem_points = [points_lst_fixed[i] for i in [0]]
print(problem_points)
print(len(problem_points))
# then, get these geometries as a list
prob_point_vals = [list(pt.keys())[0] for pt in problem_points]
print(prob_point_vals)
# finally, filter the overall grid space to identify these problem geometries
pts_to_repeat = grid[grid['geometry'].isin(prob_point_vals)]
pts_to_repeat
# Out:
# 2
# [{<POINT (14.443 45.326)>: [{'id': 'ChIJbRuc-OGgZEcRE6wanKxOuNQ', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327624, 'longitude': 14.441770499999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Visoka poslovna škola PAR', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Trg Riječke rezolucije 4, Rijeka'}, {'id': 'ChIJGZyGAuKgZEcRs3UGZAWqAeM', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Riječke rezolucije, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3273295, 'longitude': 14.4421117}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of St. Jerome', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg Riječke rezolucije, Rijeka'}, {'id': 'ChIJiSk1C-KgZEcRvMZPYo23zUs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Marka Marulića 14, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327566, 'longitude': 14.443368699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Chapel of Sts. Fabian and Sebastian', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ul. Marka Marulića 14, Rijeka'}, {'id': 'ChIJGdEk9uGgZEcRTSe6aQ2Cz2I', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 24a, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327361499999995, 'longitude': 14.441356899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sveučilište Algebra – regionalni centar Rijeka', 'languageCode': 'en'}, 'shortFormattedAddress': 'Korzo 24a, Rijeka'}, {'id': 'ChIJF1n6TvOhZEcR4wJn9I0UR-s', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Verdijeva ul. 11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.324475899999996, 'longitude': 14.443451800000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja waldorfska škola u Rijeci', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Verdijeva ul. 11, Rijeka'}, {'id': 'ChIJpVP7sOOgZEcRODcT4XvdCRo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Verdijeva ul. 6, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3250106, 'longitude': 14.442612799999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pomorsko Uciliste Nautički Centar -Kvarner', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Verdijeva ul. 6, Rijeka'}, {'id': 'ChIJZaiN136hZEcRwO_sU18Rx-c', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Veslarska ul. 8, 51000, Rijeka, Croatia', 'location': {'latitude': 45.325014900000006, 'longitude': 14.444503599999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mathrix - Instrukcije i poduke', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Veslarska ul. 8, Rijeka'}, {'id': 'ChIJSyRKWuKgZEcRqkX-mHXPCXs', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Korzo 2 A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326082299999996, 'longitude': 14.443702100000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Intelekt - škola za odrasle', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': ' ...
# 1
# [<POINT (14.443 45.326)>]
#     Id                   geometry
# 57   0  POINT (14.44257 45.32603)

# %%
# this worked, didn't reach the 20 limit when split by each type
points_lst_fixed_fin = obtain_places_from_points(url, headers, pts_to_repeat, 200, 'split_all')
# Out:
# obtaining places for point  57  /  1
# Obtaining places type by type
# Obtaining for type  art_gallery
# posting request
# obtained response
# Number of results returned from type art_gallery: 6
# Obtaining for type  museum
# posting request
# obtained response
# Number of results returned from type museum: 1
# Obtaining for type  performing_arts_theater
# posting request
# obtained response
# Number of results returned from type performing_arts_theater: 1
# Obtaining for type  library
# posting request
# obtained response
# Number of results returned from type library: 1
# Obtaining for type  school
# posting request
# obtained response
# Number of results returned from type school: 6
# Obtaining for type  university
# posting request
# obtained response
# Number of results returned from type university: 2
# Obtaining for type  community_center
# posting request
# obtained response
# Obtaining for type  cultural_center
# posting request
# obtained response
# Obtaining for type  historical_landmark
# posting request
# obtained response
# Number of results returned from type historical_landmark: 13
# Obtaining for type  city_hall
# posting request
# obtained response
# Number of results returned from type city_hall: 2
# Obtaining for type  courthouse
# posting request
# obtained response
# Obtaining for type  local_government_office
# posting request
# obtained response
# Number of results returned from type local_government_office: 7
# Obtaining for type  police
# posting request
# obtained response
# Obtaining for type  hospital
# posting request
# obtained response
# Number of results returned from type hospital: 2
# Obtaining for type  church
# posting request
# obtained response
# Number of results returned from type church: 3
# Obtaining for type  hindu_temple
# posting request
# obtained response
# Obtaining for type  mosque
# posting request
# obtained response
# Obtaining for type  synagogue
# posting request
# obtained response
# [{'id': 'ChIJgwWHduKgZEcRSXvcxdMIhmY', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. pod Voltun 4, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327568199999995, 'longitude': 14.443808200000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Galerija Principij', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Ul. pod Voltun 4, Rijeka'}, {'id': 'ChIJlwVUt-OgZEcR2UtxZtWi0bY', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Verdijeva ul. 19 b, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3249162, 'longitude': 14.442383699999999}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Galerija Juraj Klović', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Verdijeva ul. 19 b, Rijeka'}, {'id': 'ChIJMRd__T6hZEcRX4E-pyLQK3Q', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg 128 Brigade Hrvatske Vojske 3A, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3268433, 'longitude': 14.441175300000001}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PONEŠTRICA Galerija', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Trg 128 Brigade Hrvatske Vojske 3A, Rijeka'}, {'id': 'ChIJ63bv_FyhZEcRWnco2ikO5xU', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pavlinski trg 6, 51000, Rijeka, Croatia', 'location': {'latitude': 45.326283, 'longitude': 14.4448435}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Galerija Lena Art', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Pavlinski trg 6, Rijeka'}, {'id': 'ChIJv7BZHTehZEcRpftrE88vYX4', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ul. Janeza Trdine, Pavlinski trg 2, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3260353, 'longitude': 14.444833399999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'LeMark.Art j.d.o.o.', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Ul. Janeza Trdine, Pavlinski trg 2, Rijeka'}, {'id': 'ChIJGdEk9uGgZEcR0BNk4L-mw9c', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Korzo 24, 51000, Rijeka, Croatia', 'location': {'latitude': 45.327220399999995, 'longitude': 14.4415383}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mali Salon', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Korzo 24, Rijeka'}, {'id': 'ChIJ7aOXJcWhZEcRrCwZuBa7k24', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Užarska ul. 11, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3265384, 'longitude': 14.4449952}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Muzej Farmacije', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Užarska ul. 11, Rijeka'}, {'id': 'ChIJWy-frtmhZEcR0U5ctRWpoOo', 'types': ['performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Unnamedroad, 51000, Rijeka, Croatia', 'location': {'latitude': 45.3270451, 'longitude': 14.442113399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Produkcija Z', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Performing Arts Theater', 'languageCode': 'en-US'}, 'primaryType': 'performing_arts_theater' ...

# %%
points_lst_fin = points_lst_fixed_fin + points_lst_fixed_good + points_lst_good
print(len(points_lst_fin))

city_gdf = clean_maps_api_output(points_lst_fin)

city_gdf.to_file("/mnt/c/Users/natra/Documents/Research/Identity-Conflict/croatia_files/clean/rijeka_locs_400x400.geojson",
                          driver='GeoJSON')
# Out:
# 340
# Number of place dictionaries returned from API:  114
# Shape of resulting dataframe:  (361, 13)
# Shape of dataframe after dropping dups:  (359, 13)

# %% [markdown]
# ## Serbia

# %% [markdown]
# ### Novi Pazar

# %%
# created grid in as 400 x 400 w x h grids with Fishnet tool in ArcGIS Pro
grid = gpd.read_file('./serbia_files/raw/site_locations/novi-pazar-fishnet-clip-4326.shp')
print(grid.shape)
print(grid.crs)
grid.head()
# Out:
# (115, 2)
# EPSG:4326
#    Id                   geometry
# 0   0   POINT (20.49476 43.1168)
# 1   0  POINT (20.49968 43.11682)
# 2   0  POINT (20.48981 43.12038)
# 3   0   POINT (20.49473 43.1204)
# 4   0  POINT (20.49965 43.12042)

# %%
points_lst = obtain_places_from_points(url, headers, grid, 200)
# Out:
# obtaining places for point  0  /  115
# posting request
# obtained response
# []
# obtaining places for point  1  /  115
# posting request
# obtained response
# []
# obtaining places for point  2  /  115
# posting request
# obtained response
# []
# obtaining places for point  3  /  115
# posting request
# obtained response
# [{'id': 'ChIJx2HJPgAtUxMRkq1IosYopR0', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mur 48, Paralovo, Serbia', 'location': {'latitude': 43.119771199999995, 'longitude': 20.4944107}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Nur Džamija', 'languageCode': 'bs'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Mur 48, Paralovo'}]
# obtaining places for point  4  /  115
# posting request
# obtained response
# []
# obtaining places for point  5  /  115
# posting request
# obtained response
# [{'id': 'ChIJl_cQH0wtUxMRMv__Z9sLY3I', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mur, Serbia', 'location': {'latitude': 43.1216302, 'longitude': 20.5049095}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mosque Gornji Šutenovac', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Mur'}]
# obtaining places for point  6  /  115
# posting request
# obtained response
# []
# obtaining places for point  7  /  115
# posting request
# obtained response
# []
# obtaining places for point  8  /  115
# posting request
# obtained response
# []
# obtaining places for point  9  /  115
# posting request
# obtained response
# []
# obtaining places for point  10  /  115
# posting request
# obtained response
# []
# obtaining places for point  11  /  115
# posting request
# obtained response
# []
# obtaining places for point  12  /  115
# posting request
# obtained response
# []
# obtaining places for point  13  /  115
# posting request
# obtained response
# []
# obtaining places for point  14  /  115
# posting request
# obtained response
# [{'id': 'ChIJXQpZ_GEtUxMRS9Mm04rU_M4', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zlatiborska Ulica, Novi Pazar, Serbia', 'location': {'latitude': 43.1255794, 'longitude': 20.505793399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'ORDINACIJA BEJAN', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Zlatiborska Ulica, Novi Pazar'}]
# obtaining places for point  15  /  115
# posting request
# obtained response
# []
# obtaining places for point  16  /  115
# posting request
# obtained response
# []
# obtaining places for point  17  /  115
# posting request
# obtained response
# [{'id': 'ChIJWaVKWb8pVkcRb5XQFc2yEqU', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mur, Serbia', 'location': {'latitude': 43.124373299999995, 'longitude': 20.517584199999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ćeremindžinica Mosque', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Mur'}]
# obtaining places for point  18  /  115
# posting request
# obtained response
# []
# obtaining places for point  19  /  115
# posting request
# obtained response
# [{'id': 'ChIJYxoIYwAnVkcRTCvElqD6mYg', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Osoje, Serbia', 'location': {'latitude': 43.1243291, 'longitude': 20.5315709}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hadži Šemsova džamija', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Osoje'}]
# obtaining places for point  20  /  115
# posting request
# obtained response
# [{'id': 'ChIJqUGpuiMtUxMRFD9kjxWjrA8', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.128096199999995, 'longitude': 20.4860789}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Džamija Donje Paralovo', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  21  /  115
# posting request
# obtained response
# []
# obtaining places for point  22  /  115
# posting request
# obtained response
# [{'id': 'ChIJjbQHU3ktUxMRIolxZMUewNM', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Hadži-Mehova džamija, Ive Andrića, Novi Pazar, Serbia', 'location': {'latitude': 43.1270828, 'longitude': 20.4958021}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hadži Mehova Mosque', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Hadži-Mehova džamija, Ive Andrića, Novi Pazar'}]
# obtaining places for point  23  /  115
# posting request
# obtained response
# [{'id': 'ChIJzSwOdAAtUxMRn3shFSL00vg', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '3. Sandžačke proleterske brigade 77, Novi Pazar, Serbia', 'location': {'latitude': 43.126214499999996, 'longitude': 20.5006067}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hadži Šefkova Džamija', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': '3. Sandžačke proleterske brigade 77, Novi Pazar'}]
# obtaining places for point  24  /  115
# posting request
# obtained response
# [{'id': 'ChIJ1xUQfx4oVkcRymS-9cRAI4Q', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1279016, 'longitude': 20.506790799999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sinan beg medresa', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJPRDZWQApVkcRVHOJu4FeWgk', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.127269899999995, 'longitude': 20.5029526}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dzamija Privatna', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  25  /  115
# posting request
# obtained response
# [{'id': 'ChIJ1dgjblgpVkcRp4kNLyTCiXM', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1288471, 'longitude': 20.5097921}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Džamija El Džinan', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  26  /  115
# posting request
# obtained response
# []
# obtaining places for point  27  /  115
# posting request
# obtained response
# [{'id': 'ChIJiw72MQApVkcR-NO6XYt5d_c', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Трнавска 1, Novi Pazar, Serbia', 'location': {'latitude': 43.129225, 'longitude': 20.5188849}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Stambol Mosque', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Трнавска 1, Novi Pazar'}]
# obtaining places for point  28  /  115
# posting request
# obtained response
# [{'id': 'ChIJze1wSwApVkcRkgphWa8F2VM', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1282463, 'longitude': 20.5233206}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Islamski Centar Gazilar', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  29  /  115
# posting request
# obtained response
# []
# obtaining places for point  30  /  115
# posting request
# obtained response
# []
# obtaining places for point  31  /  115
# posting request
# obtained response
# []
# obtaining places for point  32  /  115
# posting request
# obtained response
# []
# obtaining places for point  33  /  115
# posting request
# obtained response
# []
# obtaining places for point  34  /  115
# posting request
# obtained response
# []
# obtaining places for point  35  /  115
# posting request
# obtained response
# []
# obtaining places for point  36  /  115
# posting request
# obtained response
# [{'id': 'ChIJxVuUVBkoVkcRzN3xSP_oVXY', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Berat, Emina Redžepagića, Novi Pazar, Serbia', 'location': {'latitude': 43.1306199, 'longitude': 20.5064456}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Berat Mosque', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Berat, Emina Redžepagića, Novi Pazar'}]
# obtaining places for point  37  /  115
# posting request
# obtained response
# [{'id': 'ChIJNd-04PYpVkcR2vSujtwJQJY', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'ул, Generala Živkovića bb, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1324793, 'longitude': 20.509321699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'GASTROMEDICA GM NOVI PAZAR', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'ул, Generala Živkovića bb, Novi Pazar'}, {'id': 'ChIJLa_M4bgpVkcRdfs9ef_IoPo', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Generala Živkovića bb, 020 390 990, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.132537299999996, 'longitude': 20.5093352}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Poliklinika Bosfor', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Generala Živkovića bb, 020 390 990, Novi Pazar'}, {'id': 'ChIJc0R-h8ApVkcRidB9ohbX6qs', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Emina Redžepagića 37, Novi Pazar, Serbia', 'location': {'latitude': 43.132, 'longitude': 20.507554199999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vrtić "AJŠA" - BenX', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Emina Redžepagića 37, Novi Pazar'}, {'id': 'ChIJXSvdsW8pVkcRNXbtweZKm-0', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Generala Živkovića, Novi Pazar, Serbia', 'location': {'latitude': 43.1324585, 'longitude': 20.509238999999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dijagnostika As (Rendgen Kabinet)', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Generala Živkovića, Novi Pazar'}, {'id': 'ChIJg7xIoJ4pVkcRbwHCK7a6PSk', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Emina Redžepagića 44, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.132088599999996, 'longitude': 20.507650899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'NP BENIM', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Emina Redžepagića 44, Novi Pazar'}]
# obtaining places for point  38  /  115
# posting request
# obtained response
# [{'id': 'ChIJP9mYVR8pVkcRGTRwABRYzcI', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sutjeska, Novi Pazar, Serbia', 'location': {'latitude': 43.1321789, 'longitude': 20.5124204}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Medicinska skola "Halifa bin Zaid Al Nahjan"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Sutjeska, Novi Pazar'}]
# obtaining places for point  39  /  115
# posting request
# obtained response
# [{'id': 'ChIJMQLcYgYoVkcRMUPb0tj7LfQ', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.130308, 'longitude': 20.5210792}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'AutoCentar CESTA', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJ6ZAVigUoVkcRHaxHUSyetUc', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1326623, 'longitude': 20.51988}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Deciji vrtic Leptiric', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJG7Nl8QUoVkcRUStH0UNPb60', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1321588, 'longitude': 20.5203551}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Skola crtanja i slikanja Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJ_z60jQYoVkcRi45JyPcWhXY', 'types': ['hindu_temple', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ruđera Boškovića, Novi Pazar, Serbia', 'location': {'latitude': 43.1307444, 'longitude': 20.5189786}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Drvostil Bibić', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hindu Temple', 'languageCode': 'en-US'}, 'primaryType': 'hindu_temple', 'shortFormattedAddress': 'Ruđera Boškovića, Novi Pazar'}]
# obtaining places for point  40  /  115
# posting request
# obtained response
# []
# obtaining places for point  41  /  115
# posting request
# obtained response
# []
# obtaining places for point  42  /  115
# posting request
# obtained response
# []
# obtaining places for point  43  /  115
# posting request
# obtained response
# []
# obtaining places for point  44  /  115
# posting request
# obtained response
# [{'id': 'ChIJodZBPTgpVkcRNbTNMy_BZSw', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Hadzet, Novi Pazar, Serbia', 'location': {'latitude': 43.1342645, 'longitude': 20.484909899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Džamija "Ebu Bekr", Barakovci', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Hadzet, Novi Pazar'}]
# obtaining places for point  45  /  115
# posting request
# obtained response
# []
# obtaining places for point  46  /  115
# posting request
# obtained response
# []
# obtaining places for point  47  /  115
# posting request
# obtained response
# [{'id': 'ChIJ5ZfNWAApVkcRSMkKOg5pXZY', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Hercegovačka 168, Novi Pazar, Serbia', 'location': {'latitude': 43.135366999999995, 'longitude': 20.5013681}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi Pazar', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Hercegovačka 168, Novi Pazar'}]
# obtaining places for point  48  /  115
# posting request
# obtained response
# [{'id': 'ChIJR0_UNRgoVkcR7ZEnGYi04d0', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Бродаревска 5, Novi Pazar, Serbia', 'location': {'latitude': 43.1343349, 'longitude': 20.505773899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Nikšićka Džamija', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Бродаревска 5, Novi Pazar'}]
# obtaining places for point  49  /  115
# posting request
# obtained response
# [{'id': 'ChIJBcwolhAoVkcRrhOPKlm9rL4', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Generala Živkovića, Novi Pazar, Serbia', 'location': {'latitude': 43.1349982, 'longitude': 20.5118002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dječiji vrtic Reuda i Vildan Hadzet', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Generala Živkovića, Novi Pazar'}]
# obtaining places for point  50  /  115
# posting request
# obtained response
# [{'id': 'ChIJ3Yf95e8pVkcR6-6GsxdlasQ', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Generala Živkovića 1, Novi Pazar, Serbia', 'location': {'latitude': 43.1342782, 'longitude': 20.5124177}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Diagnostic Center of the Public Hospital in Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Generala Živkovića 1, Novi Pazar'}, {'id': 'ChIJnwHnVDMpVkcRYUOvH9YOEMM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Borisa Kidriča 1, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.135128200000004, 'longitude': 20.5141822}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto Škola Vedo-Driver', 'languageCode': 'en'}, 'shortFormattedAddress': 'Borisa Kidriča 1, Novi Pazar'}]
# obtaining places for point  51  /  115
# posting request
# obtained response
# [{'id': 'ChIJd5wJ8g8oVkcRV0D53gs396A', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Oslobođenja, Novi Pazar, Serbia', 'location': {'latitude': 43.13380250000001, 'longitude': 20.517474999999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'OŠ "Rifat Burdžović Tršo"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Oslobođenja, Novi Pazar'}, {'id': 'ChIJC-rmIR4pVkcRo8crvUeu9SA', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Beogradska, Novi Pazar, Serbia', 'location': {'latitude': 43.1346347, 'longitude': 20.5215483}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto škola XL 020 DOO Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Beogradska, Novi Pazar'}, {'id': 'ChIJxeFASgApVkcReyRx8mlJrhA', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Oslobođenja 91, Novi Pazar, Serbia', 'location': {'latitude': 43.1348561, 'longitude': 20.5171694}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Devlet-Hanum Džamija (Krnja Džamija)', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Oslobođenja 91, Novi Pazar'}, {'id': 'ChIJ1wMMohEoVkcRcdz4otitv0I', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Oslobođenja, Novi Pazar, Serbia', 'location': {'latitude': 43.1353955, 'longitude': 20.5170285}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Atelje Prtinac', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Oslobođenja, Novi Pazar'}]
# obtaining places for point  52  /  115
# posting request
# obtained response
# []
# obtaining places for point  53  /  115
# posting request
# obtained response
# []
# obtaining places for point  54  /  115
# posting request
# obtained response
# []
# obtaining places for point  55  /  115
# posting request
# obtained response
# []
# obtaining places for point  56  /  115
# posting request
# obtained response
# [{'id': 'ChIJ0bERUs0pVkcR03kZCa-P7Ec', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': '409 DUBROVAČKA, 36300, Novi Pazar, Raški okrug, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1397538, 'longitude': 20.486193099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Abex', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': '409 DUBROVAČKA, 36300, Novi Pazar, Raški okrug'}, {'id': 'ChIJPyu79sMpVkcR4OPeZiRCLXw', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dubrovačka 412. 10, Novi Pazar, Serbia', 'location': {'latitude': 43.13815820000001, 'longitude': 20.482355}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Plej prodavnica', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dubrovačka 412. 10, Novi Pazar'}]
# obtaining places for point  57  /  115
# posting request
# obtained response
# []
# obtaining places for point  58  /  115
# posting request
# obtained response
# [{'id': 'ChIJh09BPQApVkcRqotegBu80zQ', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dubrovačka 402., Novi Pazar, Serbia', 'location': {'latitude': 43.1374077, 'longitude': 20.4938496}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'HANEFY Dzamija Mosque', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Dubrovačka 402., Novi Pazar'}]
# obtaining places for point  59  /  115
# posting request
# obtained response
# []
# obtaining places for point  60  /  115
# posting request
# obtained response
# [{'id': 'ChIJ8f-srjQpVkcRyGF4gP8unQA', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1368126, 'longitude': 20.5034538}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Šarova Džamija Lug', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Kolerina džamija u Lugu, Novi Pazar'}, {'id': 'ChIJNVCUawApVkcR7mo-LgW5_2U', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šumadijska 14, Novi Pazar, Serbia', 'location': {'latitude': 43.137809999999995, 'longitude': 20.5053371}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Edukativno Kulturni Centar', 'languageCode': 'de'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Šumadijska 14, Novi Pazar'}]
# obtaining places for point  61  /  115
# posting request
# obtained response
# [{'id': 'ChIJrR-YVRYoVkcR07nrsKC1sV0', 'types': ['primary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Cetinjska 10, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1372217, 'longitude': 20.508340399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Osnovna škola „Desanka Maksimović“', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Cetinjska 10, Novi Pazar'}, {'id': 'ChIJLeql2xUoVkcR5t8hudRCvH8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.139768499999995, 'longitude': 20.5091029}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Skola Kur'ana Casnog", 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Bor Dzamija, Novi Pazar'}, {'id': 'ChIJlYgAxy4pVkcRwF56xYoYT18', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Kragujevačka bb, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1400131, 'longitude': 20.5093067}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Medresa Gazi Isa-beg - žensko odjeljenje', 'languageCode': 'bs'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Kragujevačka bb, Novi Pazar'}]
# obtaining places for point  62  /  115
# posting request
# obtained response
# [{'id': 'ChIJM9k_ZBEoVkcR940GRevpLDE', 'types': ['cafe', 'cultural_center', 'food', 'point_of_interest', 'establishment'], 'formattedAddress': 'JAZ, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1378431, 'longitude': 20.5142223}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'KLUB HEROJA', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cafe', 'languageCode': 'en-US'}, 'primaryType': 'cafe', 'shortFormattedAddress': 'JAZ, Novi Pazar'}, {'id': 'ChIJW-vXDxQoVkcRUS2C4AgqPwU', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.139440199999996, 'longitude': 20.5126258}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dečji Vrtić "Mladost"', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJu-jjFwApVkcRE92fCwobf8Q', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Srđana Stojovića, Novi Pazar, Serbia', 'location': {'latitude': 43.136748499999996, 'longitude': 20.5145917}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kuri Česme Mosque', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Srđana Stojovića, Novi Pazar'}, {'id': 'ChIJdwUYaB8pVkcR-_rIpXOPeOU', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mitrovačka, Novi Pazar, Serbia', 'location': {'latitude': 43.1382079, 'longitude': 20.512751299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sports Institution Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Mitrovačka, Novi Pazar'}, {'id': 'ChIJAQDADxQoVkcR1zHbMON34vI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kej 37. sandžačke divizije, Novi Pazar, Serbia', 'location': {'latitude': 43.139394300000006, 'longitude': 20.5126296}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kindergarten', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Kej 37. sandžačke divizije, Novi Pazar'}, {'id': 'ChIJfZAcSAApVkcRyCgx9T6ZjCc', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1381328, 'longitude': 20.5164987}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sinan Begova Džamija', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJqUT0MO8pVkcR7BtFRtMgZ3I', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1367409, 'longitude': 20.5145235}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mula Ibiševa džamija', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJ3616KRIoVkcRECPuhL0R0_I', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1382094, 'longitude': 20.5163889}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Omladinski centar "Gazi Sinan-beg"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJ1wMMohEoVkcRkNNzQqvb-lw', 'types': ['school', 'point_of_interest', 'establish ...
# obtaining places for point  63  /  115
# posting request
# obtained response
# [{'id': 'ChIJQ9vG6g0oVkcRYx7GnUPM5-o', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Multifunkcijski Objekat Dunp-A, Vuka Karadžića бб, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.138246599999995, 'longitude': 20.5211132}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'State University of Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Мултифункцијски објекат ДУНП-а, Vuka Karadžića бб, Novi Pazar'}, {'id': 'ChIJy1JB9A0oVkcRC8J9cC9UOVY', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Vuka Karadžića, Novi Pazar, Serbia', 'location': {'latitude': 43.1383277, 'longitude': 20.519899799999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gymnasium of Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Vuka Karadžića, Novi Pazar'}, {'id': 'ChIJ-5v8bhIoVkcRj4-fVy8RrzQ', 'types': ['local_government_office', 'accounting', 'government_office', 'finance', 'point_of_interest', 'establishment'], 'formattedAddress': 'Под Хамам, 7. Jula BB, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1391454, 'longitude': 20.518883}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Uprava za naplatu javnih prihoda grada Novog Pazara', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Под Хамам, 7. Jula BB, Novi Pazar'}, {'id': 'ChIJPWC97EwpVkcRZoVmaPzh93w', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Gradska 1, Novi Pazar, Serbia', 'location': {'latitude': 43.137423299999995, 'longitude': 20.517951099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Madrasah Gazi Isa-beg', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Gradska 1, Novi Pazar'}, {'id': 'ChIJlZMaZhIoVkcRjtbIpHVvgaw', 'types': ['historical_landmark', 'historical_place', 'tourist_attraction', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1393639, 'longitude': 20.5188099}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Isa-bey's Hamam", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJdf43nG0vUxMR1ySgu2sPiIA', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '1. maja, Novi Pazar, Serbia', 'location': {'latitude': 43.1369034, 'longitude': 20.518788999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mezar rahmetli akademika Muftije Muamera Zukorlića', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': '1. maja, Novi Pazar'}, {'id': 'ChIJ80LPYhIoVkcRvQLzPQppHnE', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1396905, 'longitude': 20.5194924}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Komunalna Inspekcija Novi Pazar', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJNb4VWhIoVkcRvRymrWgOn6U', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi P ...
# obtaining places for point  64  /  115
# posting request
# obtained response
# []
# obtaining places for point  65  /  115
# posting request
# obtained response
# []
# obtaining places for point  66  /  115
# posting request
# obtained response
# []
# obtaining places for point  67  /  115
# posting request
# obtained response
# []
# obtaining places for point  68  /  115
# posting request
# obtained response
# []
# obtaining places for point  69  /  115
# posting request
# obtained response
# []
# obtaining places for point  70  /  115
# posting request
# obtained response
# []
# obtaining places for point  71  /  115
# posting request
# obtained response
# [{'id': 'ChIJR3RHiJgpVkcRkGSyKyf7-AE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'ulaz F, Рифата Бурџевића 209, Нови Пазар, Serbia', 'location': {'latitude': 43.1411011, 'longitude': 20.5045461}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'International Maarif Schools, Vrtić ,,MAARIF Kindergarten"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'ulaz F, Rifata Burdževića 209, Novi Pazar'}, {'id': 'ChIJ5fq0iBMoVkcRC6XUSRQANrI', 'types': ['real_estate_agency', 'general_contractor', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Rifata Burdževića 209b, Novi Pazar, Serbia', 'location': {'latitude': 43.141075099999995, 'longitude': 20.5060593}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'NOVA dpi', 'languageCode': 'sr-Latn'}, 'shortFormattedAddress': 'Rifata Burdževića 209b, Novi Pazar'}]
# obtaining places for point  72  /  115
# posting request
# obtained response
# [{'id': 'ChIJz9THFgQpVkcREopMdVSFS3Y', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sopoćanska 60, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.143585699999996, 'longitude': 20.5100504}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Škola slikanja i crtanja Novi Pazar Artisimo EZ🎨 prodaja umetničkih slika kreativne radionice', 'languageCode': 'sr'}, 'shortFormattedAddress': 'Sopoćanska 60, Novi Pazar'}, {'id': 'ChIJRQKnAxUoVkcRIGBB8OCXx9A', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Rifata Burdževića, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1417174, 'longitude': 20.511436099999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Djeciji vrtic "Reuda i Vildan" parice', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Rifata Burdževića, Novi Pazar'}, {'id': 'ChIJh1Ymgd4pVkcR2ADJbNdHxxM', 'types': ['museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sarajevska, Novi Pazar, Serbia', 'location': {'latitude': 43.141059, 'longitude': 20.5099736}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kuća Gicića', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Sarajevska, Novi Pazar'}, {'id': 'ChIJwfcNmhUoVkcRGRcA5akJ8nI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sarajevska 26, Novi Pazar, Serbia', 'location': {'latitude': 43.1411004, 'longitude': 20.5091344}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pet Plus', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Sarajevska 26, Novi Pazar'}, {'id': 'ChIJA30uYfkpVkcREqXWo_FdRNw', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sjenička 29, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1421405, 'longitude': 20.511254700000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'SEMERKAND', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Sjenička 29, Novi Pazar'}]
# obtaining places for point  73  /  115
# posting request
# obtained response
# [{'id': 'ChIJWeP9L2soVkcRIsSQXAHo9Lk', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '28. novembra, Novi Pazar, Serbia', 'location': {'latitude': 43.1436928, 'longitude': 20.5140442}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Економско Трговинска школа', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': '28. novembra, Novi Pazar'}, {'id': 'ChIJVVVVZBQoVkcRZhGYgknaWK4', 'types': ['government_office', 'police', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kej 37. sandžačke divizije, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.140530999999996, 'longitude': 20.5131634}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'МУП', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Government Office', 'languageCode': 'en-US'}, 'primaryType': 'government_office', 'shortFormattedAddress': 'Kej 37. sandžačke divizije, Novi Pazar'}, {'id': 'ChIJ1_BcLGkpVkcRVHH2M2CbTGA', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': '28. novembra br.54, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1431744, 'longitude': 20.515532099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Academia Ecco', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': '28. novembra br.54, Novi Pazar'}, {'id': 'ChIJJwRVECkpVkcRnYq0G-0Un3k', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1429482, 'longitude': 20.5148133}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sante Plus Hospital', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Novi Pazar'}, {'id': 'ChIJ7zUIHAApVkcRBgN1velC8Yg', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Deda Šehovića 53А, Novi Pazar, Serbia', 'location': {'latitude': 43.1416591, 'longitude': 20.5145789}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kuća Filipa Bogićevića', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Deda Šehovića 53А, Novi Pazar'}, {'id': 'ChIJf9TPVWsoVkcR1ATokBjVQCc', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šabana Koče, Novi Pazar, Serbia', 'location': {'latitude': 43.142988599999995, 'longitude': 20.515979299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Udruženje Sveetio', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Šabana Koče, Novi Pazar'}, {'id': 'ChIJbf69bwApVkcRPaPRIUAn5ss', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Rifata Burdževića 45, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1406938, 'longitude': 20.5152686}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Fizio As', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Rifata Burdževića 45, Novi Pazar'}]
# obtaining places for point  74  /  115
# posting request
# obtained response
# [{'id': 'ChIJRfTgOswpVkcR6pLsWsRlUSc', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '28. novembra 12, Novi Pazar, Serbia', 'location': {'latitude': 43.1408364, 'longitude': 20.5177265}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Centar Novog Pazara', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': '28. novembra 12, Novi Pazar'}, {'id': 'ChIJcfYJ5xIoVkcRag6j8scmK4s', 'types': ['cultural_center', 'performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stevana Nemanje 2, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1409054, 'longitude': 20.5184799}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'КЦ Нови Пазар', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Stevana Nemanje 2, Novi Pazar'}, {'id': 'ChIJOUAeJxMoVkcR7YlU4-4_06Q', 'types': ['museum', 'tourist_attraction', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stevana Nemanje 20, Novi Pazar, Serbia', 'location': {'latitude': 43.1415596, 'longitude': 20.5181389}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Museum Ras', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Stevana Nemanje 20, Novi Pazar'}, {'id': 'ChIJfSvb-hIoVkcReShePO4EACk', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stevana Nemanje 2, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1405446, 'longitude': 20.5183744}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska uprava Novi Pazar', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': 'Stevana Nemanje 2, Novi Pazar'}, {'id': 'ChIJ2wZWXTspVkcRbdit77uYWlA', 'types': ['courthouse', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Žitni trg 16, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1416201, 'longitude': 20.517704}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Основни суд у Новом Пазару', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Žitni trg 16, Novi Pazar'}, {'id': 'ChIJX18sJRMoVkcRJJHa_QjbVpI', 'types': ['courthouse', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Žitni trg 16, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.141745199999995, 'longitude': 20.5177074}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'High court', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'Žitni trg 16, Novi Pazar'}, {'id': 'ChIJz-GeoUMpVkcR3LWMX9EVf6E', 'types': ['courthouse', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'AVNOJ-a 16, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1417435, 'longitude': 20.517812}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Prekršajni sud u Novom Pazaru', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Courthouse', 'languageCode': 'en-US'}, 'primaryType': 'courthouse', 'shortFormattedAddress': 'AVNOJ-a 16, Novi Pazar'}, {'id': 'ChIJYa-VfOcpVkcRVoAnUJxu3Mk', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Prvog maja bb, Нови Пазар 36300, Serbia', 'location': {'latitude': 43.1409276, 'longitude': 20.5183955}, 'businessStatus': 'OPERATIONAL', ...
# obtaining places for point  75  /  115
# posting request
# obtained response
# []
# obtaining places for point  76  /  115
# posting request
# obtained response
# [{'id': 'ChIJE85_AQApVkcRhcC-ZoGLRC0', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Svojbor, Novi Pazar, Serbia', 'location': {'latitude': 43.1414654, 'longitude': 20.5278857}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hadzi Halit i Hadzi Zekije Gashi', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Svojbor, Novi Pazar'}]
# obtaining places for point  77  /  115
# posting request
# obtained response
# []
# obtaining places for point  78  /  115
# posting request
# obtained response
# []
# obtaining places for point  79  /  115
# posting request
# obtained response
# []
# obtaining places for point  80  /  115
# posting request
# obtained response
# []
# obtaining places for point  81  /  115
# posting request
# obtained response
# []
# obtaining places for point  82  /  115
# posting request
# obtained response
# []
# obtaining places for point  83  /  115
# posting request
# obtained response
# [{'id': 'ChIJWQzkFb0pVkcRU3KIRDyZUxQ', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Crkva Svetog Nikole, Miodraga Jovanovića 2, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1448039, 'longitude': 20.5146439}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'St. Nicholas Serbian Orthodox Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Црква Светог Николе, Miodraga Jovanovića 2, Novi Pazar'}, {'id': 'ChIJ6-KH4WooVkcRkS7WoruIxSk', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gornji Aleksinac, Novi Pazar, Serbia', 'location': {'latitude': 43.1446487, 'longitude': 20.513765799999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bukreska dzamija', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Gornji Aleksinac, Novi Pazar'}, {'id': 'ChIJ4S52eWooVkcR9Zy10eyS7B0', 'types': ['cemetery', 'historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1462593, 'longitude': 20.5120805}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Jewish Cemetery', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cemetery', 'languageCode': 'en-US'}, 'primaryType': 'cemetery', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  84  /  115
# posting request
# obtained response
# [{'id': 'ChIJ-2lLijcpVkcRWfaBSFddxow', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Relje Krilatice, Novi Pazar, Serbia', 'location': {'latitude': 43.1464893, 'longitude': 20.5182522}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto Skola XL 020 DOO', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Relje Krilatice, Novi Pazar'}, {'id': 'ChIJV0ZC8sYpVkcREp0xw6pXrts', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gojka Bačanina 50, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.146225799999996, 'longitude': 20.5189928}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Osnovna škola "Bratstvo"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Osnovna škola "Bratstvo", Gojka Bačanina 50, Novi Pazar'}, {'id': 'ChIJzwsCaWwoVkcRGMv__ZTPSaY', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Stane Bačanin 1, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1451948, 'longitude': 20.519175699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Дечији диспанзер', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Stane Bačanin 1, Novi Pazar'}, {'id': 'ChIJ294cfGwoVkcRz_YugjQvtQE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gojka Bačanina 99, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1467983, 'longitude': 20.5198367}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Akademija Oxford Novi Pazar - Škola stranih jezika i računara, sudski tumači i prevodioci za sve jezike', 'languageCode': 'en'}, 'shortFormattedAddress': 'Gojka Bačanina 99, Novi Pazar'}, {'id': 'ChIJjS_KRHMpVkcRDIpwtL-rp-k', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gojka Bačanina 99, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.146936, 'longitude': 20.5200718}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola "Nikola Tesla", Novi Pazar', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Gojka Bačanina 99, Novi Pazar'}, {'id': 'ChIJvUTZZAApVkcRcRt-GUJe6JM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gojka Bačanina, Novi Pazar, Serbia', 'location': {'latitude': 43.145741099999995, 'longitude': 20.5193236}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vrtić NAŠE DETE', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Gojka Bačanina, Novi Pazar'}, {'id': 'ChIJ4y7N5TMpVkcRNpcf9RKdEBw', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Relje Krilatice 27, Novi Pazar, Serbia', 'location': {'latitude': 43.146234, 'longitude': 20.5174707}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zgrada "Mitropolija"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Relje Krilatice 27, Novi Pazar'}, {'id': 'ChIJNT8oDWwoVkcRwOyDMS7K17g', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Gojka Bačanina, Novi Pazar, Serbia', 'location': {'latitude': 43.1457963, 'longitude': 20.518960999999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Обданиште Младост', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US' ...
# obtaining places for point  85  /  115
# posting request
# obtained response
# []
# obtaining places for point  86  /  115
# posting request
# obtained response
# [{'id': 'ChIJgw58mLApVkcRv4gZ17ctr60', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Save Kovačevića 50a, Нови Пазар 36300, Serbia', 'location': {'latitude': 43.1458265, 'longitude': 20.527538399999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola "Hipokrat"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Save Kovačevića 50a, Novi Pazar'}, {'id': 'ChIJfbBIQUQpVkcRSFwrVmhQjX8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1453286, 'longitude': 20.527908999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Medicinska škola Hipokrat', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  87  /  115
# posting request
# obtained response
# []
# obtaining places for point  88  /  115
# posting request
# obtained response
# []
# obtaining places for point  89  /  115
# posting request
# obtained response
# []
# obtaining places for point  90  /  115
# posting request
# obtained response
# [{'id': 'ChIJqcM5WwApVkcR41pgjFy_u_o', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Donji Aleksinac 63Г, Novi Pazar, Serbia', 'location': {'latitude': 43.1487589, 'longitude': 20.5052117}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Džamija u Eroziju', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Donji Aleksinac 63Г, Novi Pazar'}]
# obtaining places for point  91  /  115
# posting request
# obtained response
# []
# obtaining places for point  92  /  115
# posting request
# obtained response
# []
# obtaining places for point  93  /  115
# posting request
# obtained response
# []
# obtaining places for point  94  /  115
# posting request
# obtained response
# []
# obtaining places for point  95  /  115
# posting request
# obtained response
# []
# obtaining places for point  96  /  115
# posting request
# obtained response
# []
# obtaining places for point  97  /  115
# posting request
# obtained response
# []
# obtaining places for point  98  /  115
# posting request
# obtained response
# []
# obtaining places for point  99  /  115
# posting request
# obtained response
# []
# obtaining places for point  100  /  115
# posting request
# obtained response
# []
# obtaining places for point  101  /  115
# posting request
# obtained response
# []
# obtaining places for point  102  /  115
# posting request
# obtained response
# []
# obtaining places for point  103  /  115
# posting request
# obtained response
# [{'id': 'ChIJrbjFemMoVkcRPa2rfngGUBo', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dimitrija Tucovića bb, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.1543017, 'longitude': 20.5289328}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Erwin Transport d.o.o', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Dimitrija Tucovića bb, Novi Pazar'}]
# obtaining places for point  104  /  115
# posting request
# obtained response
# []
# obtaining places for point  105  /  115
# posting request
# obtained response
# []
# obtaining places for point  106  /  115
# posting request
# obtained response
# []
# obtaining places for point  107  /  115
# posting request
# obtained response
# []
# obtaining places for point  108  /  115
# posting request
# obtained response
# []
# obtaining places for point  109  /  115
# posting request
# obtained response
# [{'id': 'ChIJr2l9IpUpVkcR0V_0LBh_Sng', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.156689799999995, 'longitude': 20.5252566}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto skola XL ABCDE Poligon', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  110  /  115
# posting request
# obtained response
# [{'id': 'ChIJsTyfH2MoVkcRpG_a-Jb7gQI', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dimitrija Tucovića 65, Novi Pazar 36300, Serbia', 'location': {'latitude': 43.156267799999995, 'longitude': 20.530900700000004}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'University of Novi Pazar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Dimitrija Tucovića 65, Novi Pazar'}]
# obtaining places for point  111  /  115
# posting request
# obtained response
# [{'id': 'ChIJj32DT30oVkcRrQ_mtA35x4E', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.157168899999995, 'longitude': 20.5344083}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja Medicinska Škola HIPOKRAT S/M', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Novi Pazar'}]
# obtaining places for point  112  /  115
# posting request
# obtained response
# []
# obtaining places for point  113  /  115
# posting request
# obtained response
# [{'id': 'ChIJrcYq9PQoVkcRGoFvgeLsUTY', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Slava Raškovića 147, Novi Pazar, Serbia', 'location': {'latitude': 43.1613477, 'longitude': 20.527542699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of the Holy Apostles Peter and Paul', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Slava Raškovića 147, Novi Pazar'}, {'id': 'ChIJ_5xXc4ooVkcRxPHd3VtlujQ', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Pazar, Serbia', 'location': {'latitude': 43.1596654, 'longitude': 20.5268303}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Основна школа „Меша Селимовић"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Primary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Основна Школа "Меша Селимовић", Novi Pazar'}]
# obtaining places for point  114  /  115
# posting request
# obtained response
# [{'id': 'ChIJ81QusagpVkcRytD2-dFkBWY', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Save Kovačevića, Novi Pazar, Serbia', 'location': {'latitude': 43.1587093, 'longitude': 20.535037799999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Specijalna Skola Hipokrat', 'languageCode': 'de'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Save Kovačevića, Novi Pazar'}]

# %%
# ensure no points which reached the 20-place cutoff from Google
idxs_of_problem_spots = [i for i, pt in enumerate(points_lst) if len(list(pt.values())[0]) > 19]
idxs_of_problem_spots
# Out:
# []

# %%
city_gdf = clean_maps_api_output(points_lst)

city_gdf.to_file("/mnt/c/Users/natra/Documents/Research/Identity-Conflict/serbia_files/clean/novi_pazar_locs_400x400.geojson",
                          driver='GeoJSON')
# Out:
# Number of place dictionaries returned from API:  43
# Shape of resulting dataframe:  (117, 13)
# Shape of dataframe after dropping dups:  (117, 13)

# %% [markdown]
# ### Novi Sad

# %%
# created grid in as 400 x 400 w x h grids with Fishnet tool in ArcGIS Pro
grid = gpd.read_file('./serbia_files/raw/site_locations/novi-sad-fishnet-clip-4326.shp')
print(grid.shape)
print(grid.crs)
grid.head()
# Out:
# (546, 2)
# EPSG:4326
#    Id                   geometry
# 0   0  POINT (19.80307 45.22342)
# 1   0  POINT (19.80816 45.22347)
# 2   0  POINT (19.81326 45.22353)
# 3   0  POINT (19.81835 45.22358)
# 4   0  POINT (19.78262 45.22681)

# %%
points_lst = obtain_places_from_points(url, headers, grid, 200)
# Out:
# obtaining places for point  0  /  546
# posting request
# obtained response
# []
# obtaining places for point  1  /  546
# posting request
# obtained response
# []
# obtaining places for point  2  /  546
# posting request
# obtained response
# []
# obtaining places for point  3  /  546
# posting request
# obtained response
# []
# obtaining places for point  4  /  546
# posting request
# obtained response
# [{'id': 'ChIJGXBCTzAOW0cRNuxPFj_65bE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kamenjar 3 br. 7, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2280387, 'longitude': 19.7836914}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Privatna osnovna škola "Kirilo i Metodije" Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Kamenjar 3 br. 7, Novi Sad'}]
# obtaining places for point  5  /  546
# posting request
# obtained response
# []
# obtaining places for point  6  /  546
# posting request
# obtained response
# []
# obtaining places for point  7  /  546
# posting request
# obtained response
# []
# obtaining places for point  8  /  546
# posting request
# obtained response
# []
# obtaining places for point  9  /  546
# posting request
# obtained response
# []
# obtaining places for point  10  /  546
# posting request
# obtained response
# []
# obtaining places for point  11  /  546
# posting request
# obtained response
# []
# obtaining places for point  12  /  546
# posting request
# obtained response
# []
# obtaining places for point  13  /  546
# posting request
# obtained response
# []
# obtaining places for point  14  /  546
# posting request
# obtained response
# [{'id': 'ChIJy3f-CwAPW0cRB6xydITFZjM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Светогорска 48, Veternik, Serbia', 'location': {'latitude': 45.2317985, 'longitude': 19.767634899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pizza edukacija', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Светогорска 48, Veternik'}]
# obtaining places for point  15  /  546
# posting request
# obtained response
# []
# obtaining places for point  16  /  546
# posting request
# obtained response
# []
# obtaining places for point  17  /  546
# posting request
# obtained response
# [{'id': 'ChIJ38Z1IcgPW0cRlCX8lDkgteA', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kamenjar 3, Novi Sad, Serbia', 'location': {'latitude': 45.2286815, 'longitude': 19.782709}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'rakovac', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Kamenjar 3, Novi Sad'}]
# obtaining places for point  18  /  546
# posting request
# obtained response
# []
# obtaining places for point  19  /  546
# posting request
# obtained response
# [{'id': 'ChIJ6dDLagAPW0cRbJfH0JK3lY4', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Adice, Novi Sad, Serbia', 'location': {'latitude': 45.230542799999995, 'longitude': 19.794193699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Adice Mosque', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Novi Sad'}]
# obtaining places for point  20  /  546
# posting request
# obtained response
# []
# obtaining places for point  21  /  546
# posting request
# obtained response
# []
# obtaining places for point  22  /  546
# posting request
# obtained response
# []
# obtaining places for point  23  /  546
# posting request
# obtained response
# []
# obtaining places for point  24  /  546
# posting request
# obtained response
# []
# obtaining places for point  25  /  546
# posting request
# obtained response
# []
# obtaining places for point  26  /  546
# posting request
# obtained response
# []
# obtaining places for point  27  /  546
# posting request
# obtained response
# []
# obtaining places for point  28  /  546
# posting request
# obtained response
# [{'id': 'ChIJMb75O9IRW0cRTafCOOcTuqk', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ribarsko ostrvo, Novi Sad 21000, Serbia', 'location': {'latitude': 45.230138499999995, 'longitude': 19.8363569}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'KSV Danubius', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ribarsko ostrvo, Novi Sad'}]
# obtaining places for point  29  /  546
# posting request
# obtained response
# []
# obtaining places for point  30  /  546
# posting request
# obtained response
# [{'id': 'ChIJG8XQZqoPW0cRGvDqTXw9GjE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Olivere Marković 39, Novi Sad 21000, Serbia', 'location': {'latitude': 45.23299, 'longitude': 19.7693205}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Časovi matematike "Računko"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Olivere Marković 39, Novi Sad'}]
# obtaining places for point  31  /  546
# posting request
# obtained response
# []
# obtaining places for point  32  /  546
# posting request
# obtained response
# []
# obtaining places for point  33  /  546
# posting request
# obtained response
# [{'id': 'ChIJNWS3rCgOW0cR-OsYdeluXXc', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Sad, Serbia', 'location': {'latitude': 45.2342039, 'longitude': 19.7848854}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Serbian Orthodox Church of St Parasceva.', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Novi Sad'}]
# obtaining places for point  34  /  546
# posting request
# obtained response
# [{'id': 'ChIJ_SM8mMwPW0cRqjxBESy1y-4', 'types': ['preschool', 'child_care_agency', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Sime Šolaje bb, Novi Sad, Serbia', 'location': {'latitude': 45.234335099999996, 'longitude': 19.786706199999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PU "Radosno detinjstvo" vrtić "Radosnica"', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Sime Šolaje bb, Novi Sad'}, {'id': 'ChIJResKBNUPW0cR5QHCFhsj2Jo', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sime Šolaje 2a, Novi Sad, Serbia', 'location': {'latitude': 45.2338782, 'longitude': 19.786847299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Mesna zajednica Adice', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Sime Šolaje 2a, Novi Sad'}]
# obtaining places for point  35  /  546
# posting request
# obtained response
# []
# obtaining places for point  36  /  546
# posting request
# obtained response
# []
# obtaining places for point  37  /  546
# posting request
# obtained response
# []
# obtaining places for point  38  /  546
# posting request
# obtained response
# [{'id': 'ChIJRakjABQPW0cRmWsECeCMM8g', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Izvidnička 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.234172799999996, 'longitude': 19.8094292}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Predškolska ustanova “Bambino”', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Izvidnička 2, Novi Sad'}]
# obtaining places for point  39  /  546
# posting request
# obtained response
# []
# obtaining places for point  40  /  546
# posting request
# obtained response
# [{'id': 'ChIJ7bBfdycQW0cREIAZQ0KwKdQ', 'types': ['car_wash', 'local_government_office', 'car_repair', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Heroja Pinkija 64, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2339026, 'longitude': 19.8164435}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'NS Total 021- tehnički pregled i registracija vozila NOVI SAD', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Heroja Pinkija 64, Novi Sad'}, {'id': 'ChIJ3xLYk9sRW0cRvdLZ96O8294', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mornarska 30A, Нови Сад 21000, Serbia', 'location': {'latitude': 45.2343745, 'longitude': 19.818856999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Casovi matematike Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Mornarska 30A, Novi Sad'}, {'id': 'ChIJN86d9EcRW0cRBFUuHFnOzGw', 'types': ['car_rental', 'car_wash', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Heroja Pinkija 64, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2339026, 'longitude': 19.8164435}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'NS TOTAL 021- Rentiranje automobila (RENT A CAR) Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Car Rental Agency', 'languageCode': 'en-US'}, 'primaryType': 'car_rental', 'shortFormattedAddress': 'Heroja Pinkija 64, Novi Sad'}, {'id': 'ChIJD5CTuTIRW0cRzqKl-wdyhIY', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Heroja Pinkija 63а, Novi Sad 21000, Serbia', 'location': {'latitude': 45.234633099999996, 'longitude': 19.8180144}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Приватна предшколска установа "Лилипит"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Heroja Pinkija 63а, Novi Sad'}]
# obtaining places for point  41  /  546
# posting request
# obtained response
# []
# obtaining places for point  42  /  546
# posting request
# obtained response
# [{'id': 'ChIJ942TFM4RW0cRsMO1PLCPnU8', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': '1300 kaplara 11, Novi Sad 21000, Serbia', 'location': {'latitude': 45.234584899999994, 'longitude': 19.8291173}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Црква Светог Стефана- Морнарица', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': '1300 kaplara 11, Novi Sad'}, {'id': 'ChIJaeKz4iEQW0cR-MMpzLQXGEo', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ive Andrića, Novi Sad, Serbia', 'location': {'latitude': 45.235569899999994, 'longitude': 19.8277611}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PH DIAGNOSTIC CENTER', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Ive Andrića, Novi Sad'}]
# obtaining places for point  43  /  546
# posting request
# obtained response
# []
# obtaining places for point  44  /  546
# posting request
# obtained response
# []
# obtaining places for point  45  /  546
# posting request
# obtained response
# [{'id': 'ChIJZXCglYkRW0cRHfBIEw27HVs', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Sad, Serbia', 'location': {'latitude': 45.235763, 'longitude': 19.845500899999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ogranak Gradske Biblioteke Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Novi Sad'}]
# obtaining places for point  46  /  546
# posting request
# obtained response
# []
# obtaining places for point  47  /  546
# posting request
# obtained response
# []
# obtaining places for point  48  /  546
# posting request
# obtained response
# []
# obtaining places for point  49  /  546
# posting request
# obtained response
# []
# obtaining places for point  50  /  546
# posting request
# obtained response
# []
# obtaining places for point  51  /  546
# posting request
# obtained response
# []
# obtaining places for point  52  /  546
# posting request
# obtained response
# []
# obtaining places for point  53  /  546
# posting request
# obtained response
# []
# obtaining places for point  54  /  546
# posting request
# obtained response
# [{'id': 'ChIJpRpU-ysOW0cRsMCs_ECoc4A', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': '46 Branka Ćopića, 21000, Novi Sad, Južno-bački okrug, Novi Sad 21000, Serbia', 'location': {'latitude': 45.236081299999995, 'longitude': 19.7969684}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Tufnica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': '46 Branka Ćopića, 21000, Novi Sad, Južno-bački okrug'}, {'id': 'ChIJVz1BhSoOW0cR935cp4eRT1k', 'types': ['preschool', 'school', 'child_care_agency', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kneza Vlastimira 29, Novi Sad 21123, Serbia', 'location': {'latitude': 45.2360882, 'longitude': 19.7969771}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Predškolska ustanova Tufnica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Kneza Vlastimira 29, Novi Sad'}]
# obtaining places for point  55  /  546
# posting request
# obtained response
# []
# obtaining places for point  56  /  546
# posting request
# obtained response
# [{'id': 'ChIJZ8Sj_SsQW0cRRpxk3hHDn7s', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šarplaninska 19, Novi Sad 21000, Serbia', 'location': {'latitude': 45.239131, 'longitude': 19.809009}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ferona', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Šarplaninska 19, Novi Sad'}, {'id': 'ChIJUf6d0ysQW0cRwumAzXuQnB8', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Šarplaninska 28, Novi Sad 21124, Serbia', 'location': {'latitude': 45.237235, 'longitude': 19.807667}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Primary School Jozef Atila', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Šarplaninska 28, Novi Sad'}, {'id': 'ChIJ7TP7cSkQW0cRhJVBGpk8tWM', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ćirila i Metodija 69, Novi Sad 21102, Serbia', 'location': {'latitude': 45.238171099999995, 'longitude': 19.809184400000003}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': '"Dunavski cvet"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ćirila i Metodija 69, Novi Sad'}]
# obtaining places for point  57  /  546
# posting request
# obtained response
# [{'id': 'ChIJn9buLykQW0cRLyWckKBFWgs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Feješ Klare, Novi Sad, Serbia', 'location': {'latitude': 45.238361499999996, 'longitude': 19.8113135}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of Saints Cyril and Methodius', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Feješ Klare, Novi Sad'}, {'id': 'ChIJw90ZKC8QW0cRztUMYJWST1I', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ulica Petefi Šandora 27, Novi Sad, Serbia', 'location': {'latitude': 45.239478999999996, 'longitude': 19.813016299999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zemlja Čuda', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ulica Petefi Šandora 27, Novi Sad'}, {'id': 'ChIJifwh4Q0RW0cRuTNrxCiGNWs', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ulica Petefi Šandora 30, Novi Sad 21000, Serbia', 'location': {'latitude': 45.239653, 'longitude': 19.8131091}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi život u Hristu', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ulica Petefi Šandora 30, Novi Sad'}]
# obtaining places for point  58  /  546
# posting request
# obtained response
# [{'id': 'ChIJZ0TODSYQW0cRI2lawztlfKw', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ćirila i Metodija 46, Novi Sad 21000, Serbia', 'location': {'latitude': 45.237764899999995, 'longitude': 19.817091299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Church of Saint Elizabeth of Hungary', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Roman Catholic Church St. Elizabeth of Hungary, Ćirila i Metodija 46, Novi Sad'}, {'id': 'ChIJba1p0iUQW0cR78_1g8lPKNY', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ćirila i Metodija, Novi Sad, Serbia', 'location': {'latitude': 45.2383333, 'longitude': 19.818888899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Reformed Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Ćirila i Metodija, Novi Sad'}]
# obtaining places for point  59  /  546
# posting request
# obtained response
# [{'id': 'ChIJWQ-FM2oQW0cRCfaqtUj1NQg', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Heroja Pinkija 4, Novi Sad 21000, Serbia', 'location': {'latitude': 45.238127000000006, 'longitude': 19.822872399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Farmaceutski fakultet', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Heroja Pinkija 4, Novi Sad'}, {'id': 'ChIJCe45bCEQW0cRY4nGZBsPZl4', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Laze Lazarevića 28, Novi Sad 21000, Serbia', 'location': {'latitude': 45.236236399999996, 'longitude': 19.8231158}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Opšta bolnica sa porodilištem GEA', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Laze Lazarevića 28, Novi Sad'}, {'id': 'ChIJVc2W5e0RW0cRJzvpX9yhFZ8', 'types': ['hospital', 'doctor', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Laze Lazarevića 15a, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2371544, 'longitude': 19.8222448}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Hirurški Centar Popović', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Doctor', 'languageCode': 'en-US'}, 'primaryType': 'doctor', 'shortFormattedAddress': 'Laze Lazarevića 15a, Novi Sad'}, {'id': 'ChIJQba394MRW0cRNw0GN1dxryo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Laze Lazarevića 14, Novi Sad 21000, Serbia', 'location': {'latitude': 45.237607800000006, 'longitude': 19.8214176}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vanilla Caffe Poslastičarnica', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Laze Lazarevića 14, Novi Sad'}, {'id': 'ChIJhXnffhkRW0cREHR1rynm0HY', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Sad, Serbia', 'location': {'latitude': 45.239608499999996, 'longitude': 19.8227056}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vrtić Kolibri Novi Sad juče', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Novi Sad'}, {'id': 'ChIJpxNeEwARW0cRJkrVued9C6I', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Sad, Serbia', 'location': {'latitude': 45.239608499999996, 'longitude': 19.8227056}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi aad', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Novi Sad'}, {'id': 'ChIJSyaeVQARW0cR94lq0idweDE', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Рядом с этим, местом:Нови Сад, Serbia', 'location': {'latitude': 45.239608499999996, 'longitude': 19.8227056}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Klisa Psihijatrija', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Рядом с этим, местом:Нови Сад'}]
# obtaining places for point  60  /  546
# posting request
# obtained response
# [{'id': 'ChIJUz2WdyIQW0cR2k_ECCBVdtQ', 'types': ['hospital', 'doctor', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta 73a, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2377483, 'longitude': 19.829857099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Healthmedic', 'languageCode': 'en'}, 'shortFormattedAddress': 'Narodnog fronta 73a, Novi Sad'}, {'id': 'ChIJR6ucjiIQW0cRlBqkiwz6xE0', 'types': ['preschool', 'school', 'child_care_agency', 'point_of_interest', 'establishment'], 'formattedAddress': 'Banović Strahinje, Novi Sad 403462, Serbia', 'location': {'latitude': 45.238877599999995, 'longitude': 19.828837699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Новосађанче', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Banović Strahinje, Novi Sad'}, {'id': 'ChIJqdDDufMRW0cRgk_akIZxlqo', 'types': ['community_center', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Banović Strahinje 16-20, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2379014, 'longitude': 19.828750499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Local Community Center Ivo Andric', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Community Center', 'languageCode': 'en-US'}, 'primaryType': 'community_center', 'shortFormattedAddress': 'Banović Strahinje 16-20, Novi Sad'}, {'id': 'ChIJAQAAjyIQW0cRLG_1szJFD_A', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Banović Strahinje, Novi Sad 403462, Serbia', 'location': {'latitude': 45.238841799999996, 'longitude': 19.8290732}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Radosno detinjstvo', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Banović Strahinje, Novi Sad'}]
# obtaining places for point  61  /  546
# posting request
# obtained response
# [{'id': 'ChIJD_n7GhkQW0cRv0kryKslSWI', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Balzakova 44, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2370474, 'longitude': 19.8330427}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dom zdravlja MediGroup Balzakova', 'languageCode': 'en'}, 'shortFormattedAddress': 'Balzakova 44, Novi Sad'}, {'id': 'ChIJp_bAkxkQW0cRj4vCpbG9vcs', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta 45, Novi Sad 21102, Serbia', 'location': {'latitude': 45.2381926, 'longitude': 19.8355945}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Vrtić Različak', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Vrtić Različak, PU Radosno Detinjstvo, Narodnog fronta 45, Novi Sad'}, {'id': 'ChIJt-fKyxkQW0cRoiaFayMQvA4', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta 47, Novi Sad 21102, Serbia', 'location': {'latitude': 45.238901399999996, 'longitude': 19.8344277}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Библиотека „Данило Киш”', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Narodnog fronta 47, Novi Sad'}, {'id': 'ChIJK2ZzF_cRW0cRGQntmjZP9V0', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Balzakova 43, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2372708, 'longitude': 19.833852}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Centar stranih jezika Alfabet', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Balzakova 43, Novi Sad'}, {'id': 'ChIJEyS1HdERW0cRIdOa4N5BwxM', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta 53, Novi Sad 21102, Serbia', 'location': {'latitude': 45.238987099999996, 'longitude': 19.834194999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'ЈКП „Лисје” - благајна', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Narodnog fronta 53, Novi Sad'}, {'id': 'ChIJd82BiHURW0cREXoE622gYjY', 'types': ['performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2382232, 'longitude': 19.8313637}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Acrodance', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Performing Arts Theater', 'languageCode': 'en-US'}, 'primaryType': 'performing_arts_theater', 'shortFormattedAddress': 'Narodnog fronta, Novi Sad'}, {'id': 'ChIJmS4gUrsRW0cRn0XalZEsTJg', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Balzakova 71, Novi Sad, Serbia', 'location': {'latitude': 45.2376979, 'longitude': 19.835450299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sveta', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Balzakova 71, Novi Sad'}]
# obtaining places for point  62  /  546
# posting request
# obtained response
# [{'id': 'ChIJv0-VKxoQW0cRyPLZpCvohZM', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana 8, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2373116, 'longitude': 19.8364682}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary School "Žarko Zrenjanin"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Bulevar despota Stefana 8, Novi Sad'}, {'id': 'ChIJd9wdRxoQW0cRqWwpxhaVPYA', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.237510799999995, 'longitude': 19.8383532}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Nikolin', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Bulevar despota Stefana 2, Novi Sad'}, {'id': 'ChIJbVD7VhcQW0cRvidFETYRBTc', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnog fronta, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2395095, 'longitude': 19.8371691}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Play Garden', 'languageCode': 'en'}, 'shortFormattedAddress': 'Narodnog fronta, Novi Sad'}]
# obtaining places for point  63  /  546
# posting request
# obtained response
# [{'id': 'ChIJcw3ZsRoQW0cRQSQqT-Tr7lk', 'types': ['cultural_center', 'night_club', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana 5, Novi Sad 403203, Serbia', 'location': {'latitude': 45.2376346, 'longitude': 19.8425062}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'SKCNS Fabrika', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Кинеска четврт, Bulevar despota Stefana 5, Novi Sad'}, {'id': 'ChIJ901rjGcQW0cRICrDBaUFzRQ', 'types': ['cultural_center', 'library', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana 5, Novi Sad 21000, Serbia', 'location': {'latitude': 45.237505, 'longitude': 19.8416764}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Institut français de Serbie à Novi Sad / Француски институт у Србији у Новом Саду', 'languageCode': 'fr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Кинеска четврт, Bulevar despota Stefana 5, Novi Sad'}, {'id': 'ChIJV0rTl9YRW0cRxa3XZPG9mKE', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana, Novi Sad 403203, Serbia', 'location': {'latitude': 45.2371177, 'longitude': 19.841608}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kulturna stanica OPENS', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Кинеска четврт, Bulevar despota Stefana, Novi Sad'}, {'id': 'ChIJe6mIjyYRW0cRc0zMF4k_Cck', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar despota Stefana, Novi Sad 403203, Serbia', 'location': {'latitude': 45.2374728, 'longitude': 19.8416556}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Škola Francuskog jezika', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Кинеска четврт, Bulevar despota Stefana, Novi Sad'}]
# obtaining places for point  64  /  546
# posting request
# obtained response
# [{'id': 'ChIJh2YXuw8QW0cREtd3BwUpToQ', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Fruškogorska 32, Novi Sad, Serbia', 'location': {'latitude': 45.239197, 'longitude': 19.8471357}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Геронтолошки центар Нови Сад', 'languageCode': 'sr'}, 'shortFormattedAddress': 'Fruškogorska 32, Novi Sad'}]
# obtaining places for point  65  /  546
# posting request
# obtained response
# []
# obtaining places for point  66  /  546
# posting request
# obtained response
# []
# obtaining places for point  67  /  546
# posting request
# obtained response
# [{'id': 'ChIJkXCfC-IRW0cRH0M14tdXpSw', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Paunova 14, Veternik, Serbia', 'location': {'latitude': 45.2424104, 'longitude': 19.7673864}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Elementary School "Marija Trandafil"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Paunova 14, Veternik'}, {'id': 'ChIJyeaP-x0OW0cRULeDXG0wVMc', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Paunova, Veternik, Serbia', 'location': {'latitude': 45.241660700000004, 'longitude': 19.767985}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Рода', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Paunova, Veternik'}]
# obtaining places for point  68  /  546
# posting request
# obtained response
# []
# obtaining places for point  69  /  546
# posting request
# obtained response
# [{'id': 'ChIJ82LOoN8RW0cRl_8qqa2xpTk', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': '3 BRANKA ILICA, 21000, Novi Sad, Juzno-backi county, Novi Sad, Serbia', 'location': {'latitude': 45.242123899999996, 'longitude': 19.7782636}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Grin-Auto', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': '3 BRANKA ILICA, 21000, Novi Sad, Juzno-backi county'}]
# obtaining places for point  70  /  546
# posting request
# obtained response
# [{'id': 'ChIJS0bVKN8RW0cRSWPI4Uk85q4', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': '3 DOMENTIJANOVA, 21000, Novi Sad, Južno-bački okrug, Novi Sad, Serbia', 'location': {'latitude': 45.241649699999996, 'longitude': 19.782185}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Divic', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': '3 DOMENTIJANOVA, 21000, Novi Sad, Južno-bački okrug'}]
# obtaining places for point  71  /  546
# posting request
# obtained response
# [{'id': 'ChIJVf4hA9kRW0cRAO3RdzwSlJg', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Suvoborska 6 Novi Sad RS, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2419929, 'longitude': 19.785333599999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja medicinska skola "Dositej Obradovic"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Suvoborska 6 Novi Sad RS'}, {'id': 'ChIJJYlGeNgRW0cRbd_wFMA1SlA', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Suvoborska 6, Novi Sad 21000, Serbia', 'location': {'latitude': 45.241476299999995, 'longitude': 19.7852815}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja stručna škola Krug', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Suvoborska 6, Novi Sad'}, {'id': 'ChIJFQ9ys58RW0cRaCf5PSY_uhg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Suvoborska 23, Novi Sad, Serbia', 'location': {'latitude': 45.2400034, 'longitude': 19.7856097}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Krošnjica Edukativni centar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Suvoborska 23, Novi Sad'}]
# obtaining places for point  72  /  546
# posting request
# obtained response
# []
# obtaining places for point  73  /  546
# posting request
# obtained response
# [{'id': 'ChIJezN2BsIRW0cRSgkURdOZx8c', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ulica Petefi Šandora 153, Novi Sad, Serbia', 'location': {'latitude': 45.241073899999996, 'longitude': 19.7964214}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dobra vila', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ulica Petefi Šandora 153, Novi Sad'}, {'id': 'ChIJ7X3FENERW0cRKJAwXDMipBs', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar patrijarha Pavla 123, Novi Sad 21000, Serbia', 'location': {'latitude': 45.241900199999996, 'longitude': 19.7967482}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'interdoors', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Bulevar patrijarha Pavla 123, Novi Sad'}, {'id': 'ChIJp5CFz9MRW0cRE_Ro3U8kaRY', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ulica Petefi Šandora 156a, Novi Sad 21000, Serbia', 'location': {'latitude': 45.241273799999995, 'longitude': 19.7973565}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Bauriss', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Ulica Petefi Šandora 156a, Novi Sad'}]
# obtaining places for point  74  /  546
# posting request
# obtained response
# [{'id': 'ChIJvxQZei4RW0cRmExsyS5vJJQ', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar patrijarha Pavla 26A, Novi Sad 21102, Serbia', 'location': {'latitude': 45.2416781, 'longitude': 19.8037588}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Emergency medical center Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Bulevar patrijarha Pavla 26A, Novi Sad'}, {'id': 'ChIJjw_KEooRW0cR6FXLF7RKGr4', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Jastrebačka 43, Novi Sad 21124, Serbia', 'location': {'latitude': 45.2421722, 'longitude': 19.804354099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'PU Dolina Suncokreta', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Jastrebačka 43, Novi Sad'}, {'id': 'ChIJB7Z4EB8RW0cRbT67D8tAot0', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar patrijarha Pavla 89, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2412384, 'longitude': 19.8034042}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Informativni centar Acibadem Novi Sad/Srbija', 'languageCode': 'en'}, 'shortFormattedAddress': 'Bulevar patrijarha Pavla 89, Novi Sad'}]
# obtaining places for point  75  /  546
# posting request
# obtained response
# [{'id': 'ChIJiwq2p20QW0cRRTIv3CNj7OU', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ulica Petefi Šandora 86a, Novi Sad 21000, Serbia', 'location': {'latitude': 45.24024740000001, 'longitude': 19.806710499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Maštolend', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Ulica Petefi Šandora 86a, Novi Sad'}, {'id': 'ChIJeTZyqYIRW0cRJOcYFP1lahg', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Ilirska 46, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2425794, 'longitude': 19.8062182}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Edukativni centar Montessori School Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Ilirska 46, Novi Sad'}, {'id': 'ChIJ9TtiQCwQW0cRv32h57VEj-E', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar patrijarha Pavla, Novi Sad, Serbia', 'location': {'latitude': 45.2409968, 'longitude': 19.808633699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Škola Kreativne Fotografije - Lumière', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Bulevar patrijarha Pavla, Novi Sad'}, {'id': 'ChIJx1mpIAARW0cR1utflsq1Utw', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar patrijarha Pavla, Novi Sad, Serbia', 'location': {'latitude': 45.2409968, 'longitude': 19.808633699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'singidunum university', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'College', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Bulevar patrijarha Pavla, Novi Sad'}]
# obtaining places for point  76  /  546
# posting request
# obtained response
# []
# obtaining places for point  77  /  546
# posting request
# obtained response
# [{'id': 'ChIJU9PgmDMQW0cR3Vl7V_ApD3Q', 'types': ['insurance_agency', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Subotička 69, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2414267, 'longitude': 19.8159502}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Moto Grad Novi Sad Tehnički pregled, Registracija vozila,Osiguranje', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Subotička 69, Novi Sad'}, {'id': 'ChIJQRwNZAARW0cRTNLY-VEeI4o', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dalmatinska 32, Novi Sad 406015, Serbia', 'location': {'latitude': 45.2402586, 'longitude': 19.8187428}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Veselina Maslese 22', 'languageCode': 'hr'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Dalmatinska 32, Novi Sad'}, {'id': 'ChIJY4EJSQARW0cRzmnv3XHbfgg', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Milutina Bojića, Novi Sad 406025, Serbia', 'location': {'latitude': 45.2428939, 'longitude': 19.8172711}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi Sad', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Milutina Bojića, Novi Sad'}]
# obtaining places for point  78  /  546
# posting request
# obtained response
# [{'id': 'ChIJBS7xzsYRW0cRU1L3knUCBw0', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Evrope 7, Novi Sad 406018, Serbia', 'location': {'latitude': 45.2411524, 'longitude': 19.8215136}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Knjigom do osmeha', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Bulevar Evrope 7, Novi Sad'}, {'id': 'ChIJ08UL2zoQW0cR-S_WL9s3Lmc', 'types': ['preschool', 'child_care_agency', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Braće Lučić 23, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2429475, 'longitude': 19.8218316}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'rodjendaonicadugaplus', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Braće Lučić 23, Novi Sad'}, {'id': 'ChIJ7Y6QcnMRW0cReEVQU6BYoTU', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dalmatinska 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2408162, 'longitude': 19.821675}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Kombi prevoz, selidbe Stefan Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Dalmatinska 1, Novi Sad'}]
# obtaining places for point  79  /  546
# posting request
# obtained response
# ...
# obtaining places for point  432  /  546
# posting request
# obtained response
# []
# obtaining places for point  433  /  546
# posting request
# obtained response
# []
# obtaining places for point  434  /  546
# posting request
# obtained response
# []
# obtaining places for point  435  /  546
# posting request
# obtained response
# [{'id': 'ChIJmy5-WQARW0cR7TJ_n9HN7PU', 'types': ['health', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sentandrejski put 106б, Novi Sad, Serbia', 'location': {'latitude': 45.2911693, 'longitude': 19.8242658}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'NS Lab', 'languageCode': 'sr'}, 'shortFormattedAddress': 'Sentandrejski put 106б, Novi Sad'}]
# obtaining places for point  436  /  546
# posting request
# obtained response
# [{'id': 'ChIJCwRDOT0RW0cRUC-D-ZwLCVA', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sentandrejski put б.б., Novi Sad 21000, Serbia', 'location': {'latitude': 45.291833499999996, 'longitude': 19.824625299999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Orthodox Church of the Ascension of Our Lord.', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Sentandrejski put б.б., Novi Sad'}]
# obtaining places for point  437  /  546
# posting request
# obtained response
# [{'id': 'ChIJy-OkOpQRW0cRVC5-vFPBp9g', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': '102 20, Novi Sad, Serbia', 'location': {'latitude': 45.2931199, 'longitude': 19.8308604}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Krst Vodica', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': '102 20, Novi Sad'}]
# obtaining places for point  438  /  546
# posting request
# obtained response
# []
# obtaining places for point  439  /  546
# posting request
# obtained response
# [{'id': 'ChIJn3t8tRgRW0cRhWqAn6bC6xs', 'types': ['mosque', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Majke Jugovića 61, Novi Sad, Serbia', 'location': {'latitude': 45.2921951, 'longitude': 19.840226200000004}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dzemat Veliki Rit', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Mosque', 'languageCode': 'en-US'}, 'primaryType': 'mosque', 'shortFormattedAddress': 'Majke Jugovića 61, Novi Sad'}]
# obtaining places for point  440  /  546
# posting request
# obtained response
# []
# obtaining places for point  441  /  546
# posting request
# obtained response
# []
# obtaining places for point  442  /  546
# posting request
# obtained response
# []
# obtaining places for point  443  /  546
# posting request
# obtained response
# []
# obtaining places for point  444  /  546
# posting request
# obtained response
# []
# obtaining places for point  445  /  546
# posting request
# obtained response
# []
# obtaining places for point  446  /  546
# posting request
# obtained response
# []
# obtaining places for point  447  /  546
# posting request
# obtained response
# []
# obtaining places for point  448  /  546
# posting request
# obtained response
# []
# obtaining places for point  449  /  546
# posting request
# obtained response
# []
# obtaining places for point  450  /  546
# posting request
# obtained response
# []
# obtaining places for point  451  /  546
# posting request
# obtained response
# []
# obtaining places for point  452  /  546
# posting request
# obtained response
# []
# obtaining places for point  453  /  546
# posting request
# obtained response
# []
# obtaining places for point  454  /  546
# posting request
# obtained response
# []
# obtaining places for point  455  /  546
# posting request
# obtained response
# [{'id': 'ChIJBRN1GLIRW0cRziHpski66y8', 'types': ['local_government_office', 'insurance_agency', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Velebitska 1a, Novi Sad, Serbia', 'location': {'latitude': 45.295669499999995, 'longitude': 19.8219604}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'OD PUMA, registracija vozila Novi sad, tehnički pregled Novi Sad, osiguranje', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Velebitska 1a, Novi Sad'}]
# obtaining places for point  456  /  546
# posting request
# obtained response
# [{'id': 'ChIJk1QibjsRW0cRnj7oxWS8Rxo', 'types': ['primary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Velebitska, Novi Sad, Serbia', 'location': {'latitude': 45.2957958, 'longitude': 19.8260973}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Основна школа "Душан Радовић" - Велебитска', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Elementary School', 'languageCode': 'en-US'}, 'primaryType': 'primary_school', 'shortFormattedAddress': 'Velebitska, Novi Sad'}]
# obtaining places for point  457  /  546
# posting request
# obtained response
# [{'id': 'ChIJcVc1rSURW0cR638ukYgCtOs', 'types': ['secondary_school', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Dečanska 9, Novi Sad 21000, Serbia', 'location': {'latitude': 45.296146, 'longitude': 19.833088}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola SVETI NIKOLA Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Dečanska 9, Novi Sad'}, {'id': 'ChIJkYZ1IM8RW0cRby399p3JPik', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Dečanska 9, Novi Sad 21000, Serbia', 'location': {'latitude': 45.296178399999995, 'longitude': 19.8329353}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja optičarska škola Pašćan', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dečanska 9, Novi Sad'}]
# obtaining places for point  458  /  546
# posting request
# obtained response
# []
# obtaining places for point  459  /  546
# posting request
# obtained response
# []
# obtaining places for point  460  /  546
# posting request
# obtained response
# []
# obtaining places for point  461  /  546
# posting request
# obtained response
# []
# obtaining places for point  462  /  546
# posting request
# obtained response
# []
# obtaining places for point  463  /  546
# posting request
# obtained response
# []
# obtaining places for point  464  /  546
# posting request
# obtained response
# []
# obtaining places for point  465  /  546
# posting request
# obtained response
# []
# obtaining places for point  466  /  546
# posting request
# obtained response
# []
# obtaining places for point  467  /  546
# posting request
# obtained response
# []
# obtaining places for point  468  /  546
# posting request
# obtained response
# []
# obtaining places for point  469  /  546
# posting request
# obtained response
# []
# obtaining places for point  470  /  546
# posting request
# obtained response
# []
# obtaining places for point  471  /  546
# posting request
# obtained response
# []
# obtaining places for point  472  /  546
# posting request
# obtained response
# [{'id': 'ChIJ-XX8WOYRW0cR37Avprs3CxU', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dr. Milorada Pavlovića 12, Novi Sad 21102, Serbia', 'location': {'latitude': 45.2991971, 'longitude': 19.8188206}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pucke Logistic', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Dr. Milorada Pavlovića 12, Novi Sad'}]
# obtaining places for point  473  /  546
# posting request
# obtained response
# []
# obtaining places for point  474  /  546
# posting request
# obtained response
# []
# obtaining places for point  475  /  546
# posting request
# obtained response
# [{'id': 'ChIJRxBHOzARW0cRQzkqrowrofk', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Mojkovačka 23, Novi Sad 21000, Serbia', 'location': {'latitude': 45.298966199999995, 'longitude': 19.8332463}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'AUTO MOTO SISTEM DOO', 'languageCode': 'sr'}, 'shortFormattedAddress': 'Mojkovačka 23, Novi Sad'}, {'id': 'ChIJwVITADARW0cRmVZN-iXDibU', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Temerinski put 30, Novi Sad, Serbia', 'location': {'latitude': 45.299026, 'longitude': 19.830937}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Art-Ist', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Temerinski put 30, Novi Sad'}]
# obtaining places for point  476  /  546
# posting request
# obtained response
# []
# obtaining places for point  477  /  546
# posting request
# obtained response
# []
# obtaining places for point  478  /  546
# posting request
# obtained response
# []
# obtaining places for point  479  /  546
# posting request
# obtained response
# []
# obtaining places for point  480  /  546
# posting request
# obtained response
# []
# obtaining places for point  481  /  546
# posting request
# obtained response
# []
# obtaining places for point  482  /  546
# posting request
# obtained response
# []
# obtaining places for point  483  /  546
# posting request
# obtained response
# []
# obtaining places for point  484  /  546
# posting request
# obtained response
# []
# obtaining places for point  485  /  546
# posting request
# obtained response
# []
# obtaining places for point  486  /  546
# posting request
# obtained response
# []
# obtaining places for point  487  /  546
# posting request
# obtained response
# []
# obtaining places for point  488  /  546
# posting request
# obtained response
# []
# obtaining places for point  489  /  546
# posting request
# obtained response
# []
# obtaining places for point  490  /  546
# posting request
# obtained response
# []
# obtaining places for point  491  /  546
# posting request
# obtained response
# [{'id': 'ChIJaTuqnzYRW0cRt4kM-265D58', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sečanjska 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.304528, 'longitude': 19.8260801}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Šlep služba Božic Prevoz Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Sečanjska 2, Novi Sad'}]
# obtaining places for point  492  /  546
# posting request
# obtained response
# []
# obtaining places for point  493  /  546
# posting request
# obtained response
# []
# obtaining places for point  494  /  546
# posting request
# obtained response
# []
# obtaining places for point  495  /  546
# posting request
# obtained response
# []
# obtaining places for point  496  /  546
# posting request
# obtained response
# []
# obtaining places for point  497  /  546
# posting request
# obtained response
# []
# obtaining places for point  498  /  546
# posting request
# obtained response
# []
# obtaining places for point  499  /  546
# posting request
# obtained response
# []
# obtaining places for point  500  /  546
# posting request
# obtained response
# []
# obtaining places for point  501  /  546
# posting request
# obtained response
# []
# obtaining places for point  502  /  546
# posting request
# obtained response
# []
# obtaining places for point  503  /  546
# posting request
# obtained response
# []
# obtaining places for point  504  /  546
# posting request
# obtained response
# []
# obtaining places for point  505  /  546
# posting request
# obtained response
# []
# obtaining places for point  506  /  546
# posting request
# obtained response
# []
# obtaining places for point  507  /  546
# posting request
# obtained response
# []
# obtaining places for point  508  /  546
# posting request
# obtained response
# []
# obtaining places for point  509  /  546
# posting request
# obtained response
# []
# obtaining places for point  510  /  546
# posting request
# obtained response
# []
# obtaining places for point  511  /  546
# posting request
# obtained response
# []
# obtaining places for point  512  /  546
# posting request
# obtained response
# []
# obtaining places for point  513  /  546
# posting request
# obtained response
# []
# obtaining places for point  514  /  546
# posting request
# obtained response
# []
# obtaining places for point  515  /  546
# posting request
# obtained response
# []
# obtaining places for point  516  /  546
# posting request
# obtained response
# []
# obtaining places for point  517  /  546
# posting request
# obtained response
# []
# obtaining places for point  518  /  546
# posting request
# obtained response
# []
# obtaining places for point  519  /  546
# posting request
# obtained response
# [{'id': 'ChIJTWhbpjARW0cRGf6kQ9jcsqA', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Sentandrejski put 161a, Novi Sad 21000, Serbia', 'location': {'latitude': 45.3098423, 'longitude': 19.8256518}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Pan Logistic', 'languageCode': 'en'}, 'shortFormattedAddress': 'Sentandrejski put 161a, Novi Sad'}]
# obtaining places for point  520  /  546
# posting request
# obtained response
# []
# obtaining places for point  521  /  546
# posting request
# obtained response
# []
# obtaining places for point  522  /  546
# posting request
# obtained response
# []
# obtaining places for point  523  /  546
# posting request
# obtained response
# []
# obtaining places for point  524  /  546
# posting request
# obtained response
# []
# obtaining places for point  525  /  546
# posting request
# obtained response
# []
# obtaining places for point  526  /  546
# posting request
# obtained response
# []
# obtaining places for point  527  /  546
# posting request
# obtained response
# []
# obtaining places for point  528  /  546
# posting request
# obtained response
# []
# obtaining places for point  529  /  546
# posting request
# obtained response
# []
# obtaining places for point  530  /  546
# posting request
# obtained response
# []
# obtaining places for point  531  /  546
# posting request
# obtained response
# []
# obtaining places for point  532  /  546
# posting request
# obtained response
# [{'id': 'ChIJs7eaKeUXW0cRuAEMzxXv8n8', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Сентандрејски пут & 100, Novi Sad, Serbia', 'location': {'latitude': 45.313055299999995, 'longitude': 19.8295542}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Sportska ambulanta', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Hospital', 'languageCode': 'en-US'}, 'primaryType': 'hospital', 'shortFormattedAddress': 'Сентандрејски пут & 100, Novi Sad'}]
# obtaining places for point  533  /  546
# posting request
# obtained response
# []
# obtaining places for point  534  /  546
# posting request
# obtained response
# []
# obtaining places for point  535  /  546
# posting request
# obtained response
# []
# obtaining places for point  536  /  546
# posting request
# obtained response
# []
# obtaining places for point  537  /  546
# posting request
# obtained response
# []
# obtaining places for point  538  /  546
# posting request
# obtained response
# []
# obtaining places for point  539  /  546
# posting request
# obtained response
# []
# obtaining places for point  540  /  546
# posting request
# obtained response
# []
# obtaining places for point  541  /  546
# posting request
# obtained response
# []
# obtaining places for point  542  /  546
# posting request
# obtained response
# []
# obtaining places for point  543  /  546
# posting request
# obtained response
# []
# obtaining places for point  544  /  546
# posting request
# obtained response
# []
# obtaining places for point  545  /  546
# posting request
# obtained response
# []

# %%
# ensure no points which reached the 20-place cutoff from Google
idxs_of_problem_spots = [i for i, pt in enumerate(points_lst) if len(list(pt.values())[0]) > 19]
idxs_of_problem_spots

# keep only the results that weren't cut off by the api limit
points_lst_good = [pt for idx, pt in enumerate(points_lst) if idx not in idxs_of_problem_spots]
print(len(points_lst_good))

# re-run the points with > 20 locations using the 'split' method
# first, get geometry representations for each of the points that had > 20 places
problem_points = [points_lst[i] for i in idxs_of_problem_spots]
print(len(problem_points))
# then, get these geometries as a list
prob_point_vals = [list(pt.keys())[0] for pt in problem_points]
print(prob_point_vals)
# finally, filter the overall grid space to identify these problem geometries
pts_to_repeat = grid[grid['geometry'].isin(prob_point_vals)]
pts_to_repeat
# Out:
# 542
# 4
# [<POINT (19.843 45.253)>, <POINT (19.848 45.253)>, <POINT (19.843 45.256)>, <POINT (19.848 45.256)>]
#      Id                   geometry
# 140   0  POINT (19.84324 45.25264)
# 141   0  POINT (19.84833 45.25269)
# 162   0  POINT (19.84316 45.25624)
# 163   0  POINT (19.84826 45.25629)

# %%
# all works, good to go
points_lst_fixed = obtain_places_from_points(url, headers, pts_to_repeat, 200, 'split')
# Out:
# obtaining places for point  140  /  4
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJUTlceWkQW0cRBs_grCGE_eY', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 4a, Novi Sad, Serbia', 'location': {'latitude': 45.253130899999995, 'longitude': 19.8440284}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Singidunum university', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 4a, Novi Sad'}, {'id': 'ChIJYZTN0msQW0cRcdx-f6eW6-8', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 7, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2524278, 'longitude': 19.843636999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola "Svetozar Miletić", Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Narodnih heroja 7, Novi Sad'}, {'id': 'ChIJCb0UMWoQW0cRWFVb03OBJTo', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg mladenaca 5, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2521546, 'longitude': 19.8428306}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Гимназија "Смарт"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Trg mladenaca 5, Novi Sad'}, {'id': 'ChIJg2wqG2oQW0cRc46jLvRn9AY', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Petra Drapšina 8, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252765, 'longitude': 19.8414695}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Higher Professional School For The Education Of Teachers', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Petra Drapšina 8, Novi Sad'}, {'id': 'ChIJweHSamoQW0cRUbhdPd1U45w', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Petra Drapšina 13, Novi Sad, Serbia', 'location': {'latitude': 45.2518702, 'longitude': 19.8410401}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Seventh-day Adventist church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Petra Drapšina 13, Novi Sad'}, {'id': 'ChIJE0ACzm4QW0cRTztCB8QPsrI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 2 sprat 9, kancelarija 7, Novi Sad, Serbia', 'location': {'latitude': 45.2532602, 'longitude': 19.8427479}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zanatsko obrazovni centar Adzija', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Narodnih heroja 2 sprat 9, kancelarija 7, Novi Sad'}, {'id': 'ChIJrZ5vxSsRW0cRttMkbIpGVOA', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 5, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252760699999996, 'longitude': 19.8431486}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Библиотечки огранак Стеван Сремац', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Narodnih heroja 5, Novi Sad'}, {'id': 'ChIJe7lYhGkQW0cRkT5v6O1dLgU', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina, Novi Sad, Serbia', 'location': {'latitude': 45.2532536, 'longitude': 19.8437524}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Јерменски хачкар', 'languageC ...
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJN4dpX2kQW0cR6v7G6zERQsk', 'types': ['cultural_landmark', 'tourist_attraction', 'art_gallery', 'museum', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Galerija 1, Novi Sad 21101, Serbia', 'location': {'latitude': 45.252514, 'longitude': 19.845693}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Gallery of Matica Srpska', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Trg Galerija 1, Novi Sad'}, {'id': 'ChIJxQkTw2sQW0cRLqmp6O2BtlE', 'types': ['dental_clinic', 'hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vase Stajića 4, Novi Sad 21000, Serbia', 'location': {'latitude': 45.251964, 'longitude': 19.844521999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Stomatološka poliklinika prof. Džolev', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Dental Clinic', 'languageCode': 'en-US'}, 'primaryType': 'dental_clinic', 'shortFormattedAddress': 'Vase Stajića 4, Novi Sad'}, {'id': 'ChIJJdY8l2kQW0cR3JZ1htIvE-U', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kralja Aleksandra 14, Novi Sad 21000, Serbia', 'location': {'latitude': 45.253918899999995, 'longitude': 19.8435032}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Menrat’s palace', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Kralja Aleksandra 14, Novi Sad'}, {'id': 'ChIJG3fm5msQW0cRyWLsL73TQN0', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vase Stajića 1, Novi Sad, Serbia', 'location': {'latitude': 45.252227700000006, 'longitude': 19.845174699999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Gallery of Fine Arts – Gift Collection of Rajko Mamuzić', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Vase Stajića 1, Novi Sad'}, {'id': 'ChIJo39PZRIRW0cRIMIejQHEP9I', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg mladenaca 7c, Novi Sad, Serbia', 'location': {'latitude': 45.2520445, 'longitude': 19.8425466}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Matičarsko zdanje', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Trg mladenaca 7c, Novi Sad'}, {'id': 'ChIJKSWMHv4RW0cROWWB3ohHK0A', 'types': ['lawyer', 'finance', 'consultant', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Kralja Aleksandra 12, Novi Sad 21000, Serbia', 'location': {'latitude': 45.254050500000005, 'longitude': 19.8436628}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Advokat Stefan Dačević Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Attorney', 'languageCode': 'en-US'}, 'primaryType': 'lawyer', 'shortFormattedAddress': 'Kralja Aleksandra 12, Novi Sad'}, {'id': 'ChIJ1RJp52oQW0cRHT8HG44ikiQ', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': '6/III ZELEZNICKA, 21000, Novi Sad, Juzno-backi county, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2515204, 'longitude': 19.842068299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zavod Za Urbanizam Vojvodine', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': '6/III ZELEZNICKA, 21000, Novi Sa ...
# Number of results returned from re:  14
# Number of results returned from cg:  18
# [{'id': 'ChIJUTlceWkQW0cRBs_grCGE_eY', 'types': ['university', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 4a, Novi Sad, Serbia', 'location': {'latitude': 45.253130899999995, 'longitude': 19.8440284}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Singidunum university', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'University', 'languageCode': 'en-US'}, 'primaryType': 'university', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 4a, Novi Sad'}, {'id': 'ChIJYZTN0msQW0cRcdx-f6eW6-8', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 7, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2524278, 'longitude': 19.843636999999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Srednja škola "Svetozar Miletić", Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Narodnih heroja 7, Novi Sad'}, {'id': 'ChIJCb0UMWoQW0cRWFVb03OBJTo', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg mladenaca 5, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2521546, 'longitude': 19.8428306}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Гимназија "Смарт"', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Trg mladenaca 5, Novi Sad'}, {'id': 'ChIJg2wqG2oQW0cRc46jLvRn9AY', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Petra Drapšina 8, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252765, 'longitude': 19.8414695}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Higher Professional School For The Education Of Teachers', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Petra Drapšina 8, Novi Sad'}, {'id': 'ChIJweHSamoQW0cRUbhdPd1U45w', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Petra Drapšina 13, Novi Sad, Serbia', 'location': {'latitude': 45.2518702, 'longitude': 19.8410401}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Seventh-day Adventist church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Petra Drapšina 13, Novi Sad'}, {'id': 'ChIJE0ACzm4QW0cRTztCB8QPsrI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 2 sprat 9, kancelarija 7, Novi Sad, Serbia', 'location': {'latitude': 45.2532602, 'longitude': 19.8427479}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Zanatsko obrazovni centar Adzija', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Narodnih heroja 2 sprat 9, kancelarija 7, Novi Sad'}, {'id': 'ChIJrZ5vxSsRW0cRttMkbIpGVOA', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Narodnih heroja 5, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252760699999996, 'longitude': 19.8431486}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Библиотечки огранак Стеван Сремац', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Narodnih heroja 5, Novi Sad'}, {'id': 'ChIJe7lYhGkQW0cRkT5v6O1dLgU', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina, Novi Sad, Serbia', 'location': {'latitude': 45.2532536, 'longitude': 19.8437524}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Јерменски хачкар', 'languageCode': 'sr'}, 'primaryTypeDisplayName':  ...
# obtaining places for point  141  /  4
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJcw-ooG4QW0cRvMyqri2DUAw', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vladike Platona 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252149499999994, 'longitude': 19.8481442}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': '"Isidora Sekulić" Grammar School', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Vladike Platona 2, Novi Sad'}, {'id': 'ChIJFRKWom0QW0cRC6i-3fRwbFM', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Modene 5, Novi Sad, Serbia', 'location': {'latitude': 45.254340899999995, 'longitude': 19.8474337}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Tesla centar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Modene 5, Novi Sad'}, {'id': 'ChIJYVSPDeARW0cRQXa2GdrlDt8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 13, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2535844, 'longitude': 19.8493715}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Škola stranih jezika "Libro"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 13, Novi Sad'}, {'id': 'ChIJiZVW2WoQW0cRPBKUBSZnOH4', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Modene 5a , II sprat, Novi Sad 21101, Serbia', 'location': {'latitude': 45.254340899999995, 'longitude': 19.8474337}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'IT Fusion - Edukativni centar', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Modene 5a , II sprat, Novi Sad'}]}
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJaUaVw24QW0cR2dVui1s7EIE', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 16, Novi Sad 400346, Serbia', 'location': {'latitude': 45.2534008, 'longitude': 19.849213499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Покрајинска влада', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 16, Novi Sad'}, {'id': 'ChIJB5EPgXoRW0cR5g-eeq3lrh8', 'types': ['local_government_office', 'accounting', 'finance', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 14, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2533922, 'longitude': 19.8464849}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ministarstvo Finansija Poreska Uprava', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 14, Novi Sad'}, {'id': 'ChIJR5d0TGkQW0cRMV-MRR-QYe8', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Žarka Zrenjanina 2, Novi Sad, Serbia', 'location': {'latitude': 45.2530351, 'longitude': 19.8472324}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Assembly of Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Žarka Zrenjanina 2, Novi Sad'}, {'id': 'ChIJKeo4XGkQW0cR3qhCYOiVnUE', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zadužbina Pavla Beljanskog, Trg Galerija 2, Novi Sad 21101, Serbia', 'location': {'latitude': 45.2527228, 'longitude': 19.846010000000003}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'The Pavle Beljanski Memorial Collection', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Pavle Beljanski Foundation, Trg Galerija 2, Novi Sad'}, {'id': 'ChIJ_1drlW4QW0cRUPZAFOHf1wE', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vladike Platona bb, Novi Sad, Serbia', 'location': {'latitude': 45.2529097, 'longitude': 19.849298599999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Skupština AP Vojvodine', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Vladike Platona bb, Novi Sad'}, {'id': 'ChIJnZnlCR0RW0cRUjSDc-jsyrk', 'types': ['local_government_office', 'accounting', 'finance', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Modene 7, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2542581, 'longitude': 19.8478384}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'UPRAVA ZA TREZOR FILIJALA NOVI SAD', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Modene 7, Novi Sad'}, {'id': 'ChIJ-54jxm4QW0cRZPiVwsIm3Z4', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 12, Novi Sad 400346, Serbia', 'location': {'latitude': 45.253334800000005, 'longitude': 19.848652500000004}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Provincial Secretariat for Education, Regulations, Administration and National Minorities – National Communities', 'languageCode': 'en'}, 'primaryTypeDisplay ...
# Number of results returned from re:  4
# Number of results returned from cg:  16
# [{'id': 'ChIJcw-ooG4QW0cRvMyqri2DUAw', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vladike Platona 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.252149499999994, 'longitude': 19.8481442}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': '"Isidora Sekulić" Grammar School', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Vladike Platona 2, Novi Sad'}, {'id': 'ChIJFRKWom0QW0cRC6i-3fRwbFM', 'types': ['secondary_school', 'school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Modene 5, Novi Sad, Serbia', 'location': {'latitude': 45.254340899999995, 'longitude': 19.8474337}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Tesla centar', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'High school', 'languageCode': 'en-US'}, 'primaryType': 'secondary_school', 'shortFormattedAddress': 'Modene 5, Novi Sad'}, {'id': 'ChIJYVSPDeARW0cRQXa2GdrlDt8', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 13, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2535844, 'longitude': 19.8493715}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Škola stranih jezika "Libro"', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 13, Novi Sad'}, {'id': 'ChIJiZVW2WoQW0cRPBKUBSZnOH4', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Modene 5a , II sprat, Novi Sad 21101, Serbia', 'location': {'latitude': 45.254340899999995, 'longitude': 19.8474337}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'IT Fusion - Edukativni centar', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Modene 5a , II sprat, Novi Sad'}, {'id': 'ChIJaUaVw24QW0cR2dVui1s7EIE', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 16, Novi Sad 400346, Serbia', 'location': {'latitude': 45.2534008, 'longitude': 19.849213499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Покрајинска влада', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 16, Novi Sad'}, {'id': 'ChIJB5EPgXoRW0cR5g-eeq3lrh8', 'types': ['local_government_office', 'accounting', 'finance', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Bulevar Mihajla Pupina 14, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2533922, 'longitude': 19.8464849}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Ministarstvo Finansija Poreska Uprava', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Bulevar Mihajla Pupina 14, Novi Sad'}, {'id': 'ChIJR5d0TGkQW0cRMV-MRR-QYe8', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Žarka Zrenjanina 2, Novi Sad, Serbia', 'location': {'latitude': 45.2530351, 'longitude': 19.8472324}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Assembly of Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Žarka Zrenjanina 2, Novi Sad'}, {'id': 'ChIJKeo4XGkQW0cR3qhCYOiVnUE', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zadužbina Pavla Beljanskog, Trg Galerija 2, Novi Sad 21101, Serbia', 'location': {'latitude': 45.2527228, 'longitude': ...
# obtaining places for point  162  /  4
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJsyANgEIQW0cRoxpYHW3phKc', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2555249, 'longitude': 19.842189299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dormition Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Pozorišni trg 1, Novi Sad'}, {'id': 'ChIJ5UQSpkIQW0cR-4ZRjinIt3s', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Njegoševa 22, Novi Sad 21000, Serbia', 'location': {'latitude': 45.25712430000001, 'longitude': 19.842993}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': '"Svetozar Marković" Middle school', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Svetozar Marković secondary school, Novi Sad, Njegoševa 22, Novi Sad'}, {'id': 'ChIJn8PuPWgQW0cRjBFCbWm5ZWQ', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Njegoševa 15, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2569656, 'longitude': 19.8418655}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto skola Formula b drive', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Njegoševa 15, Novi Sad'}, {'id': 'ChIJ90-GxkIQW0cRQmsApatUkEY', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vuka Karadžića 2, Novi Sad, Serbia', 'location': {'latitude': 45.2572845, 'longitude': 19.8414152}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Slovak Evangelical Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Vuka Karadžića 2, Novi Sad'}, {'id': 'ChIJhybvCWgQW0cRT7QNR0_EaFQ', 'types': ['preschool', 'child_care_agency', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Svetozara Miletića 22, Novi Sad 21000, Serbia', 'location': {'latitude': 45.257326899999995, 'longitude': 19.8447091}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Plavi Zec', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Svetozara Miletića 22, Novi Sad'}, {'id': 'ChIJgRaUB2gQW0cRkvHSrci9nOk', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Svetozara Miletića 28, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2574849, 'longitude': 19.844384599999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Savez slepih Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Svetozara Miletića 28, Novi Sad'}, {'id': 'ChIJ5TOVZ2gQW0cRnJD_cLFWJxc', 'types': ['consultant', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Katolička porta 6, Novi Sad, Serbia', 'location': {'latitude': 45.2561809, 'longitude': 19.8455545}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Egida International', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Consultant', 'languageCode': 'en-US'}, 'primaryType': 'consultant', 'shortFormattedAddress': 'Katolička porta 6, Novi Sad'}, {'id': 'ChIJB5KnUl0QW0cR5ekmAaygPjI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': '21000, Svetozara Miletića, Novi Sad, Serbia', 'location': {'latitude': 45.257839, 'longitude': 19.8430045}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Aikido Klub Tenokami Dojo', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode':  ...
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJfd5VLWgQW0cRYnHABiL5ERc', 'types': ['performing_arts_theater', 'event_venue', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.255086299999995, 'longitude': 19.842783400000002}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Serbian National Theatre', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Performing Arts Theater', 'languageCode': 'en-US'}, 'primaryType': 'performing_arts_theater', 'shortFormattedAddress': 'Pozorišni trg 1, Novi Sad'}, {'id': 'ChIJNTVGU2gQW0cRw838k00cpyQ', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Novi Sad, Serbia', 'location': {'latitude': 45.255057799999996, 'longitude': 19.8448509}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Monument of Svetozar Miletić', 'languageCode': 'en'}, 'shortFormattedAddress': 'Novi Sad'}, {'id': 'ChIJsdt4-GgQW0cRUC8uDu5rHoE', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'City Centre, Novi Sad, Serbia', 'location': {'latitude': 45.2551503, 'longitude': 19.8451374}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Градско језгро Новог Сада', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Novi Sad'}, {'id': 'ChIJe4eUrWkQW0cR1yB89zw9NEA', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.254876599999996, 'longitude': 19.844428399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Градска Управа', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Pozorišni trg 1, Novi Sad'}, {'id': 'ChIJE13Ya2gQW0cRwaitUDqyuPI', 'types': ['cultural_center', 'point_of_interest', 'establishment'], 'formattedAddress': 'Katolička porta 5, Novi Sad 21101, Serbia', 'location': {'latitude': 45.256403299999995, 'longitude': 19.845053}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Cultural Center of Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Cultural Center', 'languageCode': 'en-US'}, 'primaryType': 'cultural_center', 'shortFormattedAddress': 'Katolička porta 5, Novi Sad'}, {'id': 'ChIJedEoqgURW0cRv37PgDVhGas', 'types': ['city_hall', 'local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg, Novi Sad, Serbia', 'location': {'latitude': 45.254847, 'longitude': 19.8445927}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi Sad City Hall', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'City Hall', 'languageCode': 'en-US'}, 'primaryType': 'city_hall', 'shortFormattedAddress': 'Pozorišni trg, Novi Sad'}, {'id': 'ChIJFSTCS0ERW0cRtpgSZN2y_G4', 'types': ['local_government_office', 'government_office', 'point_of_interest', 'establishment'], 'formattedAddress': 'Njegoševa 16, Trifkovićev trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.256766299999995, 'longitude': 19.843732499999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto skola Time Speed', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Local Government Office', 'languageCode': 'en-US'}, 'primaryType': 'local_government_office', 'shortFormattedAddress': 'Njegoševa 16, Trifkovićev trg 1, Novi Sad'}, {'id': 'ChIJr0P6s2kQW0cRfpfKyopE4XI', 'types': ['historical_landmark', 'tourist_attraction', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2 ...
# Number of results returned from re:  8
# Number of results returned from cg:  19
# [{'id': 'ChIJsyANgEIQW0cRoxpYHW3phKc', 'types': ['tourist_attraction', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pozorišni trg 1, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2555249, 'longitude': 19.842189299999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Dormition Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Pozorišni trg 1, Novi Sad'}, {'id': 'ChIJ5UQSpkIQW0cR-4ZRjinIt3s', 'types': ['point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Njegoševa 22, Novi Sad 21000, Serbia', 'location': {'latitude': 45.25712430000001, 'longitude': 19.842993}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': '"Svetozar Marković" Middle school', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Svetozar Marković secondary school, Novi Sad, Njegoševa 22, Novi Sad'}, {'id': 'ChIJn8PuPWgQW0cRjBFCbWm5ZWQ', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Njegoševa 15, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2569656, 'longitude': 19.8418655}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Auto skola Formula b drive', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Njegoševa 15, Novi Sad'}, {'id': 'ChIJ90-GxkIQW0cRQmsApatUkEY', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Vuka Karadžića 2, Novi Sad, Serbia', 'location': {'latitude': 45.2572845, 'longitude': 19.8414152}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Slovak Evangelical Church', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Vuka Karadžića 2, Novi Sad'}, {'id': 'ChIJhybvCWgQW0cRT7QNR0_EaFQ', 'types': ['preschool', 'child_care_agency', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Svetozara Miletića 22, Novi Sad 21000, Serbia', 'location': {'latitude': 45.257326899999995, 'longitude': 19.8447091}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Plavi Zec', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Preschool', 'languageCode': 'en-US'}, 'primaryType': 'preschool', 'shortFormattedAddress': 'Svetozara Miletića 22, Novi Sad'}, {'id': 'ChIJgRaUB2gQW0cRkvHSrci9nOk', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Svetozara Miletića 28, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2574849, 'longitude': 19.844384599999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Savez slepih Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Svetozara Miletića 28, Novi Sad'}, {'id': 'ChIJ5TOVZ2gQW0cRnJD_cLFWJxc', 'types': ['consultant', 'point_of_interest', 'school', 'establishment'], 'formattedAddress': 'Katolička porta 6, Novi Sad, Serbia', 'location': {'latitude': 45.2561809, 'longitude': 19.8455545}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Egida International', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Consultant', 'languageCode': 'en-US'}, 'primaryType': 'consultant', 'shortFormattedAddress': 'Katolička porta 6, Novi Sad'}, {'id': 'ChIJB5KnUl0QW0cR5ekmAaygPjI', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': '21000, Svetozara Miletića, Novi Sad, Serbia', 'location': {'latitude': 45.257839, 'longitude': 19.8430045}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Aikido Klub Tenokami Dojo', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'sho ...
# obtaining places for point  163  /  4
# Obtaining religious and educational places..
# posting request
# obtained response
# Religious & Edu out_places: {'places': [{'id': 'ChIJ9wksMmYQW0cRkseM-zEkSdw', 'types': ['tourist_attraction', 'cultural_landmark', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Nikole Pašića 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2575532, 'longitude': 19.8476844}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Saint George's Cathedral", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Nikole Pašića 2, Novi Sad'}, {'id': 'ChIJrctQIGYQW0cRV_iav51MSp8', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 1, Novi Sad 21101, Serbia', 'location': {'latitude': 45.2568704, 'longitude': 19.8483397}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi Sad City Library', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Dunavska 1, Novi Sad'}, {'id': 'ChIJhWuqPWYQW0cRIOUhMbVTYbg', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg republike 2, Novi Sad, Serbia', 'location': {'latitude': 45.2575193, 'longitude': 19.848772399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska biblioteka u Novom Sadu, ogranak „Anica Savić Rebac”', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Trg republike 2, Novi Sad'}, {'id': 'ChIJQe4Rdt8RW0cRyCOJudKajfE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 16, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2561847, 'longitude': 19.849843699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Radionice Presto', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 16, Novi Sad'}, {'id': 'ChIJ-0ArDoQRW0cROGQCEEpyEoQ', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 17, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2572671, 'longitude': 19.8497204}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Scool - Centar stranih jezika Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 17, Novi Sad'}, {'id': 'ChIJM7koF2YQW0cRdfORrhcVwGo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 14a, Novi Sad, Serbia', 'location': {'latitude': 45.255570299999995, 'longitude': 19.8472614}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Muzički Atelje', 'languageCode': 'en'}, 'shortFormattedAddress': 'Zmaj Jovina 14a, Novi Sad'}, {'id': 'ChIJ_6ZDUQARW0cRtIQKHvRmnlw', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg republike 2, Novi Sad, Serbia', 'location': {'latitude': 45.2576884, 'longitude': 19.8484201}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Јовин плато', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg republike 2, Novi Sad'}]}
# Obtaining cultural and government places..
# posting request
# obtained response
# Culture & Gov out_places: {'places': [{'id': 'ChIJ84sp2GcQW0cRNSOtA9D5nlw', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Grčkoškolska 3, Novi Sad 21000, Serbia', 'location': {'latitude': 45.25736080000001, 'longitude': 19.846236899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Poliklinika Pekić', 'languageCode': 'en'}, 'shortFormattedAddress': 'Grčkoškolska 3, Novi Sad'}, {'id': 'ChIJs7bVJWYQW0cRa6O4DKM5ESc', 'types': ['place_of_worship', 'historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 27, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2570316, 'longitude': 19.8479201}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Владичански двор', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Place of Worship', 'languageCode': 'en-US'}, 'primaryType': 'place_of_worship', 'shortFormattedAddress': 'Zmaj Jovina 27, Novi Sad'}, {'id': 'ChIJcS2RNWYQW0cRnLPp5ODGe2Q', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 25-19, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2568649, 'longitude': 19.8477697}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Jovan Jovanovic Zmaj statue', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Zmaj Jovina 25-19, Novi Sad'}, {'id': 'ChIJlUtD_2UQW0cRT-Gh5R5BkTU', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 29, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2564187, 'longitude': 19.8502693}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'City Museum of Novi Sad', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Museum', 'languageCode': 'en-US'}, 'primaryType': 'museum', 'shortFormattedAddress': 'Dunavska 29, Novi Sad'}, {'id': 'ChIJr9ZrBNoRW0cR0IfRoaXE798', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg Republike, Novi Sad, Serbia', 'location': {'latitude': 45.2576983, 'longitude': 19.849218099999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Споменик краљу Петру I Карађорђевићу Ослободиоцу', 'languageCode': 'sr'}, 'shortFormattedAddress': 'Parking lot, Republic Square, Trg Republike, Novi Sad'}, {'id': 'ChIJ6flGVG8QW0cRRn01EeSQS9Y', 'types': ['historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 29, Novi Sad 21000, Serbia', 'location': {'latitude': 45.256307199999995, 'longitude': 19.8501864}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Јаша Томић', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Historical Landmark', 'languageCode': 'en-US'}, 'primaryType': 'historical_landmark', 'shortFormattedAddress': 'Dunavska 29, Novi Sad'}, {'id': 'ChIJi72ykWgQW0cRdj8IWjLsPrc', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 22, Novi Sad, Serbia', 'location': {'latitude': 45.2560448, 'longitude': 19.8481891}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Šok zadruga', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddress': 'Zmaj Jovina 22, Novi Sad'}, {'id': 'ChIJD1Sm3GgQW0cRswOadP6S544', 'types': ['art_gallery', 'point_of_interest', 'establishment'], 'formattedAddress': 'Pasaž-dole desno u uglu, Zmaj Jovina 22, Novi Sad 21000, Serbia', 'location': {'latitude': 45.256124299999996, 'longitude': 19.8479875}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska Prodajna Galerija', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Art Gallery', 'languageCode': 'en-US'}, 'primaryType': 'art_gallery', 'shortFormattedAddres ...
# Number of results returned from re:  7
# Number of results returned from cg:  18
# [{'id': 'ChIJ9wksMmYQW0cRkseM-zEkSdw', 'types': ['tourist_attraction', 'cultural_landmark', 'church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Nikole Pašića 2, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2575532, 'longitude': 19.8476844}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': "Saint George's Cathedral", 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Nikole Pašića 2, Novi Sad'}, {'id': 'ChIJrctQIGYQW0cRV_iav51MSp8', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 1, Novi Sad 21101, Serbia', 'location': {'latitude': 45.2568704, 'longitude': 19.8483397}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Novi Sad City Library', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Dunavska 1, Novi Sad'}, {'id': 'ChIJhWuqPWYQW0cRIOUhMbVTYbg', 'types': ['library', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg republike 2, Novi Sad, Serbia', 'location': {'latitude': 45.2575193, 'longitude': 19.848772399999998}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Gradska biblioteka u Novom Sadu, ogranak „Anica Savić Rebac”', 'languageCode': 'sr-Latn'}, 'primaryTypeDisplayName': {'text': 'Library', 'languageCode': 'en-US'}, 'primaryType': 'library', 'shortFormattedAddress': 'Trg republike 2, Novi Sad'}, {'id': 'ChIJQe4Rdt8RW0cRyCOJudKajfE', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 16, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2561847, 'longitude': 19.849843699999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Radionice Presto', 'languageCode': 'en'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 16, Novi Sad'}, {'id': 'ChIJ-0ArDoQRW0cROGQCEEpyEoQ', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Dunavska 17, Novi Sad 21000, Serbia', 'location': {'latitude': 45.2572671, 'longitude': 19.8497204}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Scool - Centar stranih jezika Novi Sad', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'School', 'languageCode': 'en-US'}, 'primaryType': 'school', 'shortFormattedAddress': 'Dunavska 17, Novi Sad'}, {'id': 'ChIJM7koF2YQW0cRdfORrhcVwGo', 'types': ['school', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 14a, Novi Sad, Serbia', 'location': {'latitude': 45.255570299999995, 'longitude': 19.8472614}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Muzički Atelje', 'languageCode': 'en'}, 'shortFormattedAddress': 'Zmaj Jovina 14a, Novi Sad'}, {'id': 'ChIJ_6ZDUQARW0cRtIQKHvRmnlw', 'types': ['church', 'place_of_worship', 'point_of_interest', 'establishment'], 'formattedAddress': 'Trg republike 2, Novi Sad, Serbia', 'location': {'latitude': 45.2576884, 'longitude': 19.8484201}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Јовин плато', 'languageCode': 'sr'}, 'primaryTypeDisplayName': {'text': 'Church', 'languageCode': 'en-US'}, 'primaryType': 'church', 'shortFormattedAddress': 'Trg republike 2, Novi Sad'}, {'id': 'ChIJ84sp2GcQW0cRNSOtA9D5nlw', 'types': ['hospital', 'health', 'point_of_interest', 'establishment'], 'formattedAddress': 'Grčkoškolska 3, Novi Sad 21000, Serbia', 'location': {'latitude': 45.25736080000001, 'longitude': 19.846236899999997}, 'businessStatus': 'OPERATIONAL', 'displayName': {'text': 'Poliklinika Pekić', 'languageCode': 'en'}, 'shortFormattedAddress': 'Grčkoškolska 3, Novi Sad'}, {'id': 'ChIJs7bVJWYQW0cRa6O4DKM5ESc', 'types': ['place_of_worship', 'historical_landmark', 'historical_place', 'point_of_interest', 'establishment'], 'formattedAddress': 'Zmaj Jovina 27, Novi Sad 21000, Serbia', 'location': {' ...

# %%
points_lst_fin = points_lst_fixed + points_lst_good
print(len(points_lst_fin))

city_gdf = clean_maps_api_output(points_lst_fin)

city_gdf.to_file("/mnt/c/Users/natra/Documents/Research/Identity-Conflict/serbia_files/clean/novi_sad_locs_400x400.geojson",
                          driver='GeoJSON')
